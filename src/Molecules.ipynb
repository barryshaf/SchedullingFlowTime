# %% [markdown]
# # Quantum Chem. VQE-MUB Code, V2
#
# Refactored to work with qiskit-nature 0.7.2 and qiskit 1.2.0.
# Because everything else breaks all the way to hell.
#
# Written by Ittay Alfassi, based on work from Dekel Meirom

# %% [markdown]
# ### Required Versions:
# - qiskit-nature==0.7.2  (via pip)
# - pyscf==2.6.2          (via conda)
# - matplotlib==3.9.2     (via conda)
# - qiskit==1.2.0         (via pip, automatic when installing qiskit-nature)
# - numpy==1.26.4         (built-in with conda)

# %% [markdown]
# ### Required Infrastructure

# %% [markdown]
# - Linux or MacOS. **We highly recommend** to use the supplied dockerfile to set up a debian container.
# - Miniconda3 (current version is conda 24.7.1)

# %% [markdown]
# ## Imports

# %%
import qiskit
import numpy as np
from qiskit import QuantumCircuit
import numpy as npwhich 
from numpy import sin,cos,pi,linspace,zeros
from qiskit.circuit import Parameter
from qiskit.quantum_info import Statevector, SparsePauliOp
from qiskit.result import Counts, Result
from typing import Optional, List, Dict, Tuple, Union
from matplotlib import pyplot as plt
from itertools import product

# %% [markdown]
# ### Quantum Chemistry Imports

# %%
from pyscf import scf
from pyscf import gto

# %%
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.drivers.electronic_structure_driver import MethodType

from qiskit_nature.second_q.problems.electronic_structure_problem import ElectronicStructureProblem
from qiskit_nature.second_q.mappers import ParityMapper, JordanWignerMapper, BravyiKitaevMapper
from qiskit_nature.second_q.transformers import ActiveSpaceTransformer
from qiskit_algorithms import NumPyMinimumEigensolver
from qiskit_nature.second_q.algorithms import GroundStateEigensolver

# %% [markdown]
# ## Qubit operator generation functions

# %%
from qiskit_nature.second_q.drivers import PySCFDriver, MethodType
from qiskit_nature.second_q.mappers import ParityMapper, JordanWignerMapper, BravyiKitaevMapper
from qiskit_nature.second_q.problems import ElectronicStructureProblem
from qiskit.quantum_info import SparsePauliOp
from qiskit_nature.second_q.transformers import ActiveSpaceTransformer
from typing import Optional

def get_method_type(method: str) -> MethodType:
    method = method.lower()
    return {
        "rhf": MethodType.RHF,
        "uhf": MethodType.UHF,
        "rohf": MethodType.ROHF,
        "rks": MethodType.RKS,
        "uks": MethodType.UKS
    }.get(method, MethodType.RHF)  # Default to RHF

def get_qubit_op( #This is the important function responsible for getting the hamiltonian to solve
    molecule_str: str,
    charge: int = 0,
    basis: str = "sto3g",
    mapping_name: str = "parity",
    transformer: Optional[ActiveSpaceTransformer] = None,
    method_type: str = "rhf",
    spin: int = 0
) -> tuple[SparsePauliOp, ElectronicStructureProblem]:
    driver = PySCFDriver(
        atom=molecule_str,
        unit=DistanceUnit.ANGSTROM,
        charge=charge,
        basis=basis,
        spin=spin,
        method=get_method_type(method_type),
    )
    problem = driver.run()
    
    if transformer:
        problem = transformer.transform(problem)
    
    second_q_op = problem.hamiltonian.second_q_op()

    mapper_classes = {
        "parity": ParityMapper,
        "jordan": JordanWignerMapper,
        "bravi": BravyiKitaevMapper,
    }
    
    mapper_class = mapper_classes.get(mapping_name)
    if mapper_class is None:
        print("Mapper should be one of 'parity', 'jordan', or 'bravi'.")
        return None
    
    # If the mapping is "jordan", the mapper does not require additional arguments
    # Otherwise, the mapper requires the number of particles as an argument
    mapper = mapper_class() if mapping_name == "jordan" else mapper_class(num_particles=problem.num_particles)

    qubit_op = mapper.map(second_q_op)
    
    print("Number of particles:", problem.num_particles)
    print("Number of spatial orbitals:", problem.num_spatial_orbitals)
    print("Number of qubits:", qubit_op.num_qubits)
    print("Number of Paulis:", qubit_op.size)
    
    return qubit_op, problem

#CLASSIC SOLVER - HF Approximation (Pure PySCF)

def HF_approx_energy(mol,basis,method_type,charge=0,spin=0):
    # Define the molecule
    mol = gto.Mole()
    mol.atom = atom_str
    mol.basis = basis
    mol.charge = charge
    mol.spin = spin
    mol.build()

    # Perform HF calculation for relevant method
    if method_type.lower() == "rhf":
        mf = scf.RHF(mol)
    elif method_type.lower() == "uhf":
        mf = scf.UHF(mol)
    elif method_type.lower() == "rohf":
        mf = scf.ROHF(mol)
    else:
        raise ValueError(f"Unsupported method type: {method_type}")
    hf_energy = mf.kernel()

    return hf_energy

# %%
def get_exact_energies(elec_struct_prob): #Works by a classical, naive eigensolver
    numpy_solver = NumPyMinimumEigensolver()

    #TODO: there is a redundant call to get the mapper class here and in get_qubit_op.
    # also here you have to specify the mapping name inside the function
    # This should be passed as an argument to the function

    mapper_classes = {
        "parity": ParityMapper,
        "jordan": JordanWignerMapper,
        "bravi": BravyiKitaevMapper,
    }

    mapping_name = "pairty"  # Default to "parity" if not explicitly provided
    mapper_class = mapper_classes.get(mapping_name)
    if mapper_class is None:
        raise ValueError("Mapper should be one of 'parity', 'jordan', or 'bravi'.")
    
    # If the mapping is "jordan", the mapper does not require additional arguments
    # Otherwise, the mapper requires the number of particles as an argument
    mapper = mapper_class() if mapping_name == "jordan" else mapper_class(num_particles=elec_struct_prob.num_particles)
    
    mapper_class = mapper_classes.get(mapping_name)
    if mapper_class is None:
        print("Mapper should be one of 'parity', 'jordan', or 'bravi'.")
        return None
    
    mapper = mapper_class()
    calc = GroundStateEigensolver(mapper, numpy_solver)
    temp_res = calc.solve(elec_struct_prob)
    return temp_res, temp_res.total_energies[0], temp_res.nuclear_repulsion_energy

#TODO: put here a quantum algorithm for solving the eigenvalues
def quantum_get_exact_energies(elec_struct_prob):
    pass

# %% [markdown]
# ### Matrix Hamiltonians

# %%
def pauli_tensor_product(n, pauli_string):
    # Define Pauli matrices
    pauli_matrices = {
        'I': np.eye(2, dtype=complex),
        'X': np.array([[0, 1], [1, 0]], dtype=complex),
        'Y': np.array([[0, -1j], [1j, 0]], dtype=complex),
        'Z': np.array([[1, 0], [0, -1]], dtype=complex)
    }
    
    # Check if the input string length matches the number of qubits
    if len(pauli_string) != n:
        raise ValueError("Length of Pauli string must match the number of qubits (n).")
    
    # Start with the first matrix
    result = pauli_matrices[pauli_string[0]]
    
    # Perform the tensor product iteratively
    for char in pauli_string[1:]:
        result = np.kron(result, pauli_matrices[char])
    
    return result

def build_H_mat(H_op):
    n = len(H_op.paulis[0])
    num_strings = len(H_op.coeffs)
    H = np.zeros((2**n,2**n),dtype=np.complex128)
    for i in range(num_strings):
        coeff = H_op.coeffs[i]
        pauli = H_op.paulis[i]
        pauli_mat = pauli_tensor_product(n, pauli.to_label())
        H += coeff * pauli_mat 
    return H

def minimal_eigenvalue(matrix):
    # Compute eigenvalues using NumPy
    eigenvalues = np.linalg.eigvalsh(matrix)  # For Hermitian matrices (more efficient)
    return np.min(eigenvalues)

# %% [markdown]
# ### Display Function for second-quanization Hamiltonian

# %% [markdown]
# ## Several configutarions of LiH
#
# The geometry, charge, set of basis elements, and mapping are the same. <br>
# The active space transformers will differ.

# %%
dist = "1.5"
atom_str = f"Li .0 .0 .0; H .0 .0 {dist}"
charge = 0
basis = 'sto6g'
mapping_name = 'parity'

# %% [markdown]
# Below is a demonstration of how HF approximation result has nothing to do with choosing the active space. (i.e HF approx happens before)

# %%
transformer1 = None
transformer2 = ActiveSpaceTransformer(num_electrons=2, num_spatial_orbitals=2)

### Hartree-Fock Approximation
LiH_HF_energy = HF_approx_energy(atom_str, basis, method_type="rhf", charge=charge)
print("HF Energy:", LiH_HF_energy)

### Exact Classical Solver
LiH_qub_default, LiH_es_default = get_qubit_op(atom_str, charge=charge, basis=basis, mapping_name=mapping_name, transformer=None)
LiH_qub_active, LiH_es_active = get_qubit_op(atom_str, charge=charge, basis=basis, mapping_name=mapping_name, transformer=transformer2)

print("Exact Classical Solver - Active Space: Default")
Lih_Default_ElectronicStructureResult, Lih_Default_energy, _ = get_exact_energies(LiH_es_default)
print("Energy default:",Lih_Default_energy)
print("Full details:")
# print(Lih_Default_ElectronicStructureResult)
print('\n \n \n')
print("Exact Classical Solver - Active Space: 2 electrons, 2 orbitals")
Lih_Active_ElectronicStructureResult, Lih_Active_energy, _ = get_exact_energies(LiH_es_active)
print("Energy 2e2o:",Lih_Active_energy)
# print("Full details:")
# print(Lih_Active_ElectronicStructureResult)
# Out:
# converged SCF energy = -7.95346161954278
# HF Energy: -7.953461619542778
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (1, 1)
# Number of spatial orbitals: 2
# Number of qubits: 2
# Number of Paulis: 9
# Exact Classical Solver - Active Space: Default
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 13
#      10 LiH_qub_active, LiH_es_active = get_qubit_op(atom_str, charge=charge, basis=basis, mapping_name=mapping_name, transformer=transformer2)
#      12 print("Exact Classical Solver - Active Space: Default")
# ---> 13 Lih_Default_ElectronicStructureResult, Lih_Default_energy, _ = get_exact_energies(LiH_es_default)
#      14 print("Energy default:",Lih_Default_energy)
#      15 print("Full details:")
#
# Cell In[6], line 17, in get_exact_energies(elec_struct_prob)
#      15 mapper_class = mapper_classes.get(mapping_name)
#      16 if mapper_class is None:
# ---> 17     raise ValueError("Mapper should be one of 'parity', 'jordan', or 'bravi'.")
#      19 # If the mapping is "jordan", the mapper does not require additional arguments
#      20 # Otherwise, the mapper requires the number of particles as an argument
#      21 mapper = mapper_class() if mapping_name == "jordan" else mapper_class(num_particles=elec_struct_prob.num_particles)
#
# ValueError: Mapper should be one of 'parity', 'jordan', or 'bravi'.

# %%
### Checking the initial HF guess ### 


# 1. Define the molecule
mol = gto.Mole()
mol.atom = '''
O  0.000000   0.000000   0.000000
H  0.000000   -0.757000  0.587000
H  0.000000   0.757000   0.587000
'''
mol.basis = 'sto-3g'
mol.spin = 0  # Singlet
mol.charge = 0
mol.build()

# 2. Create a Hartree-Fock object
mf = scf.RHF(mol)

# 3. Get the core Hamiltonian (one-electron part)
hcore = mf.get_hcore()

# 4. Get the overlap matrix
S = mf.get_ovlp()

# 5. Diagonalize core Hamiltonian in AO basis to get initial guess orbitals
e_core, C_core = mf.eig(hcore, S)

# 6. Build the density matrix from occupied orbitals
nocc = mol.nelectron // 2
C_occ = C_core[:, :nocc]
D = np.dot(C_occ, C_occ.T) * 2  # RHF: 2 electrons per orbital

print("Initial orbital energies (core Hamiltonian guess):")
print(e_core[:nocc])
print("\nInitial density matrix (Slater determinant):")
print(D)
# Out:
# Initial orbital energies (core Hamiltonian guess):
# [-32.72107876  -8.30047351  -7.73495708  -7.46547568  -7.45704337]
#
# Initial density matrix (Slater determinant):
# [[ 2.13471815e+00 -6.07707067e-01  5.84777108e-17 -4.57539596e-17
#   -5.65126441e-02  8.65832393e-02  8.65832393e-02]
#  [-6.07707067e-01  2.73409454e+00 -5.70126593e-16  5.96342553e-16
#    3.49279333e-01 -3.86883317e-01 -3.86883317e-01]
#  [ 5.84777108e-17 -5.70126593e-16  2.00000000e+00  6.97363722e-16
#   -4.01021285e-16  2.13181996e-15 -7.42839092e-16]
#  [-4.57539596e-17  5.96342553e-16  6.97363722e-16  2.38715044e+00
#    1.17890940e-15  3.87058215e-01 -3.87058215e-01]
#  [-5.65126441e-02  3.49279333e-01 -4.01021285e-16  1.17890940e-15
#    2.19213008e+00 -2.51767670e-01 -2.51767670e-01]
#  [ 8.65832393e-02 -3.86883317e-01  2.13181996e-15  3.87058215e-01
#   -2.51767670e-01  1.36572408e-01  1.10553397e-02]
#  [ 8.65832393e-02 -3.86883317e-01 -7.42839092e-16 -3.87058215e-01
#   -2.51767670e-01  1.10553397e-02  1.36572408e-01]]

# %%
from pyscf import gto, scf
import numpy as np

# 1. Define LiH molecule
mol = gto.Mole()
mol.atom = '''
Li 0.0 0.0 0.0
H  0.0 0.0 1.6
'''
mol.basis = 'sto-3g'
mol.spin = 0  # Neutral molecule, singlet
mol.charge = 0
mol.build()

# 2. Hartree-Fock object
mf = scf.RHF(mol)

# 3. Core Hamiltonian and overlap
hcore = mf.get_hcore()
S = mf.get_ovlp()

# 4. Diagonalize core Hamiltonian to get initial MOs
e_core, C_core = mf.eig(hcore, S)

# 5. Build density matrix from occupied orbitals
nocc = mol.nelectron // 2
C_occ = C_core[:, :nocc]
D = np.dot(C_occ, C_occ.T) * 2  # RHF: 2 electrons per orbital

print("AO labels:", mol.ao_labels())
print("Initial orbital energies:")
print(e_core[:nocc])
print("\nInitial density matrix D (AO basis):")
print(D)
# Out:
# AO labels: ['0 Li 1s    ', '0 Li 2s    ', '0 Li 2px   ', '0 Li 2py   ', '0 Li 2pz   ', '1 H 1s    ']
# Initial orbital energies:
# [-4.73875146 -1.49893779]
#
# Initial density matrix D (AO basis):
# [[ 2.04514406e+00 -1.13283298e-01 -1.43462910e-16  3.58657275e-17
#   -6.22335904e-02 -1.38221424e-01]
#  [-1.13283298e-01  1.73249372e-01  3.90705278e-16 -9.76763194e-17
#    1.79865895e-01  3.98374037e-01]
#  [-1.43462910e-16  3.90705278e-16  8.87468518e-31 -2.21867130e-31
#    4.08773437e-16  9.05345614e-16]
#  [ 3.58657275e-17 -9.76763194e-17 -2.21867130e-31  5.54667824e-32
#   -1.02193359e-16 -2.26336403e-16]
#  [-6.22335904e-02  1.79865895e-01  4.08773437e-16 -1.02193359e-16
#    1.88290866e-01  4.17023204e-01]
#  [-1.38221424e-01  3.98374037e-01  9.05345614e-16 -2.26336403e-16
#    4.17023204e-01  9.23615525e-01]]

# %% [markdown]
# ### (1) Default settings - 4 electrons and 6 spatial orbitals

# %%
from numpy import linalg
transformer1 = None
LiH_qub_1, LiH_es_1 = get_qubit_op(atom_str, charge, basis, mapping_name, transformer1)
# print('GS energy:',get_exact_energies(LiH_es_1)[1])
# print('GS energy:', minimal_eigenvalue(build_H_mat(LiH_qub_1)))
print(LiH_qub_1)
print(LiH_es_1)
print('Energies:',get_exact_energies(LiH_es_1)[0])
eigenvalues, eigenvectors = linalg.eig(LiH_qub_1.to_matrix())
print(min(eigenvalues).real + LiH_es_1.nuclear_repulsion_energy)
# Out:
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# SparsePauliOp(['IIIIIIIIII', 'IIIIIIIIIZ', 'IIIIIIIIZZ', 'IIIIIIIIZI', 'IIIIIIIZXZ', 'IIIIIIIZXI', 'IIIIIIIIXI', 'IIIIIIIIXZ', 'IIIIIXXXXZ', 'IIIIIXXXXI', 'IIIIIYXXYI', 'IIIIIYXXYZ', 'IIIIIIIZZI', 'IIIIIIIZZZ', 'IIIIIXXXZI', 'IIIIIXXXZZ', 'IIIIIYXYII', 'IIIIIYXYIZ', 'IIIIIIZZII', 'IIIIIIZZIZ', 'IIIIIZZIII', 'IIIIIZZIIZ', 'IIIIIZIIII', 'IIIIIZIIIZ', 'IIIIZIIIII', 'IIIIZIIIIZ', 'IIIZXIIIII', 'IIIZXIIIIZ', 'IIIIXIIIII', 'IIIIXIIIIZ', 'IIZXXIIIII', 'IIZXXIIIIZ', 'IIIYYIIIII', 'IIIYYIIIIZ', 'XXXXXIIIII', 'XXXXXIIIIZ', 'YXXXYIIIII', 'YXXXYIIIIZ', 'IIIZZIIIII', 'IIIZZIIIIZ', 'IIZXZIIIII', 'IIZXZIIIIZ', 'IIIXIIIIII', 'IIIXIIIIIZ', 'XXXXZIIIII', 'XXXXZIIIIZ', 'YXXYIIIIII', 'YXXYIIIIIZ', 'IIZZIIIIII', 'IIZZIIIIIZ', 'XXXZIIIIII', 'XXXZIIIIIZ', 'YXYIIIIIII', 'YXYIIIIIIZ', 'IZZIIIIIII', 'IZZIIIIIIZ', 'ZZIIIIIIII', 'ZZIIIIIIIZ', 'ZIIIIIIIII', 'ZIIIIIIIIZ', 'IIIIIIIZXX', 'IIIIIIIZYY', 'IIIIIIIIYY', 'IIIIIIIIXX', 'IIIIIXXXXX', 'IIIIIXXXYY', 'IIIIIYXXXY', 'IIIIIYXXYX', 'IIIIIIIIZX', 'IIIIIIIZIX', 'IIIIIIIIIX', 'IIIIIIIZZX', 'IIIIIXXXIX', 'IIIIIYXYZX', 'IIIIIXXYIY', 'IIIIIYXXIY', 'IIIIIXXXZX', 'IIIIIYXYIX', 'IIIIIIZZZX', 'IIIIIIZZIX', 'IIIIIZZIZX', 'IIIIIZZIIX', 'IIIIIZIIZX', 'IIIIIZIIIX', 'IIIIZIIIZX', 'IIIIZIIIIX', 'IIIZXIIIZX', 'IIIIXIIIZX', 'IIIZXIIIIX', 'IIIIXIIIIX', 'IIZXXIIIZX', 'IIIYYIIIZX', 'IIZXXIIIIX', 'IIIYYIIIIX', 'XXXXXIIIZX', 'YXXXYIIIZX', 'XXXXXIIIIX', 'YXXXYIIIIX', 'IIIZZIIIZX', 'IIIZZIIIIX', 'IIZXZIIIZX', 'IIIXIIIIZX', 'IIZXZIIIIX', 'IIIXIIIIIX', 'XXXXZIIIZX', 'YXXYIIIIZX', 'XXXXZIIIIX', 'YXXYIIIIIX', 'IIZZIIIIZX', 'IIZZIIIIIX', 'XXXZIIIIZX', 'YXYIIIIIZX', 'XXXZIIIIIX', 'YXYIIIIIIX', 'IZZIIIIIZX', 'IZZIIIIIIX', 'ZZIIIIIIZX', 'ZZIIIIIIIX', 'ZIIIIIIIZX', 'ZIIIIIIIIX', 'IIIIIXXYYX', 'IIIIIYXYYY', 'IIIIIIZIXX', 'IIIIIIZZYY', 'IIIIIZZZXX', 'IIIIIZZIYY', 'IIIIIZIZXX', 'IIIIIZIIYY', 'IIIIZIIZXX', 'IIIIZIIIYY', 'IIIZXIIZXX', 'IIIIXIIZXX', 'IIIZXIIIYY', 'IIIIXIIIYY', 'IIZXXIIZXX', 'IIIYYIIZXX', 'IIZXXIIIYY', 'IIIYYIIIYY', 'XXXXXIIZXX', 'YXXXYIIZXX', 'XXXXXIIIYY', 'YXXXYIIIYY', 'IIIZZIIZXX', 'IIIZZIIIYY', 'IIZXZIIZXX', 'IIIXIIIZXX', 'IIZXZIIIYY', 'IIIXIIIIYY', 'XXXXZIIZXX', 'YXXYIIIZXX', 'XXXXZIIIYY', 'YXXYIIIIYY', 'IIZZIIIZXX', 'IIZZIIIIYY', 'XXXZIIIZXX', 'YXYIIIIZXX', 'XXXZIIIIYY', 'YXYIIIIIYY', 'IZZIIIIZXX', 'IZZIIIIIYY', 'ZZIIIIIZXX', 'ZZIIIIIIYY', 'ZIIIIIIZXX', 'ZIIIIIIIYY', 'IIIIIXYYXX', 'IIIIIYYYXY', 'IZXXXIZXXX', 'IIYXYIZXXX', 'IZXXXIIYXY', 'IIYXYIIYXY', 'IZXXZIZXXX', 'IIYYIIZXXX', 'IZXXZIIYXY', 'IIYYIIIYXY', 'IZXZIIZXXX', 'IIXIIIZXXX', 'IZXZIIIYXY', 'IIXIIIIYXY', 'XXZIIIZXXX', 'YYIIIIZXXX', 'XXZIIIIYXY', 'YYIIIIIYXY', 'IIIIIYYXXX', 'IIIIIXYXXY', 'ZXXXXZXXXX', 'IYXXYZXXXX', 'ZXXXXIYXXY', 'IYXXYIYXXY', 'ZXXXZZXXXX', 'IYXYIZXXXX', 'ZXXXZIYXXY', 'IYXYIIYXXY', 'ZXXZIZXXXX', 'IYYIIZXXXX', 'ZXXZIIYXXY', 'IYYIIIYXXY', 'XZIIIZXXXX', 'XIIIIZXXXX', 'XZIIIIYXXY', 'XIIIIIYXXY', 'IIIIZXXXXX', 'IIIIZYXXXY', 'IIIZXXXXXX', 'IIIIXXXXXX', 'IIIZXYXXXY', 'IIIIXYXXXY', 'IIZXXXXXXX', 'IIIYYXXXXX', 'IIZXXYXXXY', 'IIIYYYXXXY', 'XXXXXXXXXX', 'YXXXYXXXXX', 'XXXXXYXXXY', 'YXXXYYXXXY', 'IIIZZXXXXX', 'IIIZZYXXXY', 'IIZXZXXXXX', 'IIIXIXXXXX', 'IIZXZYXXXY', 'IIIXIYXXXY', 'XXXXZXXXXX', 'YXXYIXXXXX', 'XXXXZYXXXY', 'YXXYIYXXXY', 'IIZZIXXXXX', 'IIZZIYXXXY', 'XXXZIXXXXX', 'YXYIIXXXXX', 'XXXZIYXXXY', 'YXYIIYXXXY', 'IZZIIXXXXX', 'IZZIIYXXXY', 'ZZIIIXXXXX', 'ZZIIIYXXXY', 'ZIIIIXXXXX', 'ZIIIIYXXXY', 'IIIIIIIZIZ', 'IIIIIXXXIZ', 'IIIIIYXYZZ', 'IIIIIIZZZZ', 'IIIIIZZIZZ', 'IIIIIZIIZZ', 'IIIIZIIIZZ', 'IIIZXIIIZZ', 'IIIIXIIIZZ', 'IIZXXIIIZZ', 'IIIYYIIIZZ', 'XXXXXIIIZZ', 'YXXXYIIIZZ', 'IIIZZIIIZZ', 'IIZXZIIIZZ', 'IIIXIIIIZZ', 'XXXXZIIIZZ', 'YXXYIIIIZZ', 'IIZZIIIIZZ', 'XXXZIIIIZZ', 'YXYIIIIIZZ', 'IZZIIIIIZZ', 'ZZIIIIIIZZ', 'ZIIIIIIIZZ', 'IIIIIXXYYZ', 'IIIIIYXYXI', 'IIIIIIZIXZ', 'IIIIIIZZXI', 'IIIIIZZZXZ', 'IIIIIZZIXI', 'IIIIIZIZXZ', 'IIIIIZIIXI', 'IIIIZIIZXZ', 'IIIIZIIIXI', 'IIIZXIIZXZ', 'IIIIXIIZXZ', 'IIIZXIIIXI', 'IIIIXIIIXI', 'IIZXXIIZXZ', 'IIIYYIIZXZ', 'IIZXXIIIXI', 'IIIYYIIIXI', 'XXXXXIIZXZ', 'YXXXYIIZXZ', 'XXXXXIIIXI', 'YXXXYIIIXI', 'IIIZZIIZXZ', 'IIIZZIIIXI', 'IIZXZIIZ ...
#               coeffs=[-5.16194630e+00+0.j,  1.01098699e+00+0.j, -1.14956826e-01+0.j,
#   9.11920195e-02+0.j,  7.74657163e-03+0.j, -2.84445607e-05+0.j,
#  -7.74657163e-03+0.j,  2.84445607e-05+0.j, -6.32922772e-03+0.j,
#  -5.12197880e-03+0.j, -6.32922772e-03+0.j, -5.12197880e-03+0.j,
#  -1.97314472e-01+0.j,  9.36125274e-02+0.j, -1.45387498e-02+0.j,
#   4.66772527e-03+0.j, -1.45387498e-02+0.j,  4.66772527e-03+0.j,
#  -2.28782478e-01+0.j,  9.66222343e-02+0.j, -2.28782478e-01+0.j,
#   9.66222343e-02+0.j, -3.98262912e-01+0.j,  8.86094383e-02+0.j,
#   1.01098699e+00+0.j,  4.14541694e-01+0.j, -1.51805883e-02+0.j,
#  -2.92139812e-02+0.j,  1.51805883e-02+0.j,  2.92139812e-02+0.j,
#  -2.57483498e-02+0.j, -3.44089158e-02+0.j, -2.57483498e-02+0.j,
#  -3.44089158e-02+0.j,  8.84739324e-05+0.j,  1.08552808e-02+0.j,
#   8.84739324e-05+0.j,  1.08552808e-02+0.j, -1.14956826e-01+0.j,
#   9.48664761e-02+0.j,  7.74657163e-03+0.j,  2.85744701e-03+0.j,
#  -7.74657163e-03+0.j, -2.85744701e-03+0.j, -6.32922772e-03+0.j,
#  -7.15626865e-03+0.j, -6.32922772e-03+0.j, -7.15626865e-03+0.j,
#  -1.97314472e-01+0.j,  9.89907657e-02+0.j, -1.45387498e-02+0.j,
#   4.35096707e-03+0.j, -1.45387498e-02+0.j,  4.35096707e-03+0.j,
#  -2.28782478e-01+0.j,  9.90770411e-02+0.j, -2.28782478e-01+0.j,
#   9.90770411e-02+0.j, -3.98262912e-01+0.j,  9.04197487e-02+0.j,
#  -2.57483498e-02+0.j,  3.35767026e-03+0.j, -2.57483498e-02+0.j,
#   3.35767026e-03+0.j,  8.84739324e-05+0.j,  2.93980918e-03+0.j,
#   8.84739324e-05+0.j, -2.93980918e-03+0.j, -1.51805883e-02+0.j,
#  -2.97679166e-03+0.j,  1.51805883e-02+0.j,  2.97679166e-03+0.j,
#  -1.37614616e-03+0.j, -8.82069888e-04+0.j, -4.94076274e-04+0.j,
#  -4.94076274e-04+0.j,  8.82069888e-04+0.j,  1.37614616e-03+0.j,
#  -3.04221054e-03+0.j,  3.04221054e-03+0.j, -3.04221054e-03+0.j,
#   3.04221054e-03+0.j,  9.75427835e-04+0.j, -9.75427835e-04+0.j,
#  -2.92139812e-02+0.j,  2.92139812e-02+0.j,  3.67445654e-03+0.j,
#  -3.67445654e-03+0.j, -3.67445654e-03+0.j,  3.67445654e-03+0.j,
#   2.88589157e-03+0.j,  2.88589157e-03+0.j, -2.88589157e-03+0.j,
#  -2.88589157e-03+0.j, -2.03428984e-03+0.j, -2.03428984e-03+0.j,
#   2.03428984e-03+0.j,  2.03428984e-03+0.j,  1.81359686e-03+0.j,
#  -1.81359686e-03+0.j, -9.14894129e-04+0.j,  9.14894129e-04+0.j,
#   9.14894129e-04+0.j, -9.14894129e-04+0.j,  1.43904503e-03+0.j,
#   1.43904503e-03+0.j, -1.43904503e-03+0.j, -1.43904503e-03+0.j,
#  -2.91833584e-03+0.j,  2.91833584e-03+0.j, -1.06638328e-03+0.j,
#  -1.06638328e-03+0.j,  1.06638328e-03+0.j,  1.06638328e-03+0.j,
#  -1.14806254e-03+0.j,  1.14806254e-03+0.j, -1.14806254e-03+0.j,
#   1.14806254e-03+0.j,  1.08044973e-03+0.j, -1.08044973e-03+0.j,
#  -1.27352322e-03+0.j, -1.27352322e-03+0.j, -3.79578860e-03+0.j,
#  -3.79578860e-03+0.j, -3.79578860e-03+0.j, -3.79578860e-03+0.j,
#  -3.88758013e-03+0.j, -3.88758013e-03+0.j, -3.44089158e-02+0.j,
#  -3.44089158e-02+0.j,  2.88589157e-03+0.j, -2.88589157e-03+0.j,
#   2.88589157e-03+0.j, -2.88589157e-03+0.j,  5.37823834e-03+0.j,
#   5.37823834e-03+0.j,  5.37823834e-03+0.j,  5.37823834e-03+0.j,
#  -3.16758198e-04+0.j, -3.16758198e-04+0.j, -3.16758198e-04+0.j,
#  -3.16758198e-04+0.j, -4.27256439e-03+0.j, -4.27256439e-03+0.j,
#   5.84558276e-05+0.j, -5.84558276e-05+0.j,  5.84558276e-05+0.j,
#  -5.84558276e-05+0.j, -1.84313390e-04+0.j, -1.84313390e-04+0.j,
#  -1.84313390e-04+0.j, -1.84313390e-04+0.j,  5.00175467e-04+0.j,
#   5.00175467e-04+0.j,  1.12608781e-03+0.j,  1.12608781e-03+0.j,
#   1.12608781e-03+0.j,  1.12608781e-03+0.j, -1.23495480e-03+0.j,
#  -1.23495480e-03+0.j, -1.23495480e-03+0.j, -1.23495480e-03+0.j,
#  -2.84190917e-03+0.j, -2.84190917e-03+0.j, -1.54504704e-03+0.j,
#  -1.54504704e-03+0.j,  2.45480683e-03+0.j,  2.45480683e-03+0.j,
#   2.45480683e-03+0.j,  2.45480683e-03+0.j,  1.89414800e-03+0.j,
#   1.89414800e-03+0.j,  1.89414800e-03+0.j,  1.89414800e-03+0.j,
#   2.56083380e-03+0.j, -2.56083380e-03+0.j,  2.56083380e-03+0.j,
#  -2.56083380e-03+0.j, -1.49820424e-03+0.j, -1.49820424e-03+0.j,
#  -1.49820424e-03+0.j, -1.49820424e-03+0.j, -1.54504704e-03+0.j,
#   1.54504704e-03+0.j,  2.45480683e-03+0.j,  2.45480683e-03+0.j,
#   2.45480683e-03+0.j,  2.45480683e-03+0.j,  1.89414800e-03+0.j,
#   1.89414800e-03+0.j,  1.89414800e-03+0.j,  1.89414800e-03+0.j,
#   2.56083380e-03+0.j,  2.56083380e-03+0.j,  2.56083380e-03+0.j,
#   2.56083380e-03+0.j, -1.49820424e-03+0.j,  1.49820424e-03+0.j,
#  -1.49820424e-03+0.j,  1.49820424e-03+0.j,  1.08552808e-02+0.j,
#   1.08552808e-02+0.j, -2.03428984e-03+0.j,  2.03428984e-03+0.j,
#  -2.03428984e-03+0.j,  2.03428984e-03+0.j, -3.16758198e-04+0.j,
#  -3.16758198e-04+0.j, -3.16758198e-04+0.j, -3.16758198e-04+0.j,
#   1.81031043e-03+0.j,  1.81031043e-03+0.j,  1.81031043e-03+0.j,
#   1.81031043e-03+0.j, -1.50076414e-03+0.j, -1.50076414e-03+0.j,
#   3.09762883e-04+0.j, -3.09762883e-04+0.j,  3.09762883e-04+0.j,
#  -3.09762883e-04+0.j,  1.05021900e-04+0.j,  1.05021900e-04+0.j,
#   1.05021900e-04+0.j,  1.05021900e-04+0.j,  2.39961103e-03+0.j,
#   2.39961103e-03+0.j,  1.04567096e-03+0.j,  1.04567096e-03+0.j,
#   1.04567096e-03+0.j,  1.04567096e-03+0.j,  4.68428047e-05+0.j,
#   4.68428047e-05+0.j,  4.68428047e-05+0.j,  4.68428047e-05+0.j,
#  -5.30680404e-04+0.j, -5.30680404e-04+0.j,  5.36214107e-02+0.j,
#  -4.36055257e-03+0.j, -4.36055257e-03+0.j,  6.27887634e-02+0.j,
#   6.27887634e-02+0.j,  8.36012196e-02+0.j,  9.48664761e-02+0.j,
#   1.81359686e-03+0.j, -1.81359686e-03+0.j, -4.27256439e-03+0.j,
#  -4.27256439e-03+0.j, -1.50076414e-03+0.j, -1.50076414e-03+0.j,
#   1.23570872e-01+0.j, -1.17336244e-02+0.j,  1.17336244e-02+0.j,
#   3.30587284e-02+0.j,  3.30587284e-02+0.j,  5.66560678e-02+0.j,
#  -1.27339142e-02+0.j, -1.27339142e-02+0.j,  6.87855243e-02+0.j,
#   6.87855243e-02+0.j,  1.14339547e-01+0.j,  4.47907460e-03+0.j,
#  -4.47907460e-03+0.j, -3.62024877e-03+0.j,  3.62024877e-03+0.j,
#  -3.62024877e-03+0.j,  3.62024877e-03+0.j, -2.77574641e-03+0.j,
#   2.77574641e-03+0.j,  2.85744701e-03+0.j, -2.85744701e-03+0.j,
#  -9.14894129e-04+0.j,  9.14894129e-04+0.j,  9.14894129e-04+0.j,
#  -9.14894129e-04+0.j,  5.84558276e-05+0.j,  5.84558276e-05+0.j,
#  -5.84558276e-05+0.j, -5.84558276e-05+0.j,  3.09762883e-04+0.j,
#   3.09762883e-04+0.j, -3.09762883e-04+0.j, -3.09762883e-04+0.j,
#  -1.17336244e-02+0.j,  1.17336244e-02+0.j,  3.03465702e-03+0.j,
#  -3.03465702e-03+0.j, -3.03465702e-03+0.j,  3.03465702e-03+0.j,
#  -8.37336168e-03+0.j, -8.37336168e-03+0.j,  8.37336168e-03+0.j,
#   8.37336168e-03+0.j,  1.54067023e-03+0.j, -1.54067023e-03+0.j,
#   2.11113789e-03+0.j,  2.11113789e-03+0.j, -2.11113789e-03+0.j,
#  -2.11113789e-03+0.j,  1.18228325e-03+0.j, -1.18228325e-03+0.j,
#   1.18228325e-03+0.j, -1.18228325e-03+0.j, -1.05401878e-02+0.j,
#   1.05401878e-02+0.j, -2.14985767e-03+0.j, -2.14985767e-03+0.j,
#   1.89414800e-03+0.j,  1.89414800e-03+0.j,  1.89414800e-03+0.j,
#   1.89414800e-03+0.j,  5.99676091e-03+0.j,  5.99676091e-03+0.j,
#   5.99676091e-03+0.j,  5.99676091e-03+0.j,  4.80253202e-03+0.j,
#  -4.80253202e-03+0.j,  4.80253202e-03+0.j, -4.80253202e-03+0.j,
#  -4.87974050e-03+0.j, -4.87974050e-03+0.j, -4.87974050e-03+0.j,
#  -4.87974050e-03+0.j, -2.14985767e-03+0.j,  2.14985767e-03+0.j,
#   1.89414800e-03+0.j,  1.89414800e-03+0.j,  1.89414800e-03+0.j,
#   1.89414800e-03+0.j,  5.99676091e-03+0.j,  5.99676091e-03+0.j,
#   5.99676091e-03+0.j,  5.99676091e-03+0.j,  4.80253202e-03+0.j,
#   4.80253202e-03+0.j,  4.80253202e-03+0.j,  4.80253202e-03+0.j,
#  -4.87974050e-03+0.j,  4.87974050e-03+0.j, -4.87974050e-03+0.j,
#   4.87974050e-03+0.j, -7.15626865e-03+0.j, -7.15626865e-03+0.j,
#   1.43904503e-03+0.j, -1.43904503e-03+0.j,  1.43904503e-03+0.j,
#  -1.43904503e-03+0.j, -1.84313390e-04+0.j, -1.84313390e-04+0.j,
#  -1.84313390e-04+0.j, -1.84313390e-04+0.j,  1.05021900e-04+0.j,
#   1.05021900e-04+0.j,  1.05021900e-04+0.j,  1.05021900e-04+0.j,
#   3.30587284e-02+0.j,  3.30587284e-02+0.j, -8.37336168e-03+0.j,
#   8.37336168e-03+0.j, -8.37336168e-03+0.j,  8.37336168e-03+0.j,
#   3.07383271e-02+0.j,  3.07383271e-02+0.j,  3.07383271e-02+0.j,
#   3.07383271e-02+0.j, -2.36793671e-03+0.j, -2.36793671e-03+0.j,
#  -7.76444138e-03+0.j, -7.76444138e-03+0.j, -7.76444138e-03+0.j,
#  -7.76444138e-03+0.j, -2.72988283e-03+0.j, -2.72988283e-03+0.j,
#  -2.72988283e-03+0.j, -2.72988283e-03+0.j,  3.51167703e-02+0.j,
#   3.51167703e-02+0.j,  6.02255014e-02+0.j,  6.02255014e-02+0.j,
#   5.39298608e-02+0.j,  9.89907657e-02+0.j, -2.91833584e-03+0.j,
#   2.91833584e-03+0.j,  5.00175467e-04+0.j,  5.00175467e-04+0.j,
#   2.39961103e-03+0.j,  2.39961103e-03+0.j,  5.66560678e-02+0.j,
#   1.54067023e-03+0.j, -1.54067023e-03+0.j, -2.36793671e-03+0.j,
#  -2.36793671e-03+0.j,  8.47039179e-02+0.j,  9.01204280e-03+0.j,
#   9.01204280e-03+0.j,  7.05543207e-02+0.j,  7.05543207e-02+0.j,
#   6.05056059e-02+0.j, -3.81828119e-03+0.j,  3.81828119e-03+0.j,
#   2.56083380e-03+0.j,  2.56083380e-03+0.j, -2.56083380e-03+0.j,
#  -2.56083380e-03+0.j,  4.80253202e-03+0.j,  4.80253202e-03+0.j,
#  -4.80253202e-03+0.j, -4.80253202e-03+0.j,  1.03288193e-02+0.j,
#  -1.03288193e-02+0.j, -1.03288193e-02+0.j,  1.03288193e-02+0.j,
#  -3.46639181e-03+0.j, -3.46639181e-03+0.j,  3.46639181e-03+0.j,
#   3.46639181e-03+0.j, -3.81828119e-03+0.j,  3.81828119e-03+0.j,
#   2.56083380e-03+0.j,  2.56083380e-03+0.j,  2.56083380e-03+0.j,
#   2.56083380e-03+0.j,  4.80253202e-03+0.j,  4.80253202e-03+0.j,
#   4.80253202e-03+0.j,  4.80253202e-03+0.j,  1.03288193e-02+0.j,
#   1.03288193e-02+0.j,  1.03288193e-02+0.j,  1.03288193e-02+0.j,
#  -3.46639181e-03+0.j,  3.46639181e-03+0.j, -3.46639181e-03+0.j,
#   3.46639181e-03+0.j,  4.35096707e-03+0.j,  4.35096707e-03+0.j,
#  -1.06638328e-03+0.j,  1.06638328e-03+0.j, -1.06638328e-03+0.j,
#   1.06638328e-03+0.j,  1.12608781e-03+0.j,  1.12608781e-03+0.j,
#   1.12608781e-03+0.j,  1.12608781e-03+0.j,  1.04567096e-03+0.j,
#   1.04567096e-03+0.j,  1.04567096e-03+0.j,  1.04567096e-03+0.j,
#  -1.27339142e-02+0.j, -1.27339142e-02+0.j,  2.11113789e-03+0.j,
#  -2.11113789e-03+0.j,  2.11113789e-03+0.j, -2.11113789e-03+0.j,
#  -7.76444138e-03+0.j, -7.76444138e-03+0.j, -7.76444138e-03+0.j,
#  -7.76444138e-03+0.j,  9.01204280e-03+0.j,  9.01204280e-03+0.j,
#   6.57574505e-03+0.j,  6.57574505e-03+0.j,  6.57574505e-03+0.j,
#   6.57574505e-03+0.j,  3.51889374e-04+0.j,  3.51889374e-04+0.j,
#   3.51889374e-04+0.j,  3.51889374e-04+0.j, -1.08894080e-02+0.j,
#  -1.08894080e-02+0.j,  6.55845232e-02+0.j,  6.24551252e-02+0.j,
#   9.90770411e-02+0.j, -1.14806254e-03+0.j,  1.14806254e-03+0.j,
#  -1.23495480e-03+0.j, -1.23495480e-03+0.j,  4.68428047e-05+0.j,
#   4.68428047e-05+0.j,  6.87855243e-02+0.j,  1.18228325e-03+0.j,
#  -1.18228325e-03+0.j, -2.72988283e-03+0.j, -2.72988283e-03+0.j,
#   7.05543207e-02+0.j,  3.51889374e-04+0.j,  3.51889374e-04+0.j,
#   7.82363778e-02+0.j,  6.98018080e-02+0.j,  6.73234278e-02+0.j,
#   4.21728488e-03+0.j, -4.21728488e-03+0.j, -4.21728488e-03+0.j,
#   4.21728488e-03+0.j, -1.49820424e-03+0.j, -1.49820424e-03+0.j,
#  -1.49820424e-03+0.j, -1.49820424e-03+0.j, -4.87974050e-03+0.j,
#  -4.87974050e-03+0.j, -4.87974050e-03+0.j, -4.87974050e-03+0.j,
#  -3.46639181e-03+0.j,  3.46639181e-03+0.j, -3.46639181e-03+0.j,
#   3.46639181e-03+0.j,  4.86830254e-03+0.j,  4.86830254e-03+0.j,
#   4.86830254e-03+0.j,  4.86830254e-03+0.j,  6.24551252e-02+0.j,
#   9.90770411e-02+0.j, -1.14806254e-03+0.j,  1.14806254e-03+0.j,
#  -1.23495480e-03+0.j, -1.23495480e-03+0.j,  4.68428047e-05+0.j,
#   4.68428047e-05+0.j,  6.87855243e-02+0.j,  1.18228325e-03+0.j,
#  -1.18228325e-03+0.j, -2.72988283e-03+0.j, -2.72988283e-03+0.j,
#   7.05543207e-02+0.j,  3.51889374e-04+0.j,  3.51889374e-04+0.j,
#   6.98018080e-02+0.j,  7.82363778e-02+0.j,  6.73234278e-02+0.j,
#  -1.49820424e-03+0.j, -1.49820424e-03+0.j,  1.49820424e-03+0.j,
#   1.49820424e-03+0.j, -4.87974050e-03+0.j, -4.87974050e-03+0.j,
#   4.87974050e-03+0.j,  4.87974050e-03+0.j, -3.46639181e-03+0.j,
#  -3.46639181e-03+0.j,  3.46639181e-03+0.j,  3.46639181e-03+0.j,
#   4.86830254e-03+0.j, -4.86830254e-03+0.j, -4.86830254e-03+0.j,
#   4.86830254e-03+0.j,  9.04197487e-02+0.j,  1.08044973e-03+0.j,
#  -1.08044973e-03+0.j, -2.84190917e-03+0.j, -2.84190917e-03+0.j,
#  -5.30680404e-04+0.j, -5.30680404e-04+0.j,  1.14339547e-01+0.j,
#  -1.05401878e-02+0.j,  1.05401878e-02+0.j,  3.51167703e-02+0.j,
#   3.51167703e-02+0.j,  6.05056059e-02+0.j, -1.08894080e-02+0.j,
#  -1.08894080e-02+0.j,  6.73234278e-02+0.j,  6.73234278e-02+0.j,
#   1.14091635e-01+0.j,  9.11920195e-02+0.j, -2.84445607e-05+0.j,
#   2.84445607e-05+0.j, -5.12197880e-03+0.j, -5.12197880e-03+0.j,
#   9.36125274e-02+0.j,  4.66772527e-03+0.j,  4.66772527e-03+0.j,
#   9.66222343e-02+0.j,  9.66222343e-02+0.j,  8.86094383e-02+0.j,
#   3.35767026e-03+0.j,  3.35767026e-03+0.j,  2.93980918e-03+0.j,
#  -2.93980918e-03+0.j, -2.97679166e-03+0.j,  2.97679166e-03+0.j,
#  -1.37614616e-03+0.j, -8.82069888e-04+0.j, -4.94076274e-04+0.j,
#  -4.94076274e-04+0.j,  8.82069888e-04+0.j,  1.37614616e-03+0.j,
#  -3.04221054e-03+0.j,  3.04221054e-03+0.j, -3.04221054e-03+0.j,
#   3.04221054e-03+0.j,  9.75427835e-04+0.j, -9.75427835e-04+0.j,
#  -1.27352322e-03+0.j, -1.27352322e-03+0.j, -3.79578860e-03+0.j,
#  -3.79578860e-03+0.j, -3.79578860e-03+0.j, -3.79578860e-03+0.j,
#  -3.88758013e-03+0.j, -3.88758013e-03+0.j, -1.54504704e-03+0.j,
#  -1.54504704e-03+0.j, -1.54504704e-03+0.j,  1.54504704e-03+0.j,
#   5.36214107e-02+0.j, -4.36055257e-03+0.j, -4.36055257e-03+0.j,
#   6.27887634e-02+0.j,  6.27887634e-02+0.j,  8.36012196e-02+0.j,
#   4.47907460e-03+0.j, -4.47907460e-03+0.j, -3.62024877e-03+0.j,
#   3.62024877e-03+0.j, -3.62024877e-03+0.j,  3.62024877e-03+0.j,
#  -2.77574641e-03+0.j,  2.77574641e-03+0.j, -2.14985767e-03+0.j,
#  -2.14985767e-03+0.j, -2.14985767e-03+0.j,  2.14985767e-03+0.j,
#   6.02255014e-02+0.j,  6.02255014e-02+0.j,  5.39298608e-02+0.j,
#  -3.81828119e-03+0.j,  3.81828119e-03+0.j, -3.81828119e-03+0.j,
#   3.81828119e-03+0.j,  6.55845232e-02+0.j,  6.24551252e-02+0.j,
#   6.24551252e-02+0.j])
# <qiskit_nature.second_q.problems.electronic_structure_problem.ElectronicStructureProblem object at 0x16a3cfc50>
# Energies: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.940716708639
#   - computed part:      -8.940716708639
# ~ Nuclear repulsion energy (Hartree): 1.05835442184
# > Total ground state energy (Hartree): -7.882362286799
#
# === MEASURED OBSERVABLES ===
#
#   0:  # Particles: 4.000 S: 0.000 S^2: 0.000 M: 0.000
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [0.0  0.0  2.83458919]
#
#   0:
#   * Electronic dipole moment (a.u.): [0.0  0.0  4.65747064783]
#     - computed part:      [0.0  0.0  4.65747064783]
#   > Dipole moment (a.u.): [0.0  0.0  -1.82288145783]  Total: 1.82288145783
#                  (debye): [0.0  0.0  -4.6333020751]  Total: 4.6333020751
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 9
#       7 print(LiH_es_1)
#       8 print('Energies:',get_exact_energies(LiH_es_1)[0])
# ----> 9 eigenvalues, eigenvectors = linalg.eig(LiH_qub_1.to_matrix())
#      10 print(min(eigenvalues).real + LiH_es_1.nuclear_repulsion_energy)
#
# File ~/Documents/GitHub/MUBs-Quantinion/.venv/lib/python3.12/site-packages/numpy/linalg/linalg.py:1335, in eig(a)
#    1332 extobj = get_linalg_error_extobj(
#    1333     _raise_linalgerror_eigenvalues_nonconvergence)
#    1334 signature = 'D->DD' if isComplexType(t) else 'd->DD'
# -> 1335 w, vt = _umath_linalg.eig(a, signature=signature, extobj=extobj)
#    1337 if not isComplexType(t) and all(w.imag == 0.0):
#    1338     w = w.real
#
# KeyboardInterrupt:

# %% [markdown]
# ### (2) Active space: 2 electrons, 2 spatial orbitals

# %%
transformer2 = ActiveSpaceTransformer(num_electrons=2, num_spatial_orbitals=2)
LiH_qub_2, LiH_es_2 = get_qubit_op(atom_str, charge, basis, mapping_name, transformer2)
print('GS energy:', minimal_eigenvalue(build_H_mat(LiH_qub_2)))
# print('GS energy:',get_exact_energies(LiH_es_2)[1])
print(LiH_qub_2)
print(LiH_es_2.hamiltonian.second_q_op())
print('Energies:',get_exact_energies(LiH_es_1)[0])

print('Energies:',get_exact_energies(LiH_es_2))
# Out:
# Number of particles: (1, 1)
# Number of spatial orbitals: 2
# Number of qubits: 2
# Number of Paulis: 9
# GS energy: -1.0816281947228512
# SparsePauliOp(['II', 'IZ', 'ZI', 'ZZ', 'XI', 'XZ', 'IX', 'ZX', 'XX'],
#               coeffs=[-0.8283753 +0.j,  0.17399667+0.j, -0.17399667+0.j, -0.09496265+0.j,
#   0.02654859+0.j,  0.02654859+0.j,  0.02654859+0.j, -0.02654859+0.j,
#   0.01213863+0.j])
# Fermionic Operator
# number spin orbitals=4, number terms=72
#   0.2471417439972668 * ( +_0 +_0 -_0 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_1 -_0 )
# + -0.023467248713444976 * ( +_0 +_1 -_0 -_0 )
# + 0.11331213551045112 * ( +_0 +_1 -_1 -_0 )
# + 0.2471417439972668 * ( +_0 +_2 -_2 -_0 )
# + -0.023467248713444976 * ( +_0 +_2 -_3 -_0 )
# + -0.023467248713444976 * ( +_0 +_3 -_2 -_0 )
# + 0.11331213551045112 * ( +_0 +_3 -_3 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_0 -_1 )
# + 0.006069314048326776 * ( +_0 +_0 -_1 -_1 )
# + 0.006069314048326776 * ( +_0 +_1 -_0 -_1 )
# + 0.0030813404613908996 * ( +_0 +_1 -_1 -_1 )
# + -0.023467248713444976 * ( +_0 +_2 -_2 -_1 )
# + 0.006069314048326776 * ( +_0 +_2 -_3 -_1 )
# + 0.006069314048326776 * ( +_0 +_3 -_2 -_1 )
# + 0.0030813404613908996 * ( +_0 +_3 -_3 -_1 )
# + -0.023467248713444976 * ( +_1 +_0 -_0 -_0 )
# + 0.006069314048326776 * ( +_1 +_0 -_1 -_0 )
# + 0.006069314048326776 * ( +_1 +_1 -_0 -_0 )
# + 0.0030813404613908996 * ( +_1 +_1 -_1 -_0 )
# + -0.023467248713444976 * ( +_1 +_2 -_2 -_0 )
# + 0.006069314048326776 * ( +_1 +_2 -_3 -_0 )
# + 0.006069314048326776 * ( +_1 +_3 -_2 -_0 )
# + 0.0030813404613908996 * ( +_1 +_3 -_3 -_0 )
# + 0.11331213551045112 * ( +_1 +_0 -_0 -_1 )
# + 0.0030813404613908996 * ( +_1 +_0 -_1 -_1 )
# + 0.0030813404613908996 * ( +_1 +_1 -_0 -_1 )
# + 0.1694078358672006 * ( +_1 +_1 -_1 -_1 )
# + 0.11331213551045112 * ( +_1 +_2 -_2 -_1 )
# + 0.0030813404613908996 * ( +_1 +_2 -_3 -_1 )
# + 0.0030813404613908996 * ( +_1 +_3 -_2 -_1 )
# + 0.1694078358672006 * ( +_1 +_3 -_3 -_1 )
# + 0.2471417439972668 * ( +_2 +_0 -_0 -_2 )
# + -0.023467248713444976 * ( +_2 +_0 -_1 -_2 )
# + -0.023467248713444976 * ( +_2 +_1 -_0 -_2 )
# + 0.11331213551045112 * ( +_2 +_1 -_1 -_2 )
# + 0.2471417439972668 * ( +_2 +_2 -_2 -_2 )
# + -0.023467248713444976 * ( +_2 +_2 -_3 -_2 )
# + -0.023467248713444976 * ( +_2 +_3 -_2 -_2 )
# + 0.11331213551045112 * ( +_2 +_3 -_3 -_2 )
# + -0.023467248713444976 * ( +_2 +_0 -_0 -_3 )
# + 0.006069314048326776 * ( +_2 +_0 -_1 -_3 )
# + 0.006069314048326776 * ( +_2 +_1 -_0 -_3 )
# + 0.0030813404613908996 * ( +_2 +_1 -_1 -_3 )
# + -0.023467248713444976 * ( +_2 +_2 -_2 -_3 )
# + 0.006069314048326776 * ( +_2 +_2 -_3 -_3 )
# + 0.006069314048326776 * ( +_2 +_3 -_2 -_3 )
# + 0.0030813404613908996 * ( +_2 +_3 -_3 -_3 )
# + -0.023467248713444976 * ( +_3 +_0 -_0 -_2 )
# + 0.006069314048326776 * ( +_3 +_0 -_1 -_2 )
# + 0.006069314048326776 * ( +_3 +_1 -_0 -_2 )
# + 0.0030813404613908996 * ( +_3 +_1 -_1 -_2 )
# + -0.023467248713444976 * ( +_3 +_2 -_2 -_2 )
# + 0.006069314048326776 * ( +_3 +_2 -_3 -_2 )
# + 0.006069314048326776 * ( +_3 +_3 -_2 -_2 )
# + 0.0030813404613908996 * ( +_3 +_3 -_3 -_2 )
# + 0.11331213551045112 * ( +_3 +_0 -_0 -_3 )
# + 0.0030813404613908996 * ( +_3 +_0 -_1 -_3 )
# + 0.0030813404613908996 * ( +_3 +_1 -_0 -_3 )
# + 0.1694078358672006 * ( +_3 +_1 -_1 -_3 )
# + 0.11331213551045112 * ( +_3 +_2 -_2 -_3 )
# + 0.0030813404613908996 * ( +_3 +_2 -_3 -_3 )
# + 0.0030813404613908996 * ( +_3 +_3 -_2 -_3 )
# + 0.1694078358672006 * ( +_3 +_3 -_3 -_3 )
# + -0.7878447412876952 * ( +_0 -_0 )
# + 0.04693450040873902 * ( +_0 -_1 )
# + 0.04693450040873909 * ( +_1 -_0 )
# + -0.36211748527673676 * ( +_1 -_1 )
# + -0.7878447412876952 * ( +_2 -_2 )
# + 0.04693450040873902 * ( +_2 -_3 )
# + 0.04693450040873909 * ( +_3 -_2 )
# + -0.36211748527673676 * ( +_3 -_3 )
# Energies: === GROUND STATE ENERGY ===
#
# * Electronic ground state energy (Hartree): -8.940716708639
#   - computed part:      -8.940716708639
# ~ Nuclear repulsion energy (Hartree): 1.05835442184
# > Total ground state energy (Hartree): -7.882362286799
#
# === MEASURED OBSERVABLES ===
#
#   0:  # Particles: 4.000 S: 0.000 S^2: 0.000 M: 0.000
#
# === DIPOLE MOMENTS ===
#
# ~ Nuclear dipole moment (a.u.): [0.0  0.0  2.83458919]
#
#   0:
#   * Electronic dipole moment (a.u.): [0.0  0.0  4.65747064783]
#     - computed part:      [0.0  0.0  4.65747064783]
#   > Dipole moment (a.u.): [0.0  0.0  -1.82288145783]  Total: 1.82288145783
#                  (debye): [0.0  0.0  -4.6333020751]  Total: 4.6333020751
#
# Energies: (<qiskit_nature.second_q.problems.electronic_structure_result.ElectronicStructureResult object at 0x126dc47a0>, -7.863579821677109, 1.05835442184)

# %% [markdown]
# ### (3) LiH with active orbitals 1,2 (out of 0,1,2,3)

# %%
transformer3 = ActiveSpaceTransformer(num_electrons=2, num_spatial_orbitals=2, active_orbitals=[1,2])
LiH_qub_3, LiH_es_3 = get_qubit_op(atom_str, charge, basis, mapping_name, transformer3)
print('GS energy:',get_exact_energies(LiH_es_3)[1])
print(LiH_qub_3)
print(LiH_es_3.hamiltonian.second_q_op())
# Out:
# Number of particles: (1, 1)
# Number of spatial orbitals: 2
# Number of qubits: 2
# Number of Paulis: 9
# GS energy: -7.863579821677111
# SparsePauliOp(['II', 'IZ', 'ZI', 'ZZ', 'XI', 'XZ', 'IX', 'ZX', 'XX'],
#               coeffs=[-0.8283753 +0.j,  0.17399667+0.j, -0.17399667+0.j, -0.09496265+0.j,
#   0.02654859+0.j,  0.02654859+0.j,  0.02654859+0.j, -0.02654859+0.j,
#   0.01213863+0.j])
# Fermionic Operator
# number spin orbitals=4, number terms=72
#   0.2471417439972668 * ( +_0 +_0 -_0 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_1 -_0 )
# + -0.023467248713444976 * ( +_0 +_1 -_0 -_0 )
# + 0.11331213551045112 * ( +_0 +_1 -_1 -_0 )
# + 0.2471417439972668 * ( +_0 +_2 -_2 -_0 )
# + -0.023467248713444976 * ( +_0 +_2 -_3 -_0 )
# + -0.023467248713444976 * ( +_0 +_3 -_2 -_0 )
# + 0.11331213551045112 * ( +_0 +_3 -_3 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_0 -_1 )
# + 0.006069314048326776 * ( +_0 +_0 -_1 -_1 )
# + 0.006069314048326776 * ( +_0 +_1 -_0 -_1 )
# + 0.0030813404613908996 * ( +_0 +_1 -_1 -_1 )
# + -0.023467248713444976 * ( +_0 +_2 -_2 -_1 )
# + 0.006069314048326776 * ( +_0 +_2 -_3 -_1 )
# + 0.006069314048326776 * ( +_0 +_3 -_2 -_1 )
# + 0.0030813404613908996 * ( +_0 +_3 -_3 -_1 )
# + -0.023467248713444976 * ( +_1 +_0 -_0 -_0 )
# + 0.006069314048326776 * ( +_1 +_0 -_1 -_0 )
# + 0.006069314048326776 * ( +_1 +_1 -_0 -_0 )
# + 0.0030813404613908996 * ( +_1 +_1 -_1 -_0 )
# + -0.023467248713444976 * ( +_1 +_2 -_2 -_0 )
# + 0.006069314048326776 * ( +_1 +_2 -_3 -_0 )
# + 0.006069314048326776 * ( +_1 +_3 -_2 -_0 )
# + 0.0030813404613908996 * ( +_1 +_3 -_3 -_0 )
# + 0.11331213551045112 * ( +_1 +_0 -_0 -_1 )
# + 0.0030813404613908996 * ( +_1 +_0 -_1 -_1 )
# + 0.0030813404613908996 * ( +_1 +_1 -_0 -_1 )
# + 0.1694078358672006 * ( +_1 +_1 -_1 -_1 )
# + 0.11331213551045112 * ( +_1 +_2 -_2 -_1 )
# + 0.0030813404613908996 * ( +_1 +_2 -_3 -_1 )
# + 0.0030813404613908996 * ( +_1 +_3 -_2 -_1 )
# + 0.1694078358672006 * ( +_1 +_3 -_3 -_1 )
# + 0.2471417439972668 * ( +_2 +_0 -_0 -_2 )
# + -0.023467248713444976 * ( +_2 +_0 -_1 -_2 )
# + -0.023467248713444976 * ( +_2 +_1 -_0 -_2 )
# + 0.11331213551045112 * ( +_2 +_1 -_1 -_2 )
# + 0.2471417439972668 * ( +_2 +_2 -_2 -_2 )
# + -0.023467248713444976 * ( +_2 +_2 -_3 -_2 )
# + -0.023467248713444976 * ( +_2 +_3 -_2 -_2 )
# + 0.11331213551045112 * ( +_2 +_3 -_3 -_2 )
# + -0.023467248713444976 * ( +_2 +_0 -_0 -_3 )
# + 0.006069314048326776 * ( +_2 +_0 -_1 -_3 )
# + 0.006069314048326776 * ( +_2 +_1 -_0 -_3 )
# + 0.0030813404613908996 * ( +_2 +_1 -_1 -_3 )
# + -0.023467248713444976 * ( +_2 +_2 -_2 -_3 )
# + 0.006069314048326776 * ( +_2 +_2 -_3 -_3 )
# + 0.006069314048326776 * ( +_2 +_3 -_2 -_3 )
# + 0.0030813404613908996 * ( +_2 +_3 -_3 -_3 )
# + -0.023467248713444976 * ( +_3 +_0 -_0 -_2 )
# + 0.006069314048326776 * ( +_3 +_0 -_1 -_2 )
# + 0.006069314048326776 * ( +_3 +_1 -_0 -_2 )
# + 0.0030813404613908996 * ( +_3 +_1 -_1 -_2 )
# + -0.023467248713444976 * ( +_3 +_2 -_2 -_2 )
# + 0.006069314048326776 * ( +_3 +_2 -_3 -_2 )
# + 0.006069314048326776 * ( +_3 +_3 -_2 -_2 )
# + 0.0030813404613908996 * ( +_3 +_3 -_3 -_2 )
# + 0.11331213551045112 * ( +_3 +_0 -_0 -_3 )
# + 0.0030813404613908996 * ( +_3 +_0 -_1 -_3 )
# + 0.0030813404613908996 * ( +_3 +_1 -_0 -_3 )
# + 0.1694078358672006 * ( +_3 +_1 -_1 -_3 )
# + 0.11331213551045112 * ( +_3 +_2 -_2 -_3 )
# + 0.0030813404613908996 * ( +_3 +_2 -_3 -_3 )
# + 0.0030813404613908996 * ( +_3 +_3 -_2 -_3 )
# + 0.1694078358672006 * ( +_3 +_3 -_3 -_3 )
# + -0.7878447412876952 * ( +_0 -_0 )
# + 0.04693450040873902 * ( +_0 -_1 )
# + 0.04693450040873909 * ( +_1 -_0 )
# + -0.36211748527673676 * ( +_1 -_1 )
# + -0.7878447412876952 * ( +_2 -_2 )
# + 0.04693450040873902 * ( +_2 -_3 )
# + 0.04693450040873909 * ( +_3 -_2 )
# + -0.36211748527673676 * ( +_3 -_3 )

# %% [markdown]
# ### (4) Active space: 2 electrons, 2 spatial orbitals

# %%
transformer4 = ActiveSpaceTransformer(num_electrons=2, num_spatial_orbitals=3)
LiH_qub_4, LiH_es_4 = get_qubit_op(atom_str, charge, basis, mapping_name, transformer4)
print('GS energy:',get_exact_energies(LiH_es_4)[1])
print(LiH_qub_4)
print(LiH_es_4.hamiltonian.second_q_op())
# Out:
# Number of particles: (1, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# GS energy: -7.864406764937365
# SparsePauliOp(['IIII', 'IIIZ', 'IIZZ', 'IIZI', 'IZII', 'IZIZ', 'ZXII', 'ZXIZ', 'IXII', 'IXIZ', 'ZZII', 'ZZIZ', 'ZIII', 'ZIIZ', 'IIZX', 'IIIX', 'IZZX', 'IZIX', 'ZXZX', 'IXZX', 'ZXIX', 'IXIX', 'ZZZX', 'ZZIX', 'ZIZX', 'ZIIX', 'XXXX', 'YYXX', 'XXYY', 'YYYY', 'XZXX', 'XIXX', 'XZYY', 'XIYY', 'IZZZ', 'ZXZZ', 'IXZZ', 'ZZZZ', 'ZIZZ', 'XXXZ', 'YYXZ', 'XXXI', 'YYXI', 'XZXZ', 'XIXZ', 'XZXI', 'XIXI', 'IZZI', 'ZXZI', 'IXZI', 'ZZZI', 'ZIZI'],
#               coeffs=[-0.48073512+0.j, -0.03172577+0.j, -0.20749124+0.j,  0.21293828+0.j,
#   0.03172577+0.j, -0.12357087+0.j,  0.01445658+0.j,  0.01173362+0.j,
#   0.01445658+0.j,  0.01173362+0.j, -0.20749124+0.j,  0.05665607+0.j,
#  -0.21293828+0.j,  0.06878552+0.j, -0.01445658+0.j,  0.01445658+0.j,
#   0.01173362+0.j, -0.01173362+0.j, -0.00303466+0.j, -0.00303466+0.j,
#   0.00303466+0.j,  0.00303466+0.j,  0.00154067+0.j, -0.00154067+0.j,
#   0.00118228+0.j, -0.00118228+0.j,  0.00599676+0.j, -0.00599676+0.j,
#  -0.00599676+0.j,  0.00599676+0.j, -0.00480253+0.j,  0.00480253+0.j,
#   0.00480253+0.j, -0.00480253+0.j, -0.05665607+0.j, -0.00154067+0.j,
#  -0.00154067+0.j,  0.08470392+0.j,  0.07055432+0.j,  0.00480253+0.j,
#  -0.00480253+0.j,  0.00480253+0.j, -0.00480253+0.j, -0.01032882+0.j,
#   0.01032882+0.j, -0.01032882+0.j,  0.01032882+0.j,  0.06878552+0.j,
#   0.00118228+0.j,  0.00118228+0.j, -0.07055432+0.j, -0.07823638+0.j])
# Fermionic Operator
# number spin orbitals=6, number terms=174
#   0.2471417439972668 * ( +_0 +_0 -_0 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_1 -_0 )
# + -0.023467248713444976 * ( +_0 +_1 -_0 -_0 )
# + 0.11331213551045112 * ( +_0 +_1 -_1 -_0 )
# + 0.13757104859501695 * ( +_0 +_2 -_2 -_0 )
# + 0.2471417439972668 * ( +_0 +_3 -_3 -_0 )
# + -0.023467248713444976 * ( +_0 +_3 -_4 -_0 )
# + -0.023467248713444976 * ( +_0 +_4 -_3 -_0 )
# + 0.11331213551045112 * ( +_0 +_4 -_4 -_0 )
# + 0.13757104859501695 * ( +_0 +_5 -_5 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_0 -_1 )
# + 0.006069314048326776 * ( +_0 +_0 -_1 -_1 )
# + 0.006069314048326776 * ( +_0 +_1 -_0 -_1 )
# + 0.0030813404613908996 * ( +_0 +_1 -_1 -_1 )
# + 0.002364566495216859 * ( +_0 +_2 -_2 -_1 )
# + -0.023467248713444976 * ( +_0 +_3 -_3 -_1 )
# + 0.006069314048326776 * ( +_0 +_3 -_4 -_1 )
# + 0.006069314048326776 * ( +_0 +_4 -_3 -_1 )
# + 0.0030813404613908996 * ( +_0 +_4 -_4 -_1 )
# + 0.002364566495216859 * ( +_0 +_5 -_5 -_1 )
# + 0.011993521814801497 * ( +_0 +_0 -_2 -_2 )
# + 0.009605064042949077 * ( +_0 +_1 -_2 -_2 )
# + 0.011993521814801497 * ( +_0 +_2 -_0 -_2 )
# + 0.009605064042949077 * ( +_0 +_2 -_1 -_2 )
# + 0.011993521814801497 * ( +_0 +_3 -_5 -_2 )
# + 0.009605064042949077 * ( +_0 +_4 -_5 -_2 )
# + 0.011993521814801497 * ( +_0 +_5 -_3 -_2 )
# + 0.009605064042949077 * ( +_0 +_5 -_4 -_2 )
# + -0.023467248713444976 * ( +_1 +_0 -_0 -_0 )
# + 0.006069314048326776 * ( +_1 +_0 -_1 -_0 )
# + 0.006069314048326776 * ( +_1 +_1 -_0 -_0 )
# + 0.0030813404613908996 * ( +_1 +_1 -_1 -_0 )
# + 0.002364566495216859 * ( +_1 +_2 -_2 -_0 )
# + -0.023467248713444976 * ( +_1 +_3 -_3 -_0 )
# + 0.006069314048326776 * ( +_1 +_3 -_4 -_0 )
# + 0.006069314048326776 * ( +_1 +_4 -_3 -_0 )
# + 0.0030813404613908996 * ( +_1 +_4 -_4 -_0 )
# + 0.002364566495216859 * ( +_1 +_5 -_5 -_0 )
# + 0.11331213551045112 * ( +_1 +_0 -_0 -_1 )
# + 0.0030813404613908996 * ( +_1 +_0 -_1 -_1 )
# + 0.0030813404613908996 * ( +_1 +_1 -_0 -_1 )
# + 0.1694078358672006 * ( +_1 +_1 -_1 -_1 )
# + 0.14110864141142704 * ( +_1 +_2 -_2 -_1 )
# + 0.11331213551045112 * ( +_1 +_3 -_3 -_1 )
# + 0.0030813404613908996 * ( +_1 +_3 -_4 -_1 )
# + 0.0030813404613908996 * ( +_1 +_4 -_3 -_1 )
# + 0.1694078358672006 * ( +_1 +_4 -_4 -_1 )
# + 0.14110864141142704 * ( +_1 +_5 -_5 -_1 )
# + 0.009605064042949077 * ( +_1 +_0 -_2 -_2 )
# + 0.02065763854136733 * ( +_1 +_1 -_2 -_2 )
# + 0.009605064042949077 * ( +_1 +_2 -_0 -_2 )
# + 0.02065763854136733 * ( +_1 +_2 -_1 -_2 )
# + 0.009605064042949077 * ( +_1 +_3 -_5 -_2 )
# + 0.02065763854136733 * ( +_1 +_4 -_5 -_2 )
# + 0.009605064042949077 * ( +_1 +_5 -_3 -_2 )
# + 0.02065763854136733 * ( +_1 +_5 -_4 -_2 )
# + 0.011993521814801497 * ( +_2 +_0 -_2 -_0 )
# + 0.009605064042949077 * ( +_2 +_1 -_2 -_0 )
# + 0.011993521814801497 * ( +_2 +_2 -_0 -_0 )
# + 0.009605064042949077 * ( +_2 +_2 -_1 -_0 )
# + 0.011993521814801497 * ( +_2 +_3 -_5 -_0 )
# + 0.009605064042949077 * ( +_2 +_4 -_5 -_0 )
# + 0.011993521814801497 * ( +_2 +_5 -_3 -_0 )
# + 0.009605064042949077 * ( +_2 +_5 -_4 -_0 )
# + 0.009605064042949077 * ( +_2 +_0 -_2 -_1 )
# + 0.02065763854136733 * ( +_2 +_1 -_2 -_1 )
# + 0.009605064042949077 * ( +_2 +_2 -_0 -_1 )
# + 0.02065763854136733 * ( +_2 +_2 -_1 -_1 )
# + 0.009605064042949077 * ( +_2 +_3 -_5 -_1 )
# + 0.02065763854136733 * ( +_2 +_4 -_5 -_1 )
# + 0.009605064042949077 * ( +_2 +_5 -_3 -_1 )
# + 0.02065763854136733 * ( +_2 +_5 -_4 -_1 )
# + 0.13757104859501695 * ( +_2 +_0 -_0 -_2 )
# + 0.002364566495216859 * ( +_2 +_0 -_1 -_2 )
# + 0.002364566495216859 * ( +_2 +_1 -_0 -_2 )
# + 0.14110864141142704 * ( +_2 +_1 -_1 -_2 )
# + 0.15647275557970478 * ( +_2 +_2 -_2 -_2 )
# + 0.13757104859501695 * ( +_2 +_3 -_3 -_2 )
# + 0.002364566495216859 * ( +_2 +_3 -_4 -_2 )
# + 0.002364566495216859 * ( +_2 +_4 -_3 -_2 )
# + 0.14110864141142704 * ( +_2 +_4 -_4 -_2 )
# + 0.15647275557970478 * ( +_2 +_5 -_5 -_2 )
# + 0.2471417439972668 * ( +_3 +_0 -_0 -_3 )
# + -0.023467248713444976 * ( +_3 +_0 -_1 -_3 )
# + -0.023467248713444976 * ( +_3 +_1 -_0 -_3 )
# + 0.11331213551045112 * ( +_3 +_1 -_1 -_3 )
# + 0.13757104859501695 * ( +_3 +_2 -_2 -_3 )
# + 0.2471417439972668 * ( +_3 +_3 -_3 -_3 )
# + -0.023467248713444976 * ( +_3 +_3 -_4 -_3 )
# + -0.023467248713444976 * ( +_3 +_4 -_3 -_3 )
# + 0.11331213551045112 * ( +_3 +_4 -_4 -_3 )
# + 0.13757104859501695 * ( +_3 +_5 -_5 -_3 )
# + -0.023467248713444976 * ( +_3 +_0 -_0 -_4 )
# + 0.006069314048326776 * ( +_3 +_0 -_1 -_4 )
# + 0.006069314048326776 * ( +_3 +_1 -_0 -_4 )
# + 0.0030813404613908996 * ( +_3 +_1 -_1 -_4 )
# + 0.002364566495216859 * ( +_3 +_2 -_2 -_4 )
# + -0.023467248713444976 * ( +_3 +_3 -_3 -_4 )
# + 0.006069314048326776 * ( +_3 +_3 -_4 -_4 )
# + 0.006069314048326776 * ( +_3 +_4 -_3 -_4 )
# + 0.0030813404613908996 * ( +_3 +_4 -_4 -_4 )
# + 0.002364566495216859 * ( +_3 +_5 -_5 -_4 )
# + 0.011993521814801497 * ( +_3 +_0 -_2 -_5 )
# + 0.009605064042949077 * ( +_3 +_1 -_2 -_5 )
# + 0.011993521814801497 * ( +_3 +_2 -_0 -_5 )
# + 0.009605064042949077 * ( +_3 +_2 -_1 -_5 )
# + 0.011993521814801497 * ( +_3 +_3 -_5 -_5 )
# + 0.009605064042949077 * ( +_3 +_4 -_5 -_5 )
# + 0.011993521814801497 * ( +_3 +_5 -_3 -_5 )
# + 0.009605064042949077 * ( +_3 +_5 -_4 -_5 )
# + -0.023467248713444976 * ( +_4 +_0 -_0 -_3 )
# + 0.006069314048326776 * ( +_4 +_0 -_1 -_3 )
# + 0.006069314048326776 * ( +_4 +_1 -_0 -_3 )
# + 0.0030813404613908996 * ( +_4 +_1 -_1 -_3 )
# + 0.002364566495216859 * ( +_4 +_2 -_2 -_3 )
# + -0.023467248713444976 * ( +_4 +_3 -_3 -_3 )
# + 0.006069314048326776 * ( +_4 +_3 -_4 -_3 )
# + 0.006069314048326776 * ( +_4 +_4 -_3 -_3 )
# + 0.0030813404613908996 * ( +_4 +_4 -_4 -_3 )
# + 0.002364566495216859 * ( +_4 +_5 -_5 -_3 )
# + 0.11331213551045112 * ( +_4 +_0 -_0 -_4 )
# + 0.0030813404613908996 * ( +_4 +_0 -_1 -_4 )
# + 0.0030813404613908996 * ( +_4 +_1 -_0 -_4 )
# + 0.1694078358672006 * ( +_4 +_1 -_1 -_4 )
# + 0.14110864141142704 * ( +_4 +_2 -_2 -_4 )
# + 0.11331213551045112 * ( +_4 +_3 -_3 -_4 )
# + 0.0030813404613908996 * ( +_4 +_3 -_4 -_4 )
# + 0.0030813404613908996 * ( +_4 +_4 -_3 -_4 )
# + 0.1694078358672006 * ( +_4 +_4 -_4 -_4 )
# + 0.14110864141142704 * ( +_4 +_5 -_5 -_4 )
# + 0.009605064042949077 * ( +_4 +_0 -_2 -_5 )
# + 0.02065763854136733 * ( +_4 +_1 -_2 -_5 )
# + 0.009605064042949077 * ( +_4 +_2 -_0 -_5 )
# + 0.02065763854136733 * ( +_4 +_2 -_1 -_5 )
# + 0.009605064042949077 * ( +_4 +_3 -_5 -_5 )
# + 0.02065763854136733 * ( +_4 +_4 -_5 -_5 )
# + 0.009605064042949077 * ( +_4 +_5 -_3 -_5 )
# + 0.02065763854136733 * ( +_4 +_5 -_4 -_5 )
# + 0.011993521814801497 * ( +_5 +_0 -_2 -_3 )
# + 0.009605064042949077 * ( +_5 +_1 -_2 -_3 )
# + 0.011993521814801497 * ( +_5 +_2 -_0 -_3 )
# + 0.009605064042949077 * ( +_5 +_2 -_1 -_3 )
# + 0.011993521814801497 * ( +_5 +_3 -_5 -_3 )
# + 0.009605064042949077 * ( +_5 +_4 -_5 -_3 )
# + 0.011993521814801497 * ( +_5 +_5 -_3 -_3 )
# + 0.009605064042949077 * ( +_5 +_5 -_4 -_3 )
# + 0.009605064042949077 * ( +_5 +_0 -_2 -_4 )
# + 0.02065763854136733 * ( +_5 +_1 -_2 -_4 )
# + 0.009605064042949077 * ( +_5 +_2 -_0 -_4 )
# + 0.02065763854136733 * ( +_5 +_2 -_1 -_4 )
# + 0.009605064042949077 * ( +_5 +_3 -_5 -_4 )
# + 0.02065763854136733 * ( +_5 +_4 -_5 -_4 )
# + 0.009605064042949077 * ( +_5 +_5 -_3 -_4 )
# + 0.02065763854136733 * ( +_5 +_5 -_4 -_4 )
# + 0.13757104859501695 * ( +_5 +_0 -_0 -_5 )
# + 0.002364566495216859 * ( +_5 +_0 -_1 -_5 )
# + 0.002364566495216859 * ( +_5 +_1 -_0 -_5 )
# + 0.14110864141142704 * ( +_5 +_1 -_1 -_5 )
# + 0.15647275557970478 * ( +_5 +_2 -_2 -_5 )
# + 0.13757104859501695 * ( +_5 +_3 -_3 -_5 )
# + 0.002364566495216859 * ( +_5 +_3 -_4 -_5 )
# + 0.002364566495216859 * ( +_5 +_4 -_3 -_5 )
# + 0.14110864141142704 * ( +_5 +_4 -_4 -_5 )
# + 0.15647275557970478 * ( +_5 +_5 -_5 -_5 )
# + -0.7878447412876952 * ( +_0 -_0 )
# + 0.04693450040873902 * ( +_0 -_1 )
# + 0.04693450040873909 * ( +_1 -_0 )
# + -0.36211748527673676 * ( +_1 -_1 )
# + -0.3625472373052549 * ( +_2 -_2 )
# + -0.7878447412876952 * ( +_3 -_3 )
# + 0.04693450040873902 * ( +_3 -_4 )
# + 0.04693450040873909 * ( +_4 -_3 )
# + -0.36211748527673676 * ( +_4 -_4 )
# + -0.3625472373052549 * ( +_5 -_5 )

# %% [markdown]
# ### (5) LiH with active orbitals 1,2,5 (out of 0,1,2,3,4,5)

# %%
transformer5 = ActiveSpaceTransformer(num_electrons=2, num_spatial_orbitals=3, active_orbitals=[1,2,5])
LiH_qub_5, LiH_es_5 = get_qubit_op(atom_str, charge, basis, mapping_name, transformer5)
print('GS energy:',get_exact_energies(LiH_es_5)[1])
print(LiH_qub_5)
print(LiH_es_5.hamiltonian.second_q_op())
# Out:
# Number of particles: (1, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# GS energy: -7.88101571564711
# SparsePauliOp(['IIII', 'IIIZ', 'IIZZ', 'IIZI', 'IIXZ', 'IIXI', 'IZII', 'IZIZ', 'ZXII', 'ZXIZ', 'IXII', 'IXIZ', 'XXII', 'XXIZ', 'YYII', 'YYIZ', 'ZZII', 'ZZIZ', 'XZII', 'XZIZ', 'XIII', 'XIIZ', 'ZIII', 'ZIIZ', 'IIXX', 'IIYY', 'IIZX', 'IIIX', 'IZZX', 'IZIX', 'ZXZX', 'IXZX', 'ZXIX', 'IXIX', 'XXZX', 'YYZX', 'XXIX', 'YYIX', 'ZZZX', 'ZZIX', 'XZZX', 'XIZX', 'XZIX', 'XIIX', 'ZIZX', 'ZIIX', 'IZXX', 'IZYY', 'ZXXX', 'IXXX', 'ZXYY', 'IXYY', 'XXXX', 'YYXX', 'XXYY', 'YYYY', 'ZZXX', 'ZZYY', 'XZXX', 'XIXX', 'XZYY', 'XIYY', 'ZIXX', 'ZIYY', 'IZZZ', 'ZXZZ', 'IXZZ', 'XXZZ', 'YYZZ', 'ZZZZ', 'XZZZ', 'XIZZ', 'ZIZZ', 'IZXZ', 'IZXI', 'ZXXZ', 'IXXZ', 'ZXXI', 'IXXI', 'XXXZ', 'YYXZ', 'XXXI', 'YYXI', 'ZZXZ', 'ZZXI', 'XZXZ', 'XIXZ', 'XZXI', 'XIXI', 'ZIXZ', 'ZIXI', 'IZZI', 'ZXZI', 'IXZI', 'XXZI', 'YYZI', 'ZZZI', 'XZZI', 'XIZI', 'ZIZI'],
#               coeffs=[-1.99754128e-01+0.j, -9.17966070e-02+0.j, -2.11959340e-01+0.j,
#   3.71356404e-01+0.j,  1.95776536e-02+0.j,  1.95776536e-02+0.j,
#   9.17966070e-02+0.j, -1.23570872e-01+0.j,  2.73410829e-03+0.j,
#   1.17336244e-02+0.j,  2.73410829e-03+0.j,  1.17336244e-02+0.j,
#  -3.09894802e-04+0.j, -3.30587284e-02+0.j,  3.09894802e-04+0.j,
#   3.30587284e-02+0.j, -2.11959340e-01+0.j,  5.66560678e-02+0.j,
#  -1.95776536e-02+0.j, -1.27339142e-02+0.j,  1.95776536e-02+0.j,
#   1.27339142e-02+0.j, -3.71356404e-01+0.j,  1.14339547e-01+0.j,
#  -3.09894802e-04+0.j,  3.09894802e-04+0.j, -2.73410829e-03+0.j,
#   2.73410829e-03+0.j,  1.17336244e-02+0.j, -1.17336244e-02+0.j,
#  -3.03465702e-03+0.j, -3.03465702e-03+0.j,  3.03465702e-03+0.j,
#   3.03465702e-03+0.j,  8.37336168e-03+0.j, -8.37336168e-03+0.j,
#  -8.37336168e-03+0.j,  8.37336168e-03+0.j,  1.54067023e-03+0.j,
#  -1.54067023e-03+0.j,  2.11113789e-03+0.j, -2.11113789e-03+0.j,
#  -2.11113789e-03+0.j,  2.11113789e-03+0.j, -1.05401878e-02+0.j,
#   1.05401878e-02+0.j,  3.30587284e-02+0.j, -3.30587284e-02+0.j,
#  -8.37336168e-03+0.j, -8.37336168e-03+0.j,  8.37336168e-03+0.j,
#   8.37336168e-03+0.j,  3.07383271e-02+0.j, -3.07383271e-02+0.j,
#  -3.07383271e-02+0.j,  3.07383271e-02+0.j,  2.36793671e-03+0.j,
#  -2.36793671e-03+0.j,  7.76444138e-03+0.j, -7.76444138e-03+0.j,
#  -7.76444138e-03+0.j,  7.76444138e-03+0.j, -3.51167703e-02+0.j,
#   3.51167703e-02+0.j, -5.66560678e-02+0.j, -1.54067023e-03+0.j,
#  -1.54067023e-03+0.j,  2.36793671e-03+0.j, -2.36793671e-03+0.j,
#   8.47039179e-02+0.j,  9.01204280e-03+0.j, -9.01204280e-03+0.j,
#   6.05056059e-02+0.j, -1.27339142e-02+0.j, -1.27339142e-02+0.j,
#   2.11113789e-03+0.j,  2.11113789e-03+0.j,  2.11113789e-03+0.j,
#   2.11113789e-03+0.j, -7.76444138e-03+0.j,  7.76444138e-03+0.j,
#  -7.76444138e-03+0.j,  7.76444138e-03+0.j, -9.01204280e-03+0.j,
#  -9.01204280e-03+0.j, -6.57574505e-03+0.j,  6.57574505e-03+0.j,
#  -6.57574505e-03+0.j,  6.57574505e-03+0.j,  1.08894080e-02+0.j,
#   1.08894080e-02+0.j,  1.14339547e-01+0.j, -1.05401878e-02+0.j,
#  -1.05401878e-02+0.j,  3.51167703e-02+0.j, -3.51167703e-02+0.j,
#  -6.05056059e-02+0.j,  1.08894080e-02+0.j, -1.08894080e-02+0.j,
#  -1.14091635e-01+0.j])
# Fermionic Operator
# number spin orbitals=6, number terms=342
#   0.2471417439972668 * ( +_0 +_0 -_0 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_1 -_0 )
# + 0.06611745680591614 * ( +_0 +_0 -_2 -_0 )
# + -0.023467248713444976 * ( +_0 +_1 -_0 -_0 )
# + 0.11331213551045112 * ( +_0 +_1 -_1 -_0 )
# + -0.025467828488245463 * ( +_0 +_1 -_2 -_0 )
# + 0.06611745680591614 * ( +_0 +_2 -_0 -_0 )
# + -0.025467828488245463 * ( +_0 +_2 -_1 -_0 )
# + 0.2286790933634381 * ( +_0 +_2 -_2 -_0 )
# + 0.2471417439972668 * ( +_0 +_3 -_3 -_0 )
# + -0.023467248713444976 * ( +_0 +_3 -_4 -_0 )
# + 0.06611745680591614 * ( +_0 +_3 -_5 -_0 )
# + -0.023467248713444976 * ( +_0 +_4 -_3 -_0 )
# + 0.11331213551045112 * ( +_0 +_4 -_4 -_0 )
# + -0.025467828488245463 * ( +_0 +_4 -_5 -_0 )
# + 0.06611745680591614 * ( +_0 +_5 -_3 -_0 )
# + -0.025467828488245463 * ( +_0 +_5 -_4 -_0 )
# + 0.2286790933634381 * ( +_0 +_5 -_5 -_0 )
# + -0.023467248713444976 * ( +_0 +_0 -_0 -_1 )
# + 0.006069314048326776 * ( +_0 +_0 -_1 -_1 )
# + -0.016746723354736457 * ( +_0 +_0 -_2 -_1 )
# + 0.006069314048326776 * ( +_0 +_1 -_0 -_1 )
# + 0.0030813404613908996 * ( +_0 +_1 -_1 -_1 )
# + 0.004222275778764741 * ( +_0 +_1 -_2 -_1 )
# + -0.016746723354736457 * ( +_0 +_2 -_0 -_1 )
# + 0.004222275778764741 * ( +_0 +_2 -_1 -_1 )
# + -0.021080375585638238 * ( +_0 +_2 -_2 -_1 )
# + -0.023467248713444976 * ( +_0 +_3 -_3 -_1 )
# + 0.006069314048326776 * ( +_0 +_3 -_4 -_1 )
# + -0.016746723354736457 * ( +_0 +_3 -_5 -_1 )
# + 0.006069314048326776 * ( +_0 +_4 -_3 -_1 )
# + 0.0030813404613908996 * ( +_0 +_4 -_4 -_1 )
# + 0.004222275778764741 * ( +_0 +_4 -_5 -_1 )
# + -0.016746723354736457 * ( +_0 +_5 -_3 -_1 )
# + 0.004222275778764741 * ( +_0 +_5 -_4 -_1 )
# + -0.021080375585638238 * ( +_0 +_5 -_5 -_1 )
# + 0.06611745680591614 * ( +_0 +_0 -_0 -_2 )
# + -0.016746723354736457 * ( +_0 +_0 -_1 -_2 )
# + 0.06147665411357217 * ( +_0 +_0 -_2 -_2 )
# + -0.016746723354736457 * ( +_0 +_1 -_0 -_2 )
# + -0.004735873420751882 * ( +_0 +_1 -_1 -_2 )
# + -0.015528882762299193 * ( +_0 +_1 -_2 -_2 )
# + 0.06147665411357217 * ( +_0 +_2 -_0 -_2 )
# + -0.015528882762299193 * ( +_0 +_2 -_1 -_2 )
# + 0.07023354054831929 * ( +_0 +_2 -_2 -_2 )
# + 0.06611745680591614 * ( +_0 +_3 -_3 -_2 )
# + -0.016746723354736457 * ( +_0 +_3 -_4 -_2 )
# + 0.06147665411357217 * ( +_0 +_3 -_5 -_2 )
# + -0.016746723354736457 * ( +_0 +_4 -_3 -_2 )
# + -0.004735873420751882 * ( +_0 +_4 -_4 -_2 )
# + -0.015528882762299193 * ( +_0 +_4 -_5 -_2 )
# + 0.06147665411357217 * ( +_0 +_5 -_3 -_2 )
# + -0.015528882762299193 * ( +_0 +_5 -_4 -_2 )
# + 0.07023354054831929 * ( +_0 +_5 -_5 -_2 )
# + -0.023467248713444976 * ( +_1 +_0 -_0 -_0 )
# + 0.006069314048326776 * ( +_1 +_0 -_1 -_0 )
# + -0.016746723354736457 * ( +_1 +_0 -_2 -_0 )
# + 0.006069314048326776 * ( +_1 +_1 -_0 -_0 )
# + 0.0030813404613908996 * ( +_1 +_1 -_1 -_0 )
# + 0.004222275778764741 * ( +_1 +_1 -_2 -_0 )
# + -0.016746723354736457 * ( +_1 +_2 -_0 -_0 )
# + 0.004222275778764741 * ( +_1 +_2 -_1 -_0 )
# + -0.021080375585638238 * ( +_1 +_2 -_2 -_0 )
# + -0.023467248713444976 * ( +_1 +_3 -_3 -_0 )
# + 0.006069314048326776 * ( +_1 +_3 -_4 -_0 )
# + -0.016746723354736457 * ( +_1 +_3 -_5 -_0 )
# + 0.006069314048326776 * ( +_1 +_4 -_3 -_0 )
# + 0.0030813404613908996 * ( +_1 +_4 -_4 -_0 )
# + 0.004222275778764741 * ( +_1 +_4 -_5 -_0 )
# + -0.016746723354736457 * ( +_1 +_5 -_3 -_0 )
# + 0.004222275778764741 * ( +_1 +_5 -_4 -_0 )
# + -0.021080375585638238 * ( +_1 +_5 -_5 -_0 )
# + 0.11331213551045112 * ( +_1 +_0 -_0 -_1 )
# + 0.0030813404613908996 * ( +_1 +_0 -_1 -_1 )
# + -0.004735873420751882 * ( +_1 +_0 -_2 -_1 )
# + 0.0030813404613908996 * ( +_1 +_1 -_0 -_1 )
# + 0.1694078358672006 * ( +_1 +_1 -_1 -_1 )
# + 0.0180240855911208 * ( +_1 +_1 -_2 -_1 )
# + -0.004735873420751882 * ( +_1 +_2 -_0 -_1 )
# + 0.0180240855911208 * ( +_1 +_2 -_1 -_1 )
# + 0.12101121172734611 * ( +_1 +_2 -_2 -_1 )
# + 0.11331213551045112 * ( +_1 +_3 -_3 -_1 )
# + 0.0030813404613908996 * ( +_1 +_3 -_4 -_1 )
# + -0.004735873420751882 * ( +_1 +_3 -_5 -_1 )
# + 0.0030813404613908996 * ( +_1 +_4 -_3 -_1 )
# + 0.1694078358672006 * ( +_1 +_4 -_4 -_1 )
# + 0.0180240855911208 * ( +_1 +_4 -_5 -_1 )
# + -0.004735873420751882 * ( +_1 +_5 -_3 -_1 )
# + 0.0180240855911208 * ( +_1 +_5 -_4 -_1 )
# + 0.12101121172734611 * ( +_1 +_5 -_5 -_1 )
# + -0.025467828488245463 * ( +_1 +_0 -_0 -_2 )
# + 0.004222275778764741 * ( +_1 +_0 -_1 -_2 )
# + -0.015528882762299193 * ( +_1 +_0 -_2 -_2 )
# + 0.004222275778764741 * ( +_1 +_1 -_0 -_2 )
# + 0.0180240855911208 * ( +_1 +_1 -_1 -_2 )
# + 0.013151490103023179 * ( +_1 +_1 -_2 -_2 )
# + -0.015528882762299193 * ( +_1 +_2 -_0 -_2 )
# + 0.013151490103023179 * ( +_1 +_2 -_1 -_2 )
# + -0.021778815972196292 * ( +_1 +_2 -_2 -_2 )
# + -0.025467828488245463 * ( +_1 +_3 -_3 -_2 )
# + 0.004222275778764741 * ( +_1 +_3 -_4 -_2 )
# + -0.015528882762299193 * ( +_1 +_3 -_5 -_2 )
# + 0.004222275778764741 * ( +_1 +_4 -_3 -_2 )
# + 0.0180240855911208 * ( +_1 +_4 -_4 -_2 )
# + 0.013151490103023179 * ( +_1 +_4 -_5 -_2 )
# + -0.015528882762299193 * ( +_1 +_5 -_3 -_2 )
# + 0.013151490103023179 * ( +_1 +_5 -_4 -_2 )
# + -0.021778815972196292 * ( +_1 +_5 -_5 -_2 )
# + 0.06611745680591614 * ( +_2 +_0 -_0 -_0 )
# + -0.016746723354736457 * ( +_2 +_0 -_1 -_0 )
# + 0.06147665411357217 * ( +_2 +_0 -_2 -_0 )
# + -0.016746723354736457 * ( +_2 +_1 -_0 -_0 )
# + -0.004735873420751882 * ( +_2 +_1 -_1 -_0 )
# + -0.015528882762299193 * ( +_2 +_1 -_2 -_0 )
# + 0.06147665411357217 * ( +_2 +_2 -_0 -_0 )
# + -0.015528882762299193 * ( +_2 +_2 -_1 -_0 )
# + 0.07023354054831929 * ( +_2 +_2 -_2 -_0 )
# + 0.06611745680591614 * ( +_2 +_3 -_3 -_0 )
# + -0.016746723354736457 * ( +_2 +_3 -_4 -_0 )
# + 0.06147665411357217 * ( +_2 +_3 -_5 -_0 )
# + -0.016746723354736457 * ( +_2 +_4 -_3 -_0 )
# + -0.004735873420751882 * ( +_2 +_4 -_4 -_0 )
# + -0.015528882762299193 * ( +_2 +_4 -_5 -_0 )
# + 0.06147665411357217 * ( +_2 +_5 -_3 -_0 )
# + -0.015528882762299193 * ( +_2 +_5 -_4 -_0 )
# + 0.07023354054831929 * ( +_2 +_5 -_5 -_0 )
# + -0.025467828488245463 * ( +_2 +_0 -_0 -_1 )
# + 0.004222275778764741 * ( +_2 +_0 -_1 -_1 )
# + -0.015528882762299193 * ( +_2 +_0 -_2 -_1 )
# + 0.004222275778764741 * ( +_2 +_1 -_0 -_1 )
# + 0.0180240855911208 * ( +_2 +_1 -_1 -_1 )
# + 0.013151490103023179 * ( +_2 +_1 -_2 -_1 )
# + -0.015528882762299193 * ( +_2 +_2 -_0 -_1 )
# + 0.013151490103023179 * ( +_2 +_2 -_1 -_1 )
# + -0.021778815972196292 * ( +_2 +_2 -_2 -_1 )
# + -0.025467828488245463 * ( +_2 +_3 -_3 -_1 )
# + 0.004222275778764741 * ( +_2 +_3 -_4 -_1 )
# + -0.015528882762299193 * ( +_2 +_3 -_5 -_1 )
# + 0.004222275778764741 * ( +_2 +_4 -_3 -_1 )
# + 0.0180240855911208 * ( +_2 +_4 -_4 -_1 )
# + 0.013151490103023179 * ( +_2 +_4 -_5 -_1 )
# + -0.015528882762299193 * ( +_2 +_5 -_3 -_1 )
# + 0.013151490103023179 * ( +_2 +_5 -_4 -_1 )
# + -0.021778815972196292 * ( +_2 +_5 -_5 -_1 )
# + 0.2286790933634381 * ( +_2 +_0 -_0 -_2 )
# + -0.021080375585638238 * ( +_2 +_0 -_1 -_2 )
# + 0.07023354054831929 * ( +_2 +_0 -_2 -_2 )
# + -0.021080375585638238 * ( +_2 +_1 -_0 -_2 )
# + 0.12101121172734611 * ( +_2 +_1 -_1 -_2 )
# + -0.021778815972196292 * ( +_2 +_1 -_2 -_2 )
# + 0.07023354054831929 * ( +_2 +_2 -_0 -_2 )
# + -0.021778815972196292 * ( +_2 +_2 -_1 -_2 )
# + 0.22818326979612566 * ( +_2 +_2 -_2 -_2 )
# + 0.2286790933634381 * ( +_2 +_3 -_3 -_2 )
# + -0.021080375585638238 * ( +_2 +_3 -_4 -_2 )
# + 0.07023354054831929 * ( +_2 +_3 -_5 -_2 )
# + -0.021080375585638238 * ( +_2 +_4 -_3 -_2 )
# + 0.12101121172734611 * ( +_2 +_4 -_4 -_2 )
# + -0.021778815972196292 * ( +_2 +_4 -_5 -_2 )
# + 0.07023354054831929 * ( +_2 +_5 -_3 -_2 )
# + -0.021778815972196292 * ( +_2 +_5 -_4 -_2 )
# + 0.22818326979612566 * ( +_2 +_5 -_5 -_2 )
# + 0.2471417439972668 * ( +_3 +_0 -_0 -_3 )
# + -0.023467248713444976 * ( +_3 +_0 -_1 -_3 )
# + 0.06611745680591614 * ( +_3 +_0 -_2 -_3 )
# + -0.023467248713444976 * ( +_3 +_1 -_0 -_3 )
# + 0.11331213551045112 * ( +_3 +_1 -_1 -_3 )
# + -0.025467828488245463 * ( +_3 +_1 -_2 -_3 )
# + 0.06611745680591614 * ( +_3 +_2 -_0 -_3 )
# + -0.025467828488245463 * ( +_3 +_2 -_1 -_3 )
# + 0.2286790933634381 * ( +_3 +_2 -_2 -_3 )
# + 0.2471417439972668 * ( +_3 +_3 -_3 -_3 )
# + -0.023467248713444976 * ( +_3 +_3 -_4 -_3 )
# + 0.06611745680591614 * ( +_3 +_3 -_5 -_3 )
# + -0.023467248713444976 * ( +_3 +_4 -_3 -_3 )
# + 0.11331213551045112 * ( +_3 +_4 -_4 -_3 )
# + -0.025467828488245463 * ( +_3 +_4 -_5 -_3 )
# + 0.06611745680591614 * ( +_3 +_5 -_3 -_3 )
# + -0.025467828488245463 * ( +_3 +_5 -_4 -_3 )
# + 0.2286790933634381 * ( +_3 +_5 -_5 -_3 )
# + -0.023467248713444976 * ( +_3 +_0 -_0 -_4 )
# + 0.006069314048326776 * ( +_3 +_0 -_1 -_4 )
# + -0.016746723354736457 * ( +_3 +_0 -_2 -_4 )
# + 0.006069314048326776 * ( +_3 +_1 -_0 -_4 )
# + 0.0030813404613908996 * ( +_3 +_1 -_1 -_4 )
# + 0.004222275778764741 * ( +_3 +_1 -_2 -_4 )
# + -0.016746723354736457 * ( +_3 +_2 -_0 -_4 )
# + 0.004222275778764741 * ( +_3 +_2 -_1 -_4 )
# + -0.021080375585638238 * ( +_3 +_2 -_2 -_4 )
# + -0.023467248713444976 * ( +_3 +_3 -_3 -_4 )
# + 0.006069314048326776 * ( +_3 +_3 -_4 -_4 )
# + -0.016746723354736457 * ( +_3 +_3 -_5 -_4 )
# + 0.006069314048326776 * ( +_3 +_4 -_3 -_4 )
# + 0.0030813404613908996 * ( +_3 +_4 -_4 -_4 )
# + 0.004222275778764741 * ( +_3 +_4 -_5 -_4 )
# + -0.016746723354736457 * ( +_3 +_5 -_3 -_4 )
# + 0.004222275778764741 * ( +_3 +_5 -_4 -_4 )
# + -0.021080375585638238 * ( +_3 +_5 -_5 -_4 )
# + 0.06611745680591614 * ( +_3 +_0 -_0 -_5 )
# + -0.016746723354736457 * ( +_3 +_0 -_1 -_5 )
# + 0.06147665411357217 * ( +_3 +_0 -_2 -_5 )
# + -0.016746723354736457 * ( +_3 +_1 -_0 -_5 )
# + -0.004735873420751882 * ( +_3 +_1 -_1 -_5 )
# + -0.015528882762299193 * ( +_3 +_1 -_2 -_5 )
# + 0.06147665411357217 * ( +_3 +_2 -_0 -_5 )
# + -0.015528882762299193 * ( +_3 +_2 -_1 -_5 )
# + 0.07023354054831929 * ( +_3 +_2 -_2 -_5 )
# + 0.06611745680591614 * ( +_3 +_3 -_3 -_5 )
# + -0.016746723354736457 * ( +_3 +_3 -_4 -_5 )
# + 0.06147665411357217 * ( +_3 +_3 -_5 -_5 )
# + -0.016746723354736457 * ( +_3 +_4 -_3 -_5 )
# + -0.004735873420751882 * ( +_3 +_4 -_4 -_5 )
# + -0.015528882762299193 * ( +_3 +_4 -_5 -_5 )
# + 0.06147665411357217 * ( +_3 +_5 -_3 -_5 )
# + -0.015528882762299193 * ( +_3 +_5 -_4 -_5 )
# + 0.07023354054831929 * ( +_3 +_5 -_5 -_5 )
# + -0.023467248713444976 * ( +_4 +_0 -_0 -_3 )
# + 0.006069314048326776 * ( +_4 +_0 -_1 -_3 )
# + -0.016746723354736457 * ( +_4 +_0 -_2 -_3 )
# + 0.006069314048326776 * ( +_4 +_1 -_0 -_3 )
# + 0.0030813404613908996 * ( +_4 +_1 -_1 -_3 )
# + 0.004222275778764741 * ( +_4 +_1 -_2 -_3 )
# + -0.016746723354736457 * ( +_4 +_2 -_0 -_3 )
# + 0.004222275778764741 * ( +_4 +_2 -_1 -_3 )
# + -0.021080375585638238 * ( +_4 +_2 -_2 -_3 )
# + -0.023467248713444976 * ( +_4 +_3 -_3 -_3 )
# + 0.006069314048326776 * ( +_4 +_3 -_4 -_3 )
# + -0.016746723354736457 * ( +_4 +_3 -_5 -_3 )
# + 0.006069314048326776 * ( +_4 +_4 -_3 -_3 )
# + 0.0030813404613908996 * ( +_4 +_4 -_4 -_3 )
# + 0.004222275778764741 * ( +_4 +_4 -_5 -_3 )
# + -0.016746723354736457 * ( +_4 +_5 -_3 -_3 )
# + 0.004222275778764741 * ( +_4 +_5 -_4 -_3 )
# + -0.021080375585638238 * ( +_4 +_5 -_5 -_3 )
# + 0.11331213551045112 * ( +_4 +_0 -_0 -_4 )
# + 0.0030813404613908996 * ( +_4 +_0 -_1 -_4 )
# + -0.004735873420751882 * ( +_4 +_0 -_2 -_4 )
# + 0.0030813404613908996 * ( +_4 +_1 -_0 -_4 )
# + 0.1694078358672006 * ( +_4 +_1 -_1 -_4 )
# + 0.0180240855911208 * ( +_4 +_1 -_2 -_4 )
# + -0.004735873420751882 * ( +_4 +_2 -_0 -_4 )
# + 0.0180240855911208 * ( +_4 +_2 -_1 -_4 )
# + 0.12101121172734611 * ( +_4 +_2 -_2 -_4 )
# + 0.11331213551045112 * ( +_4 +_3 -_3 -_4 )
# + 0.0030813404613908996 * ( +_4 +_3 -_4 -_4 )
# + -0.004735873420751882 * ( +_4 +_3 -_5 -_4 )
# + 0.0030813404613908996 * ( +_4 +_4 -_3 -_4 )
# + 0.1694078358672006 * ( +_4 +_4 -_4 -_4 )
# + 0.0180240855911208 * ( +_4 +_4 -_5 -_4 )
# + -0.004735873420751882 * ( +_4 +_5 -_3 -_4 )
# + 0.0180240855911208 * ( +_4 +_5 -_4 -_4 )
# + 0.12101121172734611 * ( +_4 +_5 -_5 -_4 )
# + -0.025467828488245463 * ( +_4 +_0 -_0 -_5 )
# + 0.004222275778764741 * ( +_4 +_0 -_1 -_5 )
# + -0.015528882762299193 * ( +_4 +_0 -_2 -_5 )
# + 0.004222275778764741 * ( +_4 +_1 -_0 -_5 )
# + 0.0180240855911208 * ( +_4 +_1 -_1 -_5 )
# + 0.013151490103023179 * ( +_4 +_1 -_2 -_5 )
# + -0.015528882762299193 * ( +_4 +_2 -_0 -_5 )
# + 0.013151490103023179 * ( +_4 +_2 -_1 -_5 )
# + -0.021778815972196292 * ( +_4 +_2 -_2 -_5 )
# + -0.025467828488245463 * ( +_4 +_3 -_3 -_5 )
# + 0.004222275778764741 * ( +_4 +_3 -_4 -_5 )
# + -0.015528882762299193 * ( +_4 +_3 -_5 -_5 )
# + 0.004222275778764741 * ( +_4 +_4 -_3 -_5 )
# + 0.0180240855911208 * ( +_4 +_4 -_4 -_5 )
# + 0.013151490103023179 * ( +_4 +_4 -_5 -_5 )
# + -0.015528882762299193 * ( +_4 +_5 -_3 -_5 )
# + 0.013151490103023179 * ( +_4 +_5 -_4 -_5 )
# + -0.021778815972196292 * ( +_4 +_5 -_5 -_5 )
# + 0.06611745680591614 * ( +_5 +_0 -_0 -_3 )
# + -0.016746723354736457 * ( +_5 +_0 -_1 -_3 )
# + 0.06147665411357217 * ( +_5 +_0 -_2 -_3 )
# + -0.016746723354736457 * ( +_5 +_1 -_0 -_3 )
# + -0.004735873420751882 * ( +_5 +_1 -_1 -_3 )
# + -0.015528882762299193 * ( +_5 +_1 -_2 -_3 )
# + 0.06147665411357217 * ( +_5 +_2 -_0 -_3 )
# + -0.015528882762299193 * ( +_5 +_2 -_1 -_3 )
# + 0.07023354054831929 * ( +_5 +_2 -_2 -_3 )
# + 0.06611745680591614 * ( +_5 +_3 -_3 -_3 )
# + -0.016746723354736457 * ( +_5 +_3 -_4 -_3 )
# + 0.06147665411357217 * ( +_5 +_3 -_5 -_3 )
# + -0.016746723354736457 * ( +_5 +_4 -_3 -_3 )
# + -0.004735873420751882 * ( +_5 +_4 -_4 -_3 )
# + -0.015528882762299193 * ( +_5 +_4 -_5 -_3 )
# + 0.06147665411357217 * ( +_5 +_5 -_3 -_3 )
# + -0.015528882762299193 * ( +_5 +_5 -_4 -_3 )
# + 0.07023354054831929 * ( +_5 +_5 -_5 -_3 )
# + -0.025467828488245463 * ( +_5 +_0 -_0 -_4 )
# + 0.004222275778764741 * ( +_5 +_0 -_1 -_4 )
# + -0.015528882762299193 * ( +_5 +_0 -_2 -_4 )
# + 0.004222275778764741 * ( +_5 +_1 -_0 -_4 )
# + 0.0180240855911208 * ( +_5 +_1 -_1 -_4 )
# + 0.013151490103023179 * ( +_5 +_1 -_2 -_4 )
# + -0.015528882762299193 * ( +_5 +_2 -_0 -_4 )
# + 0.013151490103023179 * ( +_5 +_2 -_1 -_4 )
# + -0.021778815972196292 * ( +_5 +_2 -_2 -_4 )
# + -0.025467828488245463 * ( +_5 +_3 -_3 -_4 )
# + 0.004222275778764741 * ( +_5 +_3 -_4 -_4 )
# + -0.015528882762299193 * ( +_5 +_3 -_5 -_4 )
# + 0.004222275778764741 * ( +_5 +_4 -_3 -_4 )
# + 0.0180240855911208 * ( +_5 +_4 -_4 -_4 )
# + 0.013151490103023179 * ( +_5 +_4 -_5 -_4 )
# + -0.015528882762299193 * ( +_5 +_5 -_3 -_4 )
# + 0.013151490103023179 * ( +_5 +_5 -_4 -_4 )
# + -0.021778815972196292 * ( +_5 +_5 -_5 -_4 )
# + 0.2286790933634381 * ( +_5 +_0 -_0 -_5 )
# + -0.021080375585638238 * ( +_5 +_0 -_1 -_5 )
# + 0.07023354054831929 * ( +_5 +_0 -_2 -_5 )
# + -0.021080375585638238 * ( +_5 +_1 -_0 -_5 )
# + 0.12101121172734611 * ( +_5 +_1 -_1 -_5 )
# + -0.021778815972196292 * ( +_5 +_1 -_2 -_5 )
# + 0.07023354054831929 * ( +_5 +_2 -_0 -_5 )
# + -0.021778815972196292 * ( +_5 +_2 -_1 -_5 )
# + 0.22818326979612566 * ( +_5 +_2 -_2 -_5 )
# + 0.2286790933634381 * ( +_5 +_3 -_3 -_5 )
# + -0.021080375585638238 * ( +_5 +_3 -_4 -_5 )
# + 0.07023354054831929 * ( +_5 +_3 -_5 -_5 )
# + -0.021080375585638238 * ( +_5 +_4 -_3 -_5 )
# + 0.12101121172734611 * ( +_5 +_4 -_4 -_5 )
# + -0.021778815972196292 * ( +_5 +_4 -_5 -_5 )
# + 0.07023354054831929 * ( +_5 +_5 -_3 -_5 )
# + -0.021778815972196292 * ( +_5 +_5 -_4 -_5 )
# + 0.22818326979612566 * ( +_5 +_5 -_5 -_5 )
# + -0.7878447412876952 * ( +_0 -_0 )
# + 0.04693450040873902 * ( +_0 -_1 )
# + -0.13223491353741917 * ( +_0 -_2 )
# + 0.04693450040873909 * ( +_1 -_0 )
# + -0.36211748527673676 * ( +_1 -_1 )
# + 0.06837786611890995 * ( +_1 -_2 )
# + -0.13223491353741904 * ( +_2 -_0 )
# + 0.06837786611890997 * ( +_2 -_1 )
# + -0.21746574956930353 * ( +_2 -_2 )
# + -0.7878447412876952 * ( +_3 -_3 )
# + 0.04693450040873902 * ( +_3 -_4 )
# + -0.13223491353741917 * ( +_3 -_5 )
# + 0.04693450040873909 * ( +_4 -_3 )
# + -0.36211748527673676 * ( +_4 -_4 )
# + 0.06837786611890995 * ( +_4 -_5 )
# + -0.13223491353741904 * ( +_5 -_3 )
# + 0.06837786611890997 * ( +_5 -_4 )
# + -0.21746574956930353 * ( +_5 -_5 )

# %% [markdown]
# ## LiH GS energy as function of distance

# %%
# Constants
known_dist = 1.595
N = 25
Rs = np.linspace(0.8 * known_dist, 1.2 * known_dist, N)
energies = np.zeros(len(Rs))

# Energy calculation
for i, R in enumerate(Rs):
    atom_str = f"Li .0 .0 .0; H .0 .0 {R}"
    qubit_op, es = get_qubit_op(atom_str, charge, basis, mapping_name)
    energies[i] = get_exact_energies(es)[1]


# Find real minimum and simulated middle point
min_index = np.argmin(energies)  # Index of minimum energy
mid_index = N // 2  # Middle index of Rs

margine_const = 0.05
plt.axis([min(Rs) - margine_const * (max(Rs) - min(Rs)), 
          max(Rs) + margine_const * (max(Rs) - min(Rs)), 
          min(energies) - margine_const * (max(energies) - min(energies)), 
          max(energies) + margine_const * (max(energies) - min(energies))])

# Get updated limits
x_L, x_R, y_L, y_R = plt.axis()

# Calculate real minimum and simulated middle point
x_min, y_min = Rs[min_index], energies[min_index]
x_mid, y_mid = Rs[mid_index], energies[mid_index]
plt.plot(Rs, energies, label="Energy Curve", color="black")

# Add scatter points
plt.scatter(x_min, y_min, color="red", label=f"Real Min: Distance={x_min:.3f}, E={y_min:.3f}")
plt.scatter(x_mid, y_mid, color="blue", label=f"Simulated: Distance={x_mid:.3f}, E={y_mid:.3f}")

# Add dashed lines
# simulation min
plt.axhline(y_min, 0, (x_min-x_L)/(x_R-x_L), linestyle=":", color="red")
plt.axvline(x_min, 0, (y_min-y_L)/(y_R-y_L), linestyle=":", color="red")

# known min
plt.axhline(y_mid, 0, (x_mid-x_L)/(x_R-x_L), linestyle=":", color="blue")
plt.axvline(x_mid, 0, (y_mid-y_L)/(y_R-y_L), linestyle=":", color="blue")

# Labels and title
plt.xlabel("d [Angstrom]")
plt.ylabel("GS energy [Hartree]")
plt.title("LiH Energy vs Distance")
plt.legend()
plt.show()
# Out:
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631

# %% [markdown]
# ## H2O GS energy at known molecule geometry

# %%
known_R = 0.9584
known_theta = 104.5 * pi / 180  # Convert to radians

atom_str = (
    f"O .0 .0 .0; "
    f"H {known_R * sin(known_theta / 2):.3f} {known_R * cos(known_theta / 2):.3f} .0; "
    f"H {-known_R * sin(known_theta / 2):.3f} {known_R * cos(known_theta / 2):.3f} .0"
)

charge = 0
basis = 'sto6g'
mapping_name = "parity"

# transformer_H2O = ActiveSpaceTransformer(num_electrons=4, num_spatial_orbitals=4)
transformer_H2O = None

H2O_qub, H2O_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer_H2O)
# print('GS energy:',get_exact_energies(H2O_es)[1])
# print('GS energy:', minimal_eigenvalue(build_H_mat(H2O_qub)))
print(H2O_qub)
print(H2O_es.hamiltonian.second_q_op())
print('Energies:',get_exact_energies(H2O_es))
# Out:
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# SparsePauliOp(['IIIIIIIIIIII', 'IIIIIIIIIIIZ', 'IIIIIIIIIIZZ', 'IIIIIIIIIIZI', 'IIIIIIIIZXXZ', 'IIIIIIIIZXXI', 'IIIIIIIIIYYI', 'IIIIIIIIIYYZ', 'IIIIIIZXXXXZ', 'IIIIIIZXXXXI', 'IIIIIIIYXXYI', 'IIIIIIIYXXYZ', 'IIIIIIIIIZZI', 'IIIIIIIIIZZZ', 'IIIIIIXXXXZI', 'IIIIIIXXXXZZ', 'IIIIIIYXXYII', 'IIIIIIYXXYIZ', 'IIIIIIIIZZII', 'IIIIIIIIZZIZ', 'IIIIIIZXXZII', 'IIIIIIZXXZIZ', 'IIIIIIIYYIII', 'IIIIIIIYYIIZ', 'IIIIIIIZZIII', 'IIIIIIIZZIIZ', 'IIIIIIZZIIII', 'IIIIIIZZIIIZ', 'IIIIIIZIIIII', 'IIIIIIZIIIIZ', 'IIIIIZIIIIII', 'IIIIIZIIIIIZ', 'IIIIZXIIIIII', 'IIIIZXIIIIIZ', 'IIIIIXIIIIII', 'IIIIIXIIIIIZ', 'IIZXXXIIIIII', 'IIZXXXIIIIIZ', 'IIIYXYIIIIII', 'IIIYXYIIIIIZ', 'ZXXXXXIIIIII', 'ZXXXXXIIIIIZ', 'IYXXXYIIIIII', 'IYXXXYIIIIIZ', 'IIIIZZIIIIII', 'IIIIZZIIIIIZ', 'IIZXXZIIIIII', 'IIZXXZIIIIIZ', 'IIIYYIIIIIII', 'IIIYYIIIIIIZ', 'ZXXXXZIIIIII', 'ZXXXXZIIIIIZ', 'IYXXYIIIIIII', 'IYXXYIIIIIIZ', 'IIIZZIIIIIII', 'IIIZZIIIIIIZ', 'XXXXZIIIIIII', 'XXXXZIIIIIIZ', 'YXXYIIIIIIII', 'YXXYIIIIIIIZ', 'IIZZIIIIIIII', 'IIZZIIIIIIIZ', 'ZXXZIIIIIIII', 'ZXXZIIIIIIIZ', 'IYYIIIIIIIII', 'IYYIIIIIIIIZ', 'IZZIIIIIIIII', 'IZZIIIIIIIIZ', 'ZZIIIIIIIIII', 'ZZIIIIIIIIIZ', 'ZIIIIIIIIIII', 'ZIIIIIIIIIIZ', 'IIIIIIIIZXXX', 'IIIIIIIIZXYY', 'IIIIIIIIIYXY', 'IIIIIIIIIYYX', 'IIIIIIZXXXXX', 'IIIIIIZXXXYY', 'IIIIIIIYXXXY', 'IIIIIIIYXXYX', 'IIIIIIIIIIZX', 'IIIIIIIIIZIX', 'IIIIIIIIIIIX', 'IIIIIIIIIZZX', 'IIIIIIXXXXIX', 'IIIIIIYXXYZX', 'IIIIIIXXXYIY', 'IIIIIIYXXXIY', 'IIIIIIXXXXZX', 'IIIIIIYXXYIX', 'IIIIIIIIZZZX', 'IIIIIIIIZZIX', 'IIIIIIZXXZZX', 'IIIIIIIYYIZX', 'IIIIIIZXYIIY', 'IIIIIIIYXZZY', 'IIIIIIZXXZIX', 'IIIIIIIYYIIX', 'IIIIIIIZZIZX', 'IIIIIIIZZIIX', 'IIIIIIZZIIZX', 'IIIIIIZZIIIX', 'IIIIIIZIIIZX', 'IIIIIIZIIIIX', 'IIIIIZIIIIZX', 'IIIIIZIIIIIX', 'IIIIZXIIIIZX', 'IIIIIXIIIIZX', 'IIIIZXIIIIIX', 'IIIIIXIIIIIX', 'IIZXXXIIIIZX', 'IIIYXYIIIIZX', 'IIZXXXIIIIIX', 'IIIYXYIIIIIX', 'ZXXXXXIIIIZX', 'IYXXXYIIIIZX', 'ZXXXXXIIIIIX', 'IYXXXYIIIIIX', 'IIIIZZIIIIZX', 'IIIIZZIIIIIX', 'IIZXXZIIIIZX', 'IIIYYIIIIIZX', 'IIZXXZIIIIIX', 'IIIYYIIIIIIX', 'ZXXXXZIIIIZX', 'IYXXYIIIIIZX', 'ZXXXXZIIIIIX', 'IYXXYIIIIIIX', 'IIIZZIIIIIZX', 'IIIZZIIIIIIX', 'XXXXZIIIIIZX', 'YXXYIIIIIIZX', 'XXXXZIIIIIIX', 'YXXYIIIIIIIX', 'IIZZIIIIIIZX', 'IIZZIIIIIIIX', 'ZXXZIIIIIIZX', 'IYYIIIIIIIZX', 'ZXXZIIIIIIIX', 'IYYIIIIIIIIX', 'IZZIIIIIIIZX', 'IZZIIIIIIIIX', 'ZZIIIIIIIIZX', 'ZZIIIIIIIIIX', 'ZIIIIIIIIIZX', 'ZIIIIIIIIIIX', 'IIIIIIIIZYYX', 'IIIIIIIIIXYY', 'IIIIIIZXXYYX', 'IIIIIIIYXYYY', 'IIIIIIXXXIXX', 'IIIIIIYXYZXX', 'IIIIIIXXYIYX', 'IIIIIIYXXIXY', 'IIIIIIXXXZYY', 'IIIIIIYXYIYY', 'IIIIIIXZIZXX', 'IIIIIIXIIZXX', 'IIIIIIYIIIYX', 'IIIIIIYZIZXY', 'IIIIIIXZIIYY', 'IIIIIIXIIIYY', 'IIIZXXIIIZXX', 'IIIIYYIIIZXX', 'IIIZXXIIIIYY', 'IIIIYYIIIIYY', 'XXXXXXIIIZXX', 'YXXXXYIIIZXX', 'XXXXXXIIIIYY', 'YXXXXYIIIIYY', 'IIIZXZIIIZXX', 'IIIIXIIIIZXX', 'IIIZXZIIIIYY', 'IIIIXIIIIIYY', 'XXXXXZIIIZXX', 'YXXXYIIIIZXX', 'XXXXXZIIIIYY', 'YXXXYIIIIIYY', 'IIZXZIIIIZXX', 'IIIXIIIIIZXX', 'IIZXZIIIIIYY', 'IIIXIIIIIIYY', 'ZXXXZIIIIZXX', 'IYXYIIIIIZXX', 'ZXXXZIIIIIYY', 'IYXYIIIIIIYY', 'XXXZIIIIIZXX', 'YXYIIIIIIZXX', 'XXXZIIIIIIYY', 'YXYIIIIIIIYY', 'XZIIIIIIIZXX', 'XIIIIIIIIZXX', 'XZIIIIIIIIYY', 'XIIIIIIIIIYY', 'IIIIIIZXYYXX', 'IIIIIIIYYYXY', 'IIIIIIIZIXXX', 'IIIIIIIZZYXY', 'IIIIIIZZZXXX', 'IIIIIIZZIYXY', 'IIIIIIZIZXXX', 'IIIIIIZIIYXY', 'IIIIIZIIZXXX', 'IIIIIZIIIYXY', 'IIIIZXIIZXXX', 'IIIIIXIIZXXX', 'IIIIZXIIIYXY', 'IIIIIXIIIYXY', 'IIZXXXIIZXXX', 'IIIYXYIIZXXX', 'IIZXXXIIIYXY', 'IIIYXYIIIYXY', 'ZXXXXXIIZXXX', 'IYXXXYIIZXXX', 'ZXXXXXIIIYXY', 'IYXXXYIIIYXY', 'IIIIZZIIZXXX', 'IIIIZZIIIYXY', 'IIZXXZIIZXXX', 'IIIYYIIIZXXX', 'IIZXXZIIIYXY', 'IIIYYIIIIYXY', 'ZXXXXZIIZXXX', 'IYXXYIIIZXXX', 'ZXXXXZIIIYXY', 'IYXXYIIIIYXY', 'IIIZZIIIZXXX', 'IIIZZIIIIYXY', 'XXXXZIIIZXXX', 'YXXYIIIIZXXX', 'XXXXZIIIIYXY', 'YXXYIIIIIYXY', 'IIZZIIIIZXXX', 'IIZZIIIIIYXY', 'ZXXZIIIIZXXX', 'IYYIIIIIZXXX', 'ZXXZIIIIIYXY', 'IYYIIIIIIYXY', 'IZZIIIIIZXXX', 'IZZIIIIIIYXY', 'ZZIIIIIIZXXX', 'ZZIIIIIIIYXY', 'ZIIIIIIIZXXX', 'ZIIIIIIIIYXY', 'IIIIIIZYYXXX', 'IIIIIIIXYXXY', 'IZXXXXIZXXXX', 'IIYXXYIZXXXX', 'IZXXXXIIYXXY', ' ...
#               coeffs=[-56.03558129+0.j,  12.5545228 +0.j,   1.66895473+0.j, ...,
#    0.13803098+0.j,   0.15008032+0.j,   0.11291616+0.j])
# Fermionic Operator
# number spin orbitals=14, number terms=3150
#   2.380819201903083 * ( +_0 +_0 -_0 -_0 )
# + -0.2134076033030814 * ( +_0 +_0 -_1 -_0 )
# + 0.0946190154294636 * ( +_0 +_0 -_3 -_0 )
# + -0.12573069858334246 * ( +_0 +_0 -_5 -_0 )
# + -0.2134076033030814 * ( +_0 +_1 -_0 -_0 )
# + 0.5095385394345271 * ( +_0 +_1 -_1 -_0 )
# + -0.06735111674520967 * ( +_0 +_1 -_3 -_0 )
# + 0.15958091192404175 * ( +_0 +_1 -_5 -_0 )
# + 0.40105776423433714 * ( +_0 +_2 -_2 -_0 )
# + 0.18183235367517545 * ( +_0 +_2 -_6 -_0 )
# + 0.0946190154294636 * ( +_0 +_3 -_0 -_0 )
# + -0.06735111674520967 * ( +_0 +_3 -_1 -_0 )
# + 0.5020228139470131 * ( +_0 +_3 -_3 -_0 )
# + 0.10767965294469878 * ( +_0 +_3 -_5 -_0 )
# + 0.5585407366829527 * ( +_0 +_4 -_4 -_0 )
# + -0.12573069858334246 * ( +_0 +_5 -_0 -_0 )
# + 0.15958091192404175 * ( +_0 +_5 -_1 -_0 )
# + 0.10767965294469878 * ( +_0 +_5 -_3 -_0 )
# + 0.4063723467380974 * ( +_0 +_5 -_5 -_0 )
# + 0.18183235367517545 * ( +_0 +_6 -_2 -_0 )
# + 0.4347103345071293 * ( +_0 +_6 -_6 -_0 )
# + 2.380819201903083 * ( +_0 +_7 -_7 -_0 )
# + -0.2134076033030814 * ( +_0 +_7 -_8 -_0 )
# + 0.0946190154294636 * ( +_0 +_7 -_10 -_0 )
# + -0.12573069858334246 * ( +_0 +_7 -_12 -_0 )
# + -0.2134076033030814 * ( +_0 +_8 -_7 -_0 )
# + 0.5095385394345271 * ( +_0 +_8 -_8 -_0 )
# + -0.06735111674520967 * ( +_0 +_8 -_10 -_0 )
# + 0.15958091192404175 * ( +_0 +_8 -_12 -_0 )
# + 0.40105776423433714 * ( +_0 +_9 -_9 -_0 )
# + 0.18183235367517545 * ( +_0 +_9 -_13 -_0 )
# + 0.0946190154294636 * ( +_0 +_10 -_7 -_0 )
# + -0.06735111674520967 * ( +_0 +_10 -_8 -_0 )
# + 0.5020228139470131 * ( +_0 +_10 -_10 -_0 )
# + 0.10767965294469878 * ( +_0 +_10 -_12 -_0 )
# + 0.5585407366829527 * ( +_0 +_11 -_11 -_0 )
# + -0.12573069858334246 * ( +_0 +_12 -_7 -_0 )
# + 0.15958091192404175 * ( +_0 +_12 -_8 -_0 )
# + 0.10767965294469878 * ( +_0 +_12 -_10 -_0 )
# + 0.4063723467380974 * ( +_0 +_12 -_12 -_0 )
# + 0.18183235367517545 * ( +_0 +_13 -_9 -_0 )
# + 0.4347103345071293 * ( +_0 +_13 -_13 -_0 )
# + -0.2134076033030814 * ( +_0 +_0 -_0 -_1 )
# + 0.030995282180076557 * ( +_0 +_0 -_1 -_1 )
# + -0.012219528544728015 * ( +_0 +_0 -_3 -_1 )
# + 0.019648517685924644 * ( +_0 +_0 -_5 -_1 )
# + 0.030995282180076557 * ( +_0 +_1 -_0 -_1 )
# + -0.0070130965347988015 * ( +_0 +_1 -_1 -_1 )
# + 0.004892569527201691 * ( +_0 +_1 -_3 -_1 )
# + -0.0038049801076566097 * ( +_0 +_1 -_5 -_1 )
# + -0.002072203767195658 * ( +_0 +_2 -_2 -_1 )
# + -0.003628978006755404 * ( +_0 +_2 -_6 -_1 )
# + -0.012219528544728015 * ( +_0 +_3 -_0 -_1 )
# + 0.004892569527201691 * ( +_0 +_3 -_1 -_1 )
# + -0.006714904246896566 * ( +_0 +_3 -_3 -_1 )
# + -0.0007725683281290079 * ( +_0 +_3 -_5 -_1 )
# + -0.005611471801324744 * ( +_0 +_4 -_4 -_1 )
# + 0.019648517685924644 * ( +_0 +_5 -_0 -_1 )
# + -0.0038049801076566097 * ( +_0 +_5 -_1 -_1 )
# + -0.0007725683281290079 * ( +_0 +_5 -_3 -_1 )
# + -0.0037949781085067523 * ( +_0 +_5 -_5 -_1 )
# + -0.003628978006755404 * ( +_0 +_6 -_2 -_1 )
# + -0.0045295302574999245 * ( +_0 +_6 -_6 -_1 )
# + -0.2134076033030814 * ( +_0 +_7 -_7 -_1 )
# + 0.030995282180076557 * ( +_0 +_7 -_8 -_1 )
# + -0.012219528544728015 * ( +_0 +_7 -_10 -_1 )
# + 0.019648517685924644 * ( +_0 +_7 -_12 -_1 )
# + 0.030995282180076557 * ( +_0 +_8 -_7 -_1 )
# + -0.0070130965347988015 * ( +_0 +_8 -_8 -_1 )
# + 0.004892569527201691 * ( +_0 +_8 -_10 -_1 )
# + -0.0038049801076566097 * ( +_0 +_8 -_12 -_1 )
# + -0.002072203767195658 * ( +_0 +_9 -_9 -_1 )
# + -0.003628978006755404 * ( +_0 +_9 -_13 -_1 )
# + -0.012219528544728015 * ( +_0 +_10 -_7 -_1 )
# + 0.004892569527201691 * ( +_0 +_10 -_8 -_1 )
# + -0.006714904246896566 * ( +_0 +_10 -_10 -_1 )
# + -0.0007725683281290079 * ( +_0 +_10 -_12 -_1 )
# + -0.005611471801324744 * ( +_0 +_11 -_11 -_1 )
# + 0.019648517685924644 * ( +_0 +_12 -_7 -_1 )
# + -0.0038049801076566097 * ( +_0 +_12 -_8 -_1 )
# + -0.0007725683281290079 * ( +_0 +_12 -_10 -_1 )
# + -0.0037949781085067523 * ( +_0 +_12 -_12 -_1 )
# + -0.003628978006755404 * ( +_0 +_13 -_9 -_1 )
# + -0.0045295302574999245 * ( +_0 +_13 -_13 -_1 )
# + 0.005649627527970672 * ( +_0 +_0 -_2 -_2 )
# + 0.007884655233387718 * ( +_0 +_0 -_6 -_2 )
# + 0.008862993883178343 * ( +_0 +_1 -_2 -_2 )
# + 0.006972247261198151 * ( +_0 +_1 -_6 -_2 )
# + 0.005649627527970672 * ( +_0 +_2 -_0 -_2 )
# + 0.008862993883178343 * ( +_0 +_2 -_1 -_2 )
# + -0.0017231065512695808 * ( +_0 +_2 -_3 -_2 )
# + 0.0016070545228063892 * ( +_0 +_2 -_5 -_2 )
# + -0.0017231065512695808 * ( +_0 +_3 -_2 -_2 )
# + -0.0047990686872964984 * ( +_0 +_3 -_6 -_2 )
# + 0.0016070545228063892 * ( +_0 +_5 -_2 -_2 )
# + 0.00466468512794097 * ( +_0 +_5 -_6 -_2 )
# + 0.007884655233387718 * ( +_0 +_6 -_0 -_2 )
# + 0.006972247261198151 * ( +_0 +_6 -_1 -_2 )
# + -0.0047990686872964984 * ( +_0 +_6 -_3 -_2 )
# + 0.00466468512794097 * ( +_0 +_6 -_5 -_2 )
# + 0.005649627527970672 * ( +_0 +_7 -_9 -_2 )
# + 0.007884655233387718 * ( +_0 +_7 -_13 -_2 )
# + 0.008862993883178343 * ( +_0 +_8 -_9 -_2 )
# + 0.006972247261198151 * ( +_0 +_8 -_13 -_2 )
# + 0.005649627527970672 * ( +_0 +_9 -_7 -_2 )
# + 0.008862993883178343 * ( +_0 +_9 -_8 -_2 )
# + -0.0017231065512695808 * ( +_0 +_9 -_10 -_2 )
# + 0.0016070545228063892 * ( +_0 +_9 -_12 -_2 )
# + -0.0017231065512695808 * ( +_0 +_10 -_9 -_2 )
# + -0.0047990686872964984 * ( +_0 +_10 -_13 -_2 )
# + 0.0016070545228063892 * ( +_0 +_12 -_9 -_2 )
# + 0.00466468512794097 * ( +_0 +_12 -_13 -_2 )
# + 0.007884655233387718 * ( +_0 +_13 -_7 -_2 )
# + 0.006972247261198151 * ( +_0 +_13 -_8 -_2 )
# + -0.0047990686872964984 * ( +_0 +_13 -_10 -_2 )
# + 0.00466468512794097 * ( +_0 +_13 -_12 -_2 )
# + 0.0946190154294636 * ( +_0 +_0 -_0 -_3 )
# + -0.012219528544728015 * ( +_0 +_0 -_1 -_3 )
# + 0.014608967170476739 * ( +_0 +_0 -_3 -_3 )
# + -0.0009269450853343215 * ( +_0 +_0 -_5 -_3 )
# + -0.012219528544728015 * ( +_0 +_1 -_0 -_3 )
# + 0.008100128230361306 * ( +_0 +_1 -_1 -_3 )
# + 0.009315778666083126 * ( +_0 +_1 -_3 -_3 )
# + 0.009536897503447692 * ( +_0 +_1 -_5 -_3 )
# + 0.0030483829848446495 * ( +_0 +_2 -_2 -_3 )
# + -0.00047964767956660523 * ( +_0 +_2 -_6 -_3 )
# + 0.014608967170476739 * ( +_0 +_3 -_0 -_3 )
# + 0.009315778666083126 * ( +_0 +_3 -_1 -_3 )
# + -0.005753989732202866 * ( +_0 +_3 -_3 -_3 )
# + 0.0010211888127173612 * ( +_0 +_3 -_5 -_3 )
# + 0.0023351619175533958 * ( +_0 +_4 -_4 -_3 )
# + -0.0009269450853343215 * ( +_0 +_5 -_0 -_3 )
# + 0.009536897503447692 * ( +_0 +_5 -_1 -_3 )
# + 0.0010211888127173612 * ( +_0 +_5 -_3 -_3 )
# + 0.010730825441737767 * ( +_0 +_5 -_5 -_3 )
# + -0.00047964767956660523 * ( +_0 +_6 -_2 -_3 )
# + 0.001958494169269961 * ( +_0 +_6 -_6 -_3 )
# + 0.0946190154294636 * ( +_0 +_7 -_7 -_3 )
# + -0.012219528544728015 * ( +_0 +_7 -_8 -_3 )
# + 0.014608967170476739 * ( +_0 +_7 -_10 -_3 )
# + -0.0009269450853343215 * ( +_0 +_7 -_12 -_3 )
# + -0.012219528544728015 * ( +_0 +_8 -_7 -_3 )
# + 0.008100128230361306 * ( +_0 +_8 -_8 -_3 )
# + 0.009315778666083126 * ( +_0 +_8 -_10 -_3 )
# + 0.009536897503447692 * ( +_0 +_8 -_12 -_3 )
# + 0.0030483829848446495 * ( +_0 +_9 -_9 -_3 )
# + -0.00047964767956660523 * ( +_0 +_9 -_13 -_3 )
# + 0.014608967170476739 * ( +_0 +_10 -_7 -_3 )
# + 0.009315778666083126 * ( +_0 +_10 -_8 -_3 )
# + -0.005753989732202866 * ( +_0 +_10 -_10 -_3 )
# + 0.0010211888127173612 * ( +_0 +_10 -_12 -_3 )
# + 0.0023351619175533958 * ( +_0 +_11 -_11 -_3 )
# + -0.0009269450853343215 * ( +_0 +_12 -_7 -_3 )
# + 0.009536897503447692 * ( +_0 +_12 -_8 -_3 )
# + 0.0010211888127173612 * ( +_0 +_12 -_10 -_3 )
# + 0.010730825441737767 * ( +_0 +_12 -_12 -_3 )
# + -0.00047964767956660523 * ( +_0 +_13 -_9 -_3 )
# + 0.001958494169269961 * ( +_0 +_13 -_13 -_3 )
# + 0.013357116450470148 * ( +_0 +_0 -_4 -_4 )
# + 0.016184999634614276 * ( +_0 +_1 -_4 -_4 )
# + -0.006674292946645233 * ( +_0 +_3 -_4 -_4 )
# + 0.013357116450470148 * ( +_0 +_4 -_0 -_4 )
# + 0.016184999634614276 * ( +_0 +_4 -_1 -_4 )
# + -0.006674292946645233 * ( +_0 +_4 -_3 -_4 )
# + 0.007887280475683295 * ( +_0 +_4 -_5 -_4 )
# + 0.007887280475683295 * ( +_0 +_5 -_4 -_4 )
# + 0.013357116450470148 * ( +_0 +_7 -_11 -_4 )
# + 0.016184999634614276 * ( +_0 +_8 -_11 -_4 )
# + -0.006674292946645233 * ( +_0 +_10 -_11 -_4 )
# + 0.013357116450470148 * ( +_0 +_11 -_7 -_4 )
# + 0.016184999634614276 * ( +_0 +_11 -_8 -_4 )
# + -0.006674292946645233 * ( +_0 +_11 -_10 -_4 )
# + 0.007887280475683295 * ( +_0 +_11 -_12 -_4 )
# + 0.007887280475683295 * ( +_0 +_12 -_11 -_4 )
# + -0.12573069858334246 * ( +_0 +_0 -_0 -_5 )
# + 0.019648517685924644 * ( +_0 +_0 -_1 -_5 )
# + -0.0009269450853343215 * ( +_0 +_0 -_3 -_5 )
# + 0.01723015054862705 * ( +_0 +_0 -_5 -_5 )
# + 0.019648517685924644 * ( +_0 +_1 -_0 -_5 )
# + -0.000802670183001228 * ( +_0 +_1 -_1 -_5 )
# + 0.010403185438912641 * ( +_0 +_1 -_3 -_5 )
# + 0.003111955608212695 * ( +_0 +_1 -_5 -_5 )
# + 0.00015269561283342986 * ( +_0 +_2 -_2 -_5 )
# + -0.003390868999652126 * ( +_0 +_2 -_6 -_5 )
# + -0.0009269450853343215 * ( +_0 +_3 -_0 -_5 )
# + 0.010403185438912641 * ( +_0 +_3 -_1 -_5 )
# + -0.009590599821776942 * ( +_0 +_3 -_3 -_5 )
# + 0.00012395575372052434 * ( +_0 +_3 -_5 -_5 )
# + -0.0029694370526288315 * ( +_0 +_4 -_4 -_5 )
# + 0.01723015054862705 * ( +_0 +_5 -_0 -_5 )
# + 0.003111955608212695 * ( +_0 +_5 -_1 -_5 )
# + 0.00012395575372052434 * ( +_0 +_5 -_3 -_5 )
# + 0.004015121143461755 * ( +_0 +_5 -_5 -_5 )
# + -0.003390868999652126 * ( +_0 +_6 -_2 -_5 )
# + -0.002500440798282844 * ( +_0 +_6 -_6 -_5 )
# + -0.12573069858334246 * ( +_0 +_7 -_7 -_5 )
# + 0.019648517685924644 * ( +_0 +_7 -_8 -_5 )
# + -0.0009269450853343215 * ( +_0 +_7 -_10 -_5 )
# + 0.01723015054862705 * ( +_0 +_7 -_12 -_5 )
# + 0.019648517685924644 * ( +_0 +_8 -_7 -_5 )
# + -0.000802670183001228 * ( +_0 +_8 -_8 -_5 )
# + 0.010403185438912641 * ( +_0 +_8 -_10 -_5 )
# + 0.003111955608212695 * ( +_0 +_8 -_12 -_5 )
# + 0.00015269561283342986 * ( +_0 +_9 -_9 -_5 )
# + -0.003390868999652126 * ( +_0 +_9 -_13 -_5 )
# + -0.0009269450853343215 * ( +_0 +_10 -_7 -_5 )
# + 0.010403185438912641 * ( +_0 +_10 -_8 -_5 )
# + -0.009590599821776942 * ( +_0 +_10 -_10 -_5 )
# + 0.00012395575372052434 * ( +_0 +_10 -_12 -_5 )
# + -0.0029694370526288315 * ( +_0 +_11 -_11 -_5 )
# + 0.01723015054862705 * ( +_0 +_12 -_7 -_5 )
# + 0.003111955608212695 * ( +_0 +_12 -_8 -_5 )
# + 0.00012395575372052434 * ( +_0 +_12 -_10 -_5 )
# + 0.004015121143461755 * ( +_0 +_12 -_12 -_5 )
# + -0.003390868999652126 * ( +_0 +_13 -_9 -_5 )
# + -0.002500440798282844 * ( +_0 +_13 -_13 -_5 )
# + 0.007884655233387718 * ( +_0 +_0 -_2 -_6 )
# + 0.011031738253272692 * ( +_0 +_0 -_6 -_6 )
# + 0.011531164060897629 * ( +_0 +_1 -_2 -_6 )
# + 0.009228877299505191 * ( +_0 +_1 -_6 -_6 )
# + 0.007884655233387718 * ( +_0 +_2 -_0 -_6 )
# + 0.011531164060897629 * ( +_0 +_2 -_1 -_6 )
# + -0.0025025354626466985 * ( +_0 +_2 -_3 -_6 )
# + 0.002029824090261239 * ( +_0 +_2 -_5 -_6 )
# + -0.0025025354626466985 * ( +_0 +_3 -_2 -_6 )
# + -0.006542399358200318 * ( +_0 +_3 -_6 -_6 )
# + 0.002029824090261239 * ( +_0 +_5 -_2 -_6 )
# + 0.0061160639130119375 * ( +_0 +_5 -_6 -_6 )
# + 0.011031738253272692 * ( +_0 +_6 -_0 -_6 )
# + 0.009228877299505191 * ( +_0 +_6 -_1 -_6 )
# + -0.006542399358200318 * ( +_0 +_6 -_3 -_6 )
# + 0.0061160639130119375 * ( +_0 +_6 -_5 -_6 )
# + 0.007884655233387718 * ( +_0 +_7 -_9 -_6 )
# + 0.011031738253272692 * ( +_0 +_7 -_13 -_6 )
# + 0.011531164060897629 * ( +_0 +_8 -_9 -_6 )
# + 0.009228877299505191 * ( +_0 +_8 -_13 -_6 )
# + 0.007884655233387718 * ( +_0 +_9 -_7 -_6 )
# + 0.011531164060897629 * ( +_0 +_9 -_8 -_6 )
# + -0.0025025354626466985 * ( +_0 +_9 -_10 -_6 )
# + 0.002029824090261239 * ( +_0 +_9 -_12 -_6 )
# + -0.0025025354626466985 * ( +_0 +_10 -_9 -_6 )
# + -0.006542399358200318 * ( +_0 +_10 -_13 -_6 )
# + 0.002029824090261239 * ( +_0 +_12 -_9 -_6 )
# + 0.0061160639130119375 * ( +_0 +_12 -_13 -_6 )
# + 0.011031738253272692 * ( +_0 +_13 -_7 -_6 )
# + 0.009228877299505191 * ( +_0 +_13 -_8 -_6 )
# + -0.006542399358200318 * ( +_0 +_13 -_10 -_6 )
# + 0.0061160639130119375 * ( +_0 +_13 -_12 -_6 )
# + -0.2134076033030814 * ( +_1 +_0 -_0 -_0 )
# + 0.030995282180076557 * ( +_1 +_0 -_1 -_0 )
# + -0.012219528544728015 * ( +_1 +_0 -_3 -_0 )
# + 0.019648517685924644 * ( +_1 +_0 -_5 -_0 )
# + 0.030995282180076557 * ( +_1 +_1 -_0 -_0 )
# + -0.0070130965347988015 * ( +_1 +_1 -_1 -_0 )
# + 0.004892569527201691 * ( +_1 +_1 -_3 -_0 )
# + -0.0038049801076566097 * ( +_1 +_1 -_5 -_0 )
# + -0.002072203767195658 * ( +_1 +_2 -_2 -_0 )
# + -0.003628978006755404 * ( +_1 +_2 -_6 -_0 )
# + -0.012219528544728015 * ( +_1 +_3 -_0 -_0 )
# + 0.004892569527201691 * ( +_1 +_3 -_1 -_0 )
# + -0.006714904246896566 * ( +_1 +_3 -_3 -_0 )
# + -0.0007725683281290079 * ( +_1 +_3 -_5 -_0 )
# + -0.005611471801324744 * ( +_1 +_4 -_4 -_0 )
# + 0.019648517685924644 * ( +_1 +_5 -_0 -_0 )
# + -0.0038049801076566097 * ( +_1 +_5 -_1 -_0 )
# + -0.0007725683281290079 * ( +_1 +_5 -_3 -_0 )
# + -0.0037949781085067523 * ( +_1 +_5 -_5 -_0 )
# + -0.003628978006755404 * ( +_1 +_6 -_2 -_0 )
# + -0.0045295302574999245 * ( +_1 +_6 -_6 -_0 )
# + -0.2134076033030814 * ( +_1 +_7 -_7 -_0 )
# + 0.030995282180076557 * ( +_1 +_7 -_8 -_0 )
# + -0.012219528544728015 * ( +_1 +_7 -_10 -_0 )
# + 0.019648517685924644 * ( +_1 +_7 -_12 -_0 )
# + 0.030995282180076557 * ( +_1 +_8 -_7 -_0 )
# + -0.0070130965347988015 * ( +_1 +_8 -_8 -_0 )
# + 0.004892569527201691 * ( +_1 +_8 -_10 -_0 )
# + -0.0038049801076566097 * ( +_1 +_8 -_12 -_0 )
# + -0.002072203767195658 * ( +_1 +_9 -_9 -_0 )
# + -0.003628978006755404 * ( +_1 +_9 -_13 -_0 )
# + -0.012219528544728015 * ( +_1 +_10 -_7 -_0 )
# + 0.004892569527201691 * ( +_1 +_10 -_8 -_0 )
# + -0.006714904246896566 * ( +_1 +_10 -_10 -_0 )
# + -0.0007725683281290079 * ( +_1 +_10 -_12 -_0 )
# + -0.005611471801324744 * ( +_1 +_11 -_11 -_0 )
# + 0.019648517685924644 * ( +_1 +_12 -_7 -_0 )
# + -0.0038049801076566097 * ( +_1 +_12 -_8 -_0 )
# + -0.0007725683281290079 * ( +_1 +_12 -_10 -_0 )
# + -0.0037949781085067523 * ( +_1 +_12 -_12 -_0 )
# + -0.003628978006755404 * ( +_1 +_13 -_9 -_0 )
# + -0.0045295302574999245 * ( +_1 +_13 -_13 -_0 )
# + 0.5095385394345271 * ( +_1 +_0 -_0 -_1 )
# + -0.0070130965347988015 * ( +_1 +_0 -_1 -_1 )
# + 0.008100128230361306 * ( +_1 +_0 -_3 -_1 )
# + -0.000802670183001228 * ( +_1 +_0 -_5 -_1 )
# + -0.0070130965347988015 * ( +_1 +_1 -_0 -_1 )
# + 0.3654339211083106 * ( +_1 +_1 -_1 -_1 )
# + 0.0014353824254298988 * ( +_1 +_1 -_3 -_1 )
# + 0.07247273511698589 * ( +_1 +_1 -_5 -_1 )
# + 0.32321763140432846 * ( +_1 +_2 -_2 -_1 )
# + 0.07004051019678564 * ( +_1 +_2 -_6 -_1 )
# + 0.008100128230361306 * ( +_1 +_3 -_0 -_1 )
# + 0.0014353824254298988 * ( +_1 +_3 -_1 -_1 )
# + 0.3391724393209689 * ( +_1 +_3 -_3 -_1 )
# + 0.047979150637460305 * ( +_1 +_3 -_5 -_1 )
# + 0.3749828856512694 * ( +_1 +_4 -_4 -_1 )
# + -0.000802670183001228 * ( +_1 +_5 -_0 -_1 )
# + 0.07247273511698589 * ( +_1 +_5 -_1 -_1 )
# + 0.047979150637460305 * ( +_1 +_5 -_3 -_1 )
# + 0.3081346126528673 * ( +_1 +_5 -_5 -_1 )
# + 0.07004051019678564 * ( +_1 +_6 -_2 -_1 )
# + 0.31246622012021186 * ( +_1 +_6 -_6 -_1 )
# + 0.5095385394345271 * ( +_1 +_7 -_7 -_1 )
# + -0.0070130965347988015 * ( +_1 +_7 -_8 -_1 )
# + 0.008100128230361306 * ( +_1 +_7 -_10 -_1 )
# + -0.000802670183001228 * ( +_1 +_7 -_12 -_1 )
# + -0.0070130965347988015 * ( +_1 +_8 -_7 -_1 )
# + 0.3654339211083106 * ( +_1 +_8 -_8 -_1 )
# + 0.0014353824254298988 * ( +_1 +_8 -_10 -_1 )
# + 0.07247273511698589 * ( +_1 +_8 -_12 -_1 )
# + 0.32321763140432846 * ( +_1 +_9 -_9 -_1 )
# + 0.07004051019678564 * ( +_1 +_9 -_13 -_1 )
# + 0.008100128230361306 * ( +_1 +_10 -_7 -_1 )
# + 0.0014353824254298988 * ( +_1 +_10 -_8 -_1 )
# + 0.3391724393209689 * ( +_1 +_10 -_10 -_1 )
# + 0.047979150637460305 * ( +_1 +_10 -_12 -_1 )
# + 0.3749828856512694 * ( +_1 +_11 -_11 -_1 )
# + -0.000802670183001228 * ( +_1 +_12 -_7 -_1 )
# + 0.07247273511698589 * ( +_1 +_12 -_8 -_1 )
# + 0.047979150637460305 * ( +_1 +_12 -_10 -_1 )
# + 0.3081346126528673 * ( +_1 +_12 -_12 -_1 )
# + 0.07004051019678564 * ( +_1 +_13 -_9 -_1 )
# + 0.31246622012021186 * ( +_1 +_13 -_13 -_1 )
# + 0.008862993883178343 * ( +_1 +_0 -_2 -_2 )
# + 0.011531164060897629 * ( +_1 +_0 -_6 -_2 )
# + 0.07195680238937674 * ( +_1 +_1 -_2 -_2 )
# + 0.020558848493961487 * ( +_1 +_1 -_6 -_2 )
# + 0.008862993883178343 * ( +_1 +_2 -_0 -_2 )
# + 0.07195680238937674 * ( +_1 +_2 -_1 -_2 )
# + 0.009965388623636239 * ( +_1 +_2 -_3 -_2 )
# + -0.019987981392803587 * ( +_1 +_2 -_5 -_2 )
# + 0.009965388623636239 * ( +_1 +_3 -_2 -_2 )
# + -0.03842168599794258 * ( +_1 +_3 -_6 -_2 )
# + -0.019987981392803587 * ( +_1 +_5 -_2 -_2 )
# + 0.04924915786625416 * ( +_1 +_5 -_6 -_2 )
# + 0.011531164060897629 * ( +_1 +_6 -_0 -_2 )
# + 0.020558848493961487 * ( +_1 +_6 -_1 -_2 )
# + -0.03842168599794258 * ( +_1 +_6 -_3 -_2 )
# + 0.04924915786625416 * ( +_1 +_6 -_5 -_2 )
# + 0.008862993883178343 * ( +_1 +_7 -_9 -_2 )
# + 0.011531164060897629 * ( +_1 +_7 -_13 -_2 )
# + 0.07195680238937674 * ( +_1 +_8 -_9 -_2 )
# + 0.020558848493961487 * ( +_1 +_8 -_13 -_2 )
# + 0.008862993883178343 * ( +_1 +_9 -_7 -_2 )
# + 0.07195680238937674 * ( +_1 +_9 -_8 -_2 )
# + 0.009965388623636239 * ( +_1 +_9 -_10 -_2 )
# + -0.019987981392803587 * ( +_1 +_9 -_12 -_2 )
# + 0.009965388623636239 * ( +_1 +_10 -_9 -_2 )
# + -0.03842168599794258 * ( +_1 +_10 -_13 -_2 )
# + -0.019987981392803587 * ( +_1 +_12 -_9 -_2 )
# + 0.04924915786625416 * ( +_1 +_12 -_13 -_2 )
# + 0.011531164060897629 * ( +_1 +_13 -_7 -_2 )
# + 0.020558848493961487 * ( +_1 +_13 -_8 -_2 )
# + -0.03842168599794258 * ( +_1 +_13 -_10 -_2 )
# + 0.04924915786625416 * ( +_1 +_13 -_12 -_2 )
# + -0.06735111674520967 * ( +_1 +_0 -_0 -_3 )
# + 0.004892569527201691 * ( +_1 +_0 -_1 -_3 )
# + 0.009315778666083126 * ( +_1 +_0 -_3 -_3 )
# + 0.010403185438912641 * ( +_1 +_0 -_5 -_3 )
# + 0.004892569527201691 * ( +_1 +_1 -_0 -_3 )
# + 0.0014353824254298988 * ( +_1 +_1 -_1 -_3 )
# + 0.06245057636758058 * ( +_1 +_1 -_3 -_3 )
# + 0.010501788610311615 * ( +_1 +_1 -_5 -_3 )
# + 0.003160838781312528 * ( +_1 +_2 -_2 -_3 )
# + -0.03824604091559525 * ( +_1 +_2 -_6 -_3 )
# + 0.009315778666083126 * ( +_1 +_3 -_0 -_3 )
# + 0.06245057636758058 * ( +_1 +_3 -_1 -_3 )
# + -0.05216798016451035 * ( +_1 +_3 -_3 -_3 )
# + -0.01584872080807817 * ( +_1 +_3 -_5 -_3 )
# + -0.03460828820497552 * ( +_1 +_4 -_4 -_3 )
# + 0.010403185438912641 * ( +_1 +_5 -_0 -_3 )
# + 0.010501788610311615 * ( +_1 +_5 -_1 -_3 )
# + -0.01584872080807817 * ( +_1 +_5 -_3 -_3 )
# + 0.02923069618602904 * ( +_1 +_5 -_5 -_3 )
# + -0.03824604091559525 * ( +_1 +_6 -_2 -_3 )
# + -0.0069246232003216035 * ( +_1 +_6 -_6 -_3 )
# + -0.06735111674520967 * ( +_1 +_7 -_7 -_3 )
# + 0.004892569527201691 * ( +_1 +_7 -_8 -_3 )
# + 0.009315778666083126 * ( +_1 +_7 -_10 -_3 )
# + 0.010403185438912641 * ( +_1 +_7 -_12 -_3 )
# + 0.004892569527201691 * ( +_1 +_8 -_7 -_3 )
# + 0.0014353824254298988 * ( +_1 +_8 -_8 -_3 )
# + 0.06245057636758058 * ( +_1 +_8 -_10 -_3 )
# + 0.010501788610311615 * ( +_1 +_8 -_12 -_3 )
# + 0.003160838781312528 * ( +_1 +_9 -_9 -_3 )
# + -0.03824604091559525 * ( +_1 +_9 -_13 -_3 )
# + 0.009315778666083126 * ( +_1 +_10 -_7 -_3 )
# + 0.06245057636758058 * ( +_1 +_10 -_8 -_3 )
# + -0.05216798016451035 * ( +_1 +_10 -_10 -_3 )
# + -0.01584872080807817 * ( +_1 +_10 -_12 -_3 )
# + -0.03460828820497552 * ( +_1 +_11 -_11 -_3 )
# + 0.010403185438912641 * ( +_1 +_12 -_7 -_3 )
# + 0.010501788610311615 * ( +_1 +_12 -_8 -_3 )
# + -0.01584872080807817 * ( +_1 +_12 -_10 -_3 )
# + 0.02923069618602904 * ( +_1 +_12 -_12 -_3 )
# + -0.03824604091559525 * ( +_1 +_13 -_9 -_3 )
# + -0.0069246232003216035 * ( +_1 +_13 -_13 -_3 )
# + 0.016184999634614276 * ( +_1 +_0 -_4 -_4 )
# + 0.0726213366724718 * ( +_1 +_1 -_4 -_4 )
# + -0.02331688319836267 * ( +_1 +_3 -_4 -_4 )
# + 0.016184999634614276 * ( +_1 +_4 -_0 -_4 )
# + 0.0726213366724718 * ( +_1 +_4 -_1 -_4 )
# + -0.02331688319836267 * ( +_1 +_4 -_3 -_4 )
# + 0.029498634842258842 * ( +_1 +_4 -_5 -_4 )
# + 0.029498634842258842 * ( +_1 +_5 -_4 -_4 )
# + 0.016184999634614276 * ( +_1 +_7 -_11 -_4 )
# + 0.0726213366724718 * ( +_1 +_8 -_11 -_4 )
# + -0.02331688319836267 * ( +_1 +_10 -_11 -_4 )
# + 0.016184999634614276 * ( +_1 +_11 -_7 -_4 )
# + 0.0726213366724718 * ( +_1 +_11 -_8 -_4 )
# + -0.02331688319836267 * ( +_1 +_11 -_10 -_4 )
# + 0.029498634842258842 * ( +_1 +_11 -_12 -_4 )
# + 0.029498634842258842 * ( +_1 +_12 -_11 -_4 )
# + 0.15958091192404175 * ( +_1 +_0 -_0 -_5 )
# + -0.0038049801076566097 * ( +_1 +_0 -_1 -_5 )
# + 0.009536897503447692 * ( +_1 +_0 -_3 -_5 )
# + 0.003111955608212695 * ( +_1 +_0 -_5 -_5 )
# + -0.0038049801076566097 * ( +_1 +_1 -_0 -_5 )
# + 0.07247273511698589 * ( +_1 +_1 -_1 -_5 )
# + 0.010501788610311615 * ( +_1 +_1 -_3 -_5 )
# + 0.05146939442280164 * ( +_1 +_1 -_5 -_5 )
# + 0.03846392481235126 * ( +_1 +_2 -_2 -_5 )
# + 0.03863797474319503 * ( +_1 +_2 -_6 -_5 )
# + 0.009536897503447692 * ( +_1 +_3 -_0 -_5 )
# + 0.010501788610311615 * ( +_1 +_3 -_1 -_5 )
# + 0.044681092306227396 * ( +_1 +_3 -_3 -_5 )
# + 0.030619563484429065 * ( +_1 +_3 -_5 -_5 )
# + 0.07988856173961353 * ( +_1 +_4 -_4 -_5 )
# + 0.003111955608212695 * ( +_1 +_5 -_0 -_5 )
# + 0.05146939442280164 * ( +_1 +_5 -_1 -_5 )
# + 0.030619563484429065 * ( +_1 +_5 -_3 -_5 )
# + 0.04928150986734976 * ( +_1 +_5 -_5 -_5 )
# + 0.03863797474319503 * ( +_1 +_6 -_2 -_5 )
# + 0.035046540146689995 * ( +_1 +_6 -_6 -_5 )
# + 0.15958091192404175 * ( +_1 +_7 -_7 -_5 )
# + -0.0038049801076566097 * ( +_1 +_7 -_8 -_5 )
# + 0.009536897503447692 * ( +_1 +_7 -_10 -_5 )
# + 0.003111955608212695 * ( +_1 +_7 -_12 -_5 )
# + -0.0038049801076566097 * ( +_1 +_8 -_7 -_5 )
# + 0.07247273511698589 * ( +_1 +_8 -_8 -_5 )
# + 0.010501788610311615 * ( +_1 +_8 -_10 -_5 )
# + 0.05146939442280164 * ( +_1 +_8 -_12 -_5 )
# + 0.03846392481235126 * ( +_1 +_9 -_9 -_5 )
# + 0.03863797474319503 * ( +_1 +_9 -_13 -_5 )
# + 0.009536897503447692 * ( +_1 +_10 -_7 -_5 )
# + 0.010501788610311615 * ( +_1 +_10 -_8 -_5 )
# + 0.044681092306227396 * ( +_1 +_10 -_10 -_5 )
# + 0.030619563484429065 * ( +_1 +_10 -_12 -_5 )
# + 0.07988856173961353 * ( +_1 +_11 -_11 -_5 )
# + 0.003111955608212695 * ( +_1 +_12 -_7 -_5 )
# + 0.05146939442280164 * ( +_1 +_12 -_8 -_5 )
# + 0.030619563484429065 * ( +_1 +_12 -_10 -_5 )
# + 0.04928150986734976 * ( +_1 +_12 -_12 -_5 )
# + 0.03863797474319503 * ( +_1 +_13 -_9 -_5 )
# + 0.035046540146689995 * ( +_1 +_13 -_13 -_5 )
# + 0.006972247261198151 * ( +_1 +_0 -_2 -_6 )
# + 0.009228877299505191 * ( +_1 +_0 -_6 -_6 )
# + 0.020558848493961487 * ( +_1 +_1 -_2 -_6 )
# + 0.030995211624204936 * ( +_1 +_1 -_6 -_6 )
# + 0.006972247261198151 * ( +_1 +_2 -_0 -_6 )
# + 0.020558848493961487 * ( +_1 +_2 -_1 -_6 )
# + -0.016963338534790373 * ( +_1 +_2 -_3 -_6 )
# + 0.017592159882129785 * ( +_1 +_2 -_5 -_6 )
# + -0.016963338534790373 * ( +_1 +_3 -_2 -_6 )
# + -0.008324018548720034 * ( +_1 +_3 -_6 -_6 )
# + 0.017592159882129785 * ( +_1 +_5 -_2 -_6 )
# + -0.004730325378975572 * ( +_1 +_5 -_6 -_6 )
# + 0.009228877299505191 * ( +_1 +_6 -_0 -_6 )
# + 0.030995211624204936 * ( +_1 +_6 -_1 -_6 )
# + -0.008324018548720034 * ( +_1 +_6 -_3 -_6 )
# + -0.004730325378975572 * ( +_1 +_6 -_5 -_6 )
# + 0.006972247261198151 * ( +_1 +_7 -_9 -_6 )
# + 0.009228877299505191 * ( +_1 +_7 -_13 -_6 )
# + 0.020558848493961487 * ( +_1 +_8 -_9 -_6 )
# + 0.030995211624204936 * ( +_1 +_8 -_13 -_6 )
# + 0.006972247261198151 * ( +_1 +_9 -_7 -_6 )
# + 0.020558848493961487 * ( +_1 +_9 -_8 -_6 )
# + -0.016963338534790373 * ( +_1 +_9 -_10 -_6 )
# + 0.017592159882129785 * ( +_1 +_9 -_12 -_6 )
# + -0.016963338534790373 * ( +_1 +_10 -_9 -_6 )
# + -0.008324018548720034 * ( +_1 +_10 -_13 -_6 )
# + 0.017592159882129785 * ( +_1 +_12 -_9 -_6 )
# + -0.004730325378975572 * ( +_1 +_12 -_13 -_6 )
# + 0.009228877299505191 * ( +_1 +_13 -_7 -_6 )
# + 0.030995211624204936 * ( +_1 +_13 -_8 -_6 )
# + -0.008324018548720034 * ( +_1 +_13 -_10 -_6 )
# + -0.004730325378975572 * ( +_1 +_13 -_12 -_6 )
# + 0.005649627527970672 * ( +_2 +_0 -_2 -_0 )
# + 0.007884655233387718 * ( +_2 +_0 -_6 -_0 )
# + 0.008862993883178343 * ( +_2 +_1 -_2 -_0 )
# + 0.006972247261198151 * ( +_2 +_1 -_6 -_0 )
# + 0.005649627527970672 * ( +_2 +_2 -_0 -_0 )
# + 0.008862993883178343 * ( +_2 +_2 -_1 -_0 )
# + -0.0017231065512695808 * ( +_2 +_2 -_3 -_0 )
# + 0.0016070545228063892 * ( +_2 +_2 -_5 -_0 )
# + -0.0017231065512695808 * ( +_2 +_3 -_2 -_0 )
# + -0.0047990686872964984 * ( +_2 +_3 -_6 -_0 )
# + 0.0016070545228063892 * ( +_2 +_5 -_2 -_0 )
# + 0.00466468512794097 * ( +_2 +_5 -_6 -_0 )
# + 0.007884655233387718 * ( +_2 +_6 -_0 -_0 )
# + 0.006972247261198151 * ( +_2 +_6 -_1 -_0 )
# + -0.0047990686872964984 * ( +_2 +_6 -_3 -_0 )
# + 0.00466468512794097 * ( +_2 +_6 -_5 -_0 )
# + 0.005649627527970672 * ( +_2 +_7 -_9 -_0 )
# + 0.007884655233387718 * ( +_2 +_7 -_13 -_0 )
# + 0.008862993883178343 * ( +_2 +_8 -_9 -_0 )
# + 0.006972247261198151 * ( +_2 +_8 -_13 -_0 )
# + 0.005649627527970672 * ( +_2 +_9 -_7 -_0 )
# + 0.008862993883178343 * ( +_2 +_9 -_8 -_0 )
# + -0.0017231065512695808 * ( +_2 +_9 -_10 -_0 )
# + 0.0016070545228063892 * ( +_2 +_9 -_12 -_0 )
# + -0.0017231065512695808 * ( +_2 +_10 -_9 -_0 )
# + -0.0047990686872964984 * ( +_2 +_10 -_13 -_0 )
# + 0.0016070545228063892 * ( +_2 +_12 -_9 -_0 )
# + 0.00466468512794097 * ( +_2 +_12 -_13 -_0 )
# + 0.007884655233387718 * ( +_2 +_13 -_7 -_0 )
# + 0.006972247261198151 * ( +_2 +_13 -_8 -_0 )
# + -0.0047990686872964984 * ( +_2 +_13 -_10 -_0 )
# + 0.00466468512794097 * ( +_2 +_13 -_12 -_0 )
# + 0.008862993883178343 * ( +_2 +_0 -_2 -_1 )
# + 0.011531164060897629 * ( +_2 +_0 -_6 -_1 )
# + 0.07195680238937674 * ( +_2 +_1 -_2 -_1 )
# + 0.020558848493961487 * ( +_2 +_1 -_6 -_1 )
# + 0.008862993883178343 * ( +_2 +_2 -_0 -_1 )
# + 0.07195680238937674 * ( +_2 +_2 -_1 -_1 )
# + 0.009965388623636239 * ( +_2 +_2 -_3 -_1 )
# + -0.019987981392803587 * ( +_2 +_2 -_5 -_1 )
# + 0.009965388623636239 * ( +_2 +_3 -_2 -_1 )
# + -0.03842168599794258 * ( +_2 +_3 -_6 -_1 )
# + -0.019987981392803587 * ( +_2 +_5 -_2 -_1 )
# + 0.04924915786625416 * ( +_2 +_5 -_6 -_1 )
# + 0.011531164060897629 * ( +_2 +_6 -_0 -_1 )
# + 0.020558848493961487 * ( +_2 +_6 -_1 -_1 )
# + -0.03842168599794258 * ( +_2 +_6 -_3 -_1 )
# + 0.04924915786625416 * ( +_2 +_6 -_5 -_1 )
# + 0.008862993883178343 * ( +_2 +_7 -_9 -_1 )
# + 0.011531164060897629 * ( +_2 +_7 -_13 -_1 )
# + 0.07195680238937674 * ( +_2 +_8 -_9 -_1 )
# + 0.020558848493961487 * ( +_2 +_8 -_13 -_1 )
# + 0.008862993883178343 * ( +_2 +_9 -_7 -_1 )
# + 0.07195680238937674 * ( +_2 +_9 -_8 -_1 )
# + 0.009965388623636239 * ( +_2 +_9 -_10 -_1 )
# + -0.019987981392803587 * ( +_2 +_9 -_12 -_1 )
# + 0.009965388623636239 * ( +_2 +_10 -_9 -_1 )
# + -0.03842168599794258 * ( +_2 +_10 -_13 -_1 )
# + -0.019987981392803587 * ( +_2 +_12 -_9 -_1 )
# + 0.04924915786625416 * ( +_2 +_12 -_13 -_1 )
# + 0.011531164060897629 * ( +_2 +_13 -_7 -_1 )
# + 0.020558848493961487 * ( +_2 +_13 -_8 -_1 )
# + -0.03842168599794258 * ( +_2 +_13 -_10 -_1 )
# + 0.04924915786625416 * ( +_2 +_13 -_12 -_1 )
# + 0.40105776423433714 * ( +_2 +_0 -_0 -_2 )
# + -0.002072203767195658 * ( +_2 +_0 -_1 -_2 )
# + 0.0030483829848446495 * ( +_2 +_0 -_3 -_2 )
# + 0.00015269561283342986 * ( +_2 +_0 -_5 -_2 )
# + -0.002072203767195658 * ( +_2 +_1 -_0 -_2 )
# + 0.32321763140432846 * ( +_2 +_1 -_1 -_2 )
# + 0.003160838781312528 * ( +_2 +_1 -_3 -_2 )
# + 0.03846392481235126 * ( +_2 +_1 -_5 -_2 )
# + 0.31708937537789933 * ( +_2 +_2 -_2 -_2 )
# + 0.04550555366051583 * ( +_2 +_2 -_6 -_2 )
# + 0.0030483829848446495 * ( +_2 +_3 -_0 -_2 )
# + 0.003160838781312528 * ( +_2 +_3 -_1 -_2 )
# + 0.3000888396267996 * ( +_2 +_3 -_3 -_2 )
# + 0.02146806388413065 * ( +_2 +_3 -_5 -_2 )
# + 0.3149843805260763 * ( +_2 +_4 -_4 -_2 )
# + 0.00015269561283342986 * ( +_2 +_5 -_0 -_2 )
# + 0.03846392481235126 * ( +_2 +_5 -_1 -_2 )
# + 0.02146806388413065 * ( +_2 +_5 -_3 -_2 )
# + 0.28648655490815406 * ( +_2 +_5 -_5 -_2 )
# + 0.04550555366051583 * ( +_2 +_6 -_2 -_2 )
# + 0.3055683941275754 * ( +_2 +_6 -_6 -_2 )
# + 0.40105776423433714 * ( +_2 +_7 -_7 -_2 )
# + -0.002072203767195658 * ( +_2 +_7 -_8 -_2 )
# + 0.0030483829848446495 * ( +_2 +_7 -_10 -_2 )
# + 0.00015269561283342986 * ( +_2 +_7 -_12 -_2 )
# + -0.002072203767195658 * ( +_2 +_8 -_7 -_2 )
# + 0.32321763140432846 * ( +_2 +_8 -_8 -_2 )
# + 0.003160838781312528 * ( +_2 +_8 -_10 -_2 )
# + 0.03846392481235126 * ( +_2 +_8 -_12 -_2 )
# + 0.31708937537789933 * ( +_2 +_9 -_9 -_2 )
# + 0.04550555366051583 * ( +_2 +_9 -_13 -_2 )
# + 0.0030483829848446495 * ( +_2 +_10 -_7 -_2 )
# + 0.003160838781312528 * ( +_2 +_10 -_8 -_2 )
# + 0.3000888396267996 * ( +_2 +_10 -_10 -_2 )
# + 0.02146806388413065 * ( +_2 +_10 -_12 -_2 )
# + 0.3149843805260763 * ( +_2 +_11 -_11 -_2 )
# + 0.00015269561283342986 * ( +_2 +_12 -_7 -_2 )
# + 0.03846392481235126 * ( +_2 +_12 -_8 -_2 )
# + 0.02146806388413065 * ( +_2 +_12 -_10 -_2 )
# + 0.28648655490815406 * ( +_2 +_12 -_12 -_2 )
# + 0.04550555366051583 * ( +_2 +_13 -_9 -_2 )
# + 0.3055683941275754 * ( +_2 +_13 -_13 -_2 )
# + -0.0017231065512695808 * ( +_2 +_0 -_2 -_3 )
# + -0.0025025354626466985 * ( +_2 +_0 -_6 -_3 )
# + 0.009965388623636239 * ( +_2 +_1 -_2 -_3 )
# + -0.016963338534790373 * ( +_2 +_1 -_6 -_3 )
# + -0.0017231065512695808 * ( +_2 +_2 -_0 -_3 )
# + 0.009965388623636239 * ( +_2 +_2 -_1 -_3 )
# + 0.02382189367468165 * ( +_2 +_2 -_3 -_3 )
# + -0.014435337712107027 * ( +_2 +_2 -_5 -_3 )
# + 0.02382189367468165 * ( +_2 +_3 -_2 -_3 )
# + 0.0009583108548685334 * ( +_2 +_3 -_6 -_3 )
# + -0.014435337712107027 * ( +_2 +_5 -_2 -_3 )
# + 0.024035705430841853 * ( +_2 +_5 -_6 -_3 )
# + -0.0025025354626466985 * ( +_2 +_6 -_0 -_3 )
# + -0.016963338534790373 * ( +_2 +_6 -_1 -_3 )
# + 0.0009583108548685334 * ( +_2 +_6 -_3 -_3 )
# + 0.024035705430841853 * ( +_2 +_6 -_5 -_3 )
# + -0.0017231065512695808 * ( +_2 +_7 -_9 -_3 )
# + -0.0025025354626466985 * ( +_2 +_7 -_13 -_3 )
# + 0.009965388623636239 * ( +_2 +_8 -_9 -_3 )
# + -0.016963338534790373 * ( +_2 +_8 -_13 -_3 )
# + -0.0017231065512695808 * ( +_2 +_9 -_7 -_3 )
# + 0.009965388623636239 * ( +_2 +_9 -_8 -_3 )
# + 0.02382189367468165 * ( +_2 +_9 -_10 -_3 )
# + -0.014435337712107027 * ( +_2 +_9 -_12 -_3 )
# + 0.02382189367468165 * ( +_2 +_10 -_9 -_3 )
# + 0.0009583108548685334 * ( +_2 +_10 -_13 -_3 )
# + -0.014435337712107027 * ( +_2 +_12 -_9 -_3 )
# + 0.024035705430841853 * ( +_2 +_12 -_13 -_3 )
# + -0.0025025354626466985 * ( +_2 +_13 -_7 -_3 )
# + -0.016963338534790373 * ( +_2 +_13 -_8 -_3 )
# + 0.0009583108548685334 * ( +_2 +_13 -_10 -_3 )
# + 0.024035705430841853 * ( +_2 +_13 -_12 -_3 )
# + 0.014433156703532747 * ( +_2 +_2 -_4 -_4 )
# + 0.014433156703532747 * ( +_2 +_4 -_2 -_4 )
# + 0.011855702248728135 * ( +_2 +_4 -_6 -_4 )
# + 0.011855702248728135 * ( +_2 +_6 -_4 -_4 )
# + 0.014433156703532747 * ( +_2 +_9 -_11 -_4 )
# + 0.014433156703532747 * ( +_2 +_11 -_9 -_4 )
# + 0.011855702248728135 * ( +_2 +_11 -_13 -_4 )
# + 0.011855702248728135 * ( +_2 +_13 -_11 -_4 )
# + 0.0016070545228063892 * ( +_2 +_0 -_2 -_5 )
# + 0.002029824090261239 * ( +_2 +_0 -_6 -_5 )
# + -0.019987981392803587 * ( +_2 +_1 -_2 -_5 )
# + 0.017592159882129785 * ( +_2 +_1 -_6 -_5 )
# + 0.0016070545228063892 * ( +_2 +_2 -_0 -_5 )
# + -0.019987981392803587 * ( +_2 +_2 -_1 -_5 )
# + -0.014435337712107027 * ( +_2 +_2 -_3 -_5 )
# + 0.03562296862657816 * ( +_2 +_2 -_5 -_5 )
# + -0.014435337712107027 * ( +_2 +_3 -_2 -_5 )
# + 0.0223855355113857 * ( +_2 +_3 -_6 -_5 )
# + 0.03562296862657816 * ( +_2 +_5 -_2 -_5 )
# + -0.03254846231637297 * ( +_2 +_5 -_6 -_5 )
# + 0.002029824090261239 * ( +_2 +_6 -_0 -_5 )
# + 0.017592159882129785 * ( +_2 +_6 -_1 -_5 )
# + 0.0223855355113857 * ( +_2 +_6 -_3 -_5 )
# + -0.03254846231637297 * ( +_2 +_6 -_5 -_5 )
# + 0.0016070545228063892 * ( +_2 +_7 -_9 -_5 )
# + 0.002029824090261239 * ( +_2 +_7 -_13 -_5 )
# + -0.019987981392803587 * ( +_2 +_8 -_9 -_5 )
# + 0.017592159882129785 * ( +_2 +_8 -_13 -_5 )
# + 0.0016070545228063892 * ( +_2 +_9 -_7 -_5 )
# + -0.019987981392803587 * ( +_2 +_9 -_8 -_5 )
# + -0.014435337712107027 * ( +_2 +_9 -_10 -_5 )
# + 0.03562296862657816 * ( +_2 +_9 -_12 -_5 )
# + -0.014435337712107027 * ( +_2 +_10 -_9 -_5 )
# + 0.0223855355113857 * ( +_2 +_10 -_13 -_5 )
# + 0.03562296862657816 * ( +_2 +_12 -_9 -_5 )
# + -0.03254846231637297 * ( +_2 +_12 -_13 -_5 )
# + 0.002029824090261239 * ( +_2 +_13 -_7 -_5 )
# + 0.017592159882129785 * ( +_2 +_13 -_8 -_5 )
# + 0.0223855355113857 * ( +_2 +_13 -_10 -_5 )
# + -0.03254846231637297 * ( +_2 +_13 -_12 -_5 )
# + 0.18183235367517545 * ( +_2 +_0 -_0 -_6 )
# + -0.003628978006755404 * ( +_2 +_0 -_1 -_6 )
# + -0.00047964767956660523 * ( +_2 +_0 -_3 -_6 )
# + -0.003390868999652126 * ( +_2 +_0 -_5 -_6 )
# + -0.003628978006755404 * ( +_2 +_1 -_0 -_6 )
# + 0.07004051019678564 * ( +_2 +_1 -_1 -_6 )
# + -0.03824604091559525 * ( +_2 +_1 -_3 -_6 )
# + 0.03863797474319503 * ( +_2 +_1 -_5 -_6 )
# + 0.04550555366051583 * ( +_2 +_2 -_2 -_6 )
# + 0.07637550732075002 * ( +_2 +_2 -_6 -_6 )
# + -0.00047964767956660523 * ( +_2 +_3 -_0 -_6 )
# + -0.03824604091559525 * ( +_2 +_3 -_1 -_6 )
# + 0.07991915562182955 * ( +_2 +_3 -_3 -_6 )
# + 0.03933542712319877 * ( +_2 +_3 -_5 -_6 )
# + 0.0950224922453338 * ( +_2 +_4 -_4 -_6 )
# + -0.003390868999652126 * ( +_2 +_5 -_0 -_6 )
# + 0.03863797474319503 * ( +_2 +_5 -_1 -_6 )
# + 0.03933542712319877 * ( +_2 +_5 -_3 -_6 )
# + 0.019140546968560348 * ( +_2 +_5 -_5 -_6 )
# + 0.07637550732075002 * ( +_2 +_6 -_2 -_6 )
# + 0.04630824432548887 * ( +_2 +_6 -_6 -_6 )
# + 0.18183235367517545 * ( +_2 +_7 -_7 -_6 )
# + -0.003628978006755404 * ( +_2 +_7 -_8 -_6 )
# + -0.00047964767956660523 * ( +_2 +_7 -_10 -_6 )
# + -0.003390868999652126 * ( +_2 +_7 -_12 -_6 )
# + -0.003628978006755404 * ( +_2 +_8 -_7 -_6 )
# + 0.07004051019678564 * ( +_2 +_8 -_8 -_6 )
# + -0.03824604091559525 * ( +_2 +_8 -_10 -_6 )
# + 0.03863797474319503 * ( +_2 +_8 -_12 -_6 )
# + 0.04550555366051583 * ( +_2 +_9 -_9 -_6 )
# + 0.07637550732075002 * ( +_2 +_9 -_13 -_6 )
# + -0.00047964767956660523 * ( +_2 +_10 -_7 -_6 )
# + -0.03824604091559525 * ( +_2 +_10 -_8 -_6 )
# + 0.07991915562182955 * ( +_2 +_10 -_10 -_6 )
# + 0.03933542712319877 * ( +_2 +_10 -_12 -_6 )
# + 0.0950224922453338 * ( +_2 +_11 -_11 -_6 )
# + -0.003390868999652126 * ( +_2 +_12 -_7 -_6 )
# + 0.03863797474319503 * ( +_2 +_12 -_8 -_6 )
# + 0.03933542712319877 * ( +_2 +_12 -_10 -_6 )
# + 0.019140546968560348 * ( +_2 +_12 -_12 -_6 )
# + 0.07637550732075002 * ( +_2 +_13 -_9 -_6 )
# + 0.04630824432548887 * ( +_2 +_13 -_13 -_6 )
# + 0.0946190154294636 * ( +_3 +_0 -_0 -_0 )
# + -0.012219528544728015 * ( +_3 +_0 -_1 -_0 )
# + 0.014608967170476739 * ( +_3 +_0 -_3 -_0 )
# + -0.0009269450853343215 * ( +_3 +_0 -_5 -_0 )
# + -0.012219528544728015 * ( +_3 +_1 -_0 -_0 )
# + 0.008100128230361306 * ( +_3 +_1 -_1 -_0 )
# + 0.009315778666083126 * ( +_3 +_1 -_3 -_0 )
# + 0.009536897503447692 * ( +_3 +_1 -_5 -_0 )
# + 0.0030483829848446495 * ( +_3 +_2 -_2 -_0 )
# + -0.00047964767956660523 * ( +_3 +_2 -_6 -_0 )
# + 0.014608967170476739 * ( +_3 +_3 -_0 -_0 )
# + 0.009315778666083126 * ( +_3 +_3 -_1 -_0 )
# + -0.005753989732202866 * ( +_3 +_3 -_3 -_0 )
# + 0.0010211888127173612 * ( +_3 +_3 -_5 -_0 )
# + 0.0023351619175533958 * ( +_3 +_4 -_4 -_0 )
# + -0.0009269450853343215 * ( +_3 +_5 -_0 -_0 )
# + 0.009536897503447692 * ( +_3 +_5 -_1 -_0 )
# + 0.0010211888127173612 * ( +_3 +_5 -_3 -_0 )
# + 0.010730825441737767 * ( +_3 +_5 -_5 -_0 )
# + -0.00047964767956660523 * ( +_3 +_6 -_2 -_0 )
# + 0.001958494169269961 * ( +_3 +_6 -_6 -_0 )
# + 0.0946190154294636 * ( +_3 +_7 -_7 -_0 )
# + -0.012219528544728015 * ( +_3 +_7 -_8 -_0 )
# + 0.014608967170476739 * ( +_3 +_7 -_10 -_0 )
# + -0.0009269450853343215 * ( +_3 +_7 -_12 -_0 )
# + -0.012219528544728015 * ( +_3 +_8 -_7 -_0 )
# + 0.008100128230361306 * ( +_3 +_8 -_8 -_0 )
# + 0.009315778666083126 * ( +_3 +_8 -_10 -_0 )
# + 0.009536897503447692 * ( +_3 +_8 -_12 -_0 )
# + 0.0030483829848446495 * ( +_3 +_9 -_9 -_0 )
# + -0.00047964767956660523 * ( +_3 +_9 -_13 -_0 )
# + 0.014608967170476739 * ( +_3 +_10 -_7 -_0 )
# + 0.009315778666083126 * ( +_3 +_10 -_8 -_0 )
# + -0.005753989732202866 * ( +_3 +_10 -_10 -_0 )
# + 0.0010211888127173612 * ( +_3 +_10 -_12 -_0 )
# + 0.0023351619175533958 * ( +_3 +_11 -_11 -_0 )
# + -0.0009269450853343215 * ( +_3 +_12 -_7 -_0 )
# + 0.009536897503447692 * ( +_3 +_12 -_8 -_0 )
# + 0.0010211888127173612 * ( +_3 +_12 -_10 -_0 )
# + 0.010730825441737767 * ( +_3 +_12 -_12 -_0 )
# + -0.00047964767956660523 * ( +_3 +_13 -_9 -_0 )
# + 0.001958494169269961 * ( +_3 +_13 -_13 -_0 )
# + -0.06735111674520967 * ( +_3 +_0 -_0 -_1 )
# + 0.004892569527201691 * ( +_3 +_0 -_1 -_1 )
# + 0.009315778666083126 * ( +_3 +_0 -_3 -_1 )
# + 0.010403185438912641 * ( +_3 +_0 -_5 -_1 )
# + 0.004892569527201691 * ( +_3 +_1 -_0 -_1 )
# + 0.0014353824254298988 * ( +_3 +_1 -_1 -_1 )
# + 0.06245057636758058 * ( +_3 +_1 -_3 -_1 )
# + 0.010501788610311615 * ( +_3 +_1 -_5 -_1 )
# + 0.003160838781312528 * ( +_3 +_2 -_2 -_1 )
# + -0.03824604091559525 * ( +_3 +_2 -_6 -_1 )
# + 0.009315778666083126 * ( +_3 +_3 -_0 -_1 )
# + 0.06245057636758058 * ( +_3 +_3 -_1 -_1 )
# + -0.05216798016451035 * ( +_3 +_3 -_3 -_1 )
# + -0.01584872080807817 * ( +_3 +_3 -_5 -_1 )
# + -0.03460828820497552 * ( +_3 +_4 -_4 -_1 )
# + 0.010403185438912641 * ( +_3 +_5 -_0 -_1 )
# + 0.010501788610311615 * ( +_3 +_5 -_1 -_1 )
# + -0.01584872080807817 * ( +_3 +_5 -_3 -_1 )
# + 0.02923069618602904 * ( +_3 +_5 -_5 -_1 )
# + -0.03824604091559525 * ( +_3 +_6 -_2 -_1 )
# + -0.0069246232003216035 * ( +_3 +_6 -_6 -_1 )
# + -0.06735111674520967 * ( +_3 +_7 -_7 -_1 )
# + 0.004892569527201691 * ( +_3 +_7 -_8 -_1 )
# + 0.009315778666083126 * ( +_3 +_7 -_10 -_1 )
# + 0.010403185438912641 * ( +_3 +_7 -_12 -_1 )
# + 0.004892569527201691 * ( +_3 +_8 -_7 -_1 )
# + 0.0014353824254298988 * ( +_3 +_8 -_8 -_1 )
# + 0.06245057636758058 * ( +_3 +_8 -_10 -_1 )
# + 0.010501788610311615 * ( +_3 +_8 -_12 -_1 )
# + 0.003160838781312528 * ( +_3 +_9 -_9 -_1 )
# + -0.03824604091559525 * ( +_3 +_9 -_13 -_1 )
# + 0.009315778666083126 * ( +_3 +_10 -_7 -_1 )
# + 0.06245057636758058 * ( +_3 +_10 -_8 -_1 )
# + -0.05216798016451035 * ( +_3 +_10 -_10 -_1 )
# + -0.01584872080807817 * ( +_3 +_10 -_12 -_1 )
# + -0.03460828820497552 * ( +_3 +_11 -_11 -_1 )
# + 0.010403185438912641 * ( +_3 +_12 -_7 -_1 )
# + 0.010501788610311615 * ( +_3 +_12 -_8 -_1 )
# + -0.01584872080807817 * ( +_3 +_12 -_10 -_1 )
# + 0.02923069618602904 * ( +_3 +_12 -_12 -_1 )
# + -0.03824604091559525 * ( +_3 +_13 -_9 -_1 )
# + -0.0069246232003216035 * ( +_3 +_13 -_13 -_1 )
# + -0.0017231065512695808 * ( +_3 +_0 -_2 -_2 )
# + -0.0025025354626466985 * ( +_3 +_0 -_6 -_2 )
# + 0.009965388623636239 * ( +_3 +_1 -_2 -_2 )
# + -0.016963338534790373 * ( +_3 +_1 -_6 -_2 )
# + -0.0017231065512695808 * ( +_3 +_2 -_0 -_2 )
# + 0.009965388623636239 * ( +_3 +_2 -_1 -_2 )
# + 0.02382189367468165 * ( +_3 +_2 -_3 -_2 )
# + -0.014435337712107027 * ( +_3 +_2 -_5 -_2 )
# + 0.02382189367468165 * ( +_3 +_3 -_2 -_2 )
# + 0.0009583108548685334 * ( +_3 +_3 -_6 -_2 )
# + -0.014435337712107027 * ( +_3 +_5 -_2 -_2 )
# + 0.024035705430841853 * ( +_3 +_5 -_6 -_2 )
# + -0.0025025354626466985 * ( +_3 +_6 -_0 -_2 )
# + -0.016963338534790373 * ( +_3 +_6 -_1 -_2 )
# + 0.0009583108548685334 * ( +_3 +_6 -_3 -_2 )
# + 0.024035705430841853 * ( +_3 +_6 -_5 -_2 )
# + -0.0017231065512695808 * ( +_3 +_7 -_9 -_2 )
# + -0.0025025354626466985 * ( +_3 +_7 -_13 -_2 )
# + 0.009965388623636239 * ( +_3 +_8 -_9 -_2 )
# + -0.016963338534790373 * ( +_3 +_8 -_13 -_2 )
# + -0.0017231065512695808 * ( +_3 +_9 -_7 -_2 )
# + 0.009965388623636239 * ( +_3 +_9 -_8 -_2 )
# + 0.02382189367468165 * ( +_3 +_9 -_10 -_2 )
# + -0.014435337712107027 * ( +_3 +_9 -_12 -_2 )
# + 0.02382189367468165 * ( +_3 +_10 -_9 -_2 )
# + 0.0009583108548685334 * ( +_3 +_10 -_13 -_2 )
# + -0.014435337712107027 * ( +_3 +_12 -_9 -_2 )
# + 0.024035705430841853 * ( +_3 +_12 -_13 -_2 )
# + -0.0025025354626466985 * ( +_3 +_13 -_7 -_2 )
# + -0.016963338534790373 * ( +_3 +_13 -_8 -_2 )
# + 0.0009583108548685334 * ( +_3 +_13 -_10 -_2 )
# + 0.024035705430841853 * ( +_3 +_13 -_12 -_2 )
# + 0.5020228139470131 * ( +_3 +_0 -_0 -_3 )
# + -0.006714904246896566 * ( +_3 +_0 -_1 -_3 )
# + -0.005753989732202866 * ( +_3 +_0 -_3 -_3 )
# + -0.009590599821776942 * ( +_3 +_0 -_5 -_3 )
# + -0.006714904246896566 * ( +_3 +_1 -_0 -_3 )
# + 0.3391724393209689 * ( +_3 +_1 -_1 -_3 )
# + -0.05216798016451035 * ( +_3 +_1 -_3 -_3 )
# + 0.044681092306227396 * ( +_3 +_1 -_5 -_3 )
# + 0.3000888396267996 * ( +_3 +_2 -_2 -_3 )
# + 0.07991915562182955 * ( +_3 +_2 -_6 -_3 )
# + -0.005753989732202866 * ( +_3 +_3 -_0 -_3 )
# + -0.05216798016451035 * ( +_3 +_3 -_1 -_3 )
# + 0.3913848698001695 * ( +_3 +_3 -_3 -_3 )
# + 0.06043422850371158 * ( +_3 +_3 -_5 -_3 )
# + 0.3647000452756474 * ( +_3 +_4 -_4 -_3 )
# + -0.009590599821776942 * ( +_3 +_5 -_0 -_3 )
# + 0.044681092306227396 * ( +_3 +_5 -_1 -_3 )
# + 0.06043422850371158 * ( +_3 +_5 -_3 -_3 )
# + 0.27572352525455873 * ( +_3 +_5 -_5 -_3 )
# + 0.07991915562182955 * ( +_3 +_6 -_2 -_3 )
# + 0.3040835411195416 * ( +_3 +_6 -_6 -_3 )
# + 0.5020228139470131 * ( +_3 +_7 -_7 -_3 )
# + -0.006714904246896566 * ( +_3 +_7 -_8 -_3 )
# + -0.005753989732202866 * ( +_3 +_7 -_10 -_3 )
# + -0.009590599821776942 * ( +_3 +_7 -_12 -_3 )
# + -0.006714904246896566 * ( +_3 +_8 -_7 -_3 )
# + 0.3391724393209689 * ( +_3 +_8 -_8 -_3 )
# + -0.05216798016451035 * ( +_3 +_8 -_10 -_3 )
# + 0.044681092306227396 * ( +_3 +_8 -_12 -_3 )
# + 0.3000888396267996 * ( +_3 +_9 -_9 -_3 )
# + 0.07991915562182955 * ( +_3 +_9 -_13 -_3 )
# + -0.005753989732202866 * ( +_3 +_10 -_7 -_3 )
# + -0.05216798016451035 * ( +_3 +_10 -_8 -_3 )
# + 0.3913848698001695 * ( +_3 +_10 -_10 -_3 )
# + 0.06043422850371158 * ( +_3 +_10 -_12 -_3 )
# + 0.3647000452756474 * ( +_3 +_11 -_11 -_3 )
# + -0.009590599821776942 * ( +_3 +_12 -_7 -_3 )
# + 0.044681092306227396 * ( +_3 +_12 -_8 -_3 )
# + 0.06043422850371158 * ( +_3 +_12 -_10 -_3 )
# + 0.27572352525455873 * ( +_3 +_12 -_12 -_3 )
# + 0.07991915562182955 * ( +_3 +_13 -_9 -_3 )
# + 0.3040835411195416 * ( +_3 +_13 -_13 -_3 )
# + -0.006674292946645233 * ( +_3 +_0 -_4 -_4 )
# + -0.02331688319836267 * ( +_3 +_1 -_4 -_4 )
# + 0.027794429823241783 * ( +_3 +_3 -_4 -_4 )
# + -0.006674292946645233 * ( +_3 +_4 -_0 -_4 )
# + -0.02331688319836267 * ( +_3 +_4 -_1 -_4 )
# + 0.027794429823241783 * ( +_3 +_4 -_3 -_4 )
# + -0.000724362471316495 * ( +_3 +_4 -_5 -_4 )
# + -0.000724362471316495 * ( +_3 +_5 -_4 -_4 )
# + -0.006674292946645233 * ( +_3 +_7 -_11 -_4 )
# + -0.02331688319836267 * ( +_3 +_8 -_11 -_4 )
# + 0.027794429823241783 * ( +_3 +_10 -_11 -_4 )
# + -0.006674292946645233 * ( +_3 +_11 -_7 -_4 )
# + -0.02331688319836267 * ( +_3 +_11 -_8 -_4 )
# + 0.027794429823241783 * ( +_3 +_11 -_10 -_4 )
# + -0.000724362471316495 * ( +_3 +_11 -_12 -_4 )
# + -0.000724362471316495 * ( +_3 +_12 -_11 -_4 )
# + 0.10767965294469878 * ( +_3 +_0 -_0 -_5 )
# + -0.0007725683281290079 * ( +_3 +_0 -_1 -_5 )
# + 0.0010211888127173612 * ( +_3 +_0 -_3 -_5 )
# + 0.00012395575372052434 * ( +_3 +_0 -_5 -_5 )
# + -0.0007725683281290079 * ( +_3 +_1 -_0 -_5 )
# + 0.047979150637460305 * ( +_3 +_1 -_1 -_5 )
# + -0.01584872080807817 * ( +_3 +_1 -_3 -_5 )
# + 0.030619563484429065 * ( +_3 +_1 -_5 -_5 )
# + 0.02146806388413065 * ( +_3 +_2 -_2 -_5 )
# + 0.03933542712319877 * ( +_3 +_2 -_6 -_5 )
# + 0.0010211888127173612 * ( +_3 +_3 -_0 -_5 )
# + -0.01584872080807817 * ( +_3 +_3 -_1 -_5 )
# + 0.06043422850371158 * ( +_3 +_3 -_3 -_5 )
# + 0.034475312935390676 * ( +_3 +_3 -_5 -_5 )
# + 0.05802701431850952 * ( +_3 +_4 -_4 -_5 )
# + 0.00012395575372052434 * ( +_3 +_5 -_0 -_5 )
# + 0.030619563484429065 * ( +_3 +_5 -_1 -_5 )
# + 0.034475312935390676 * ( +_3 +_5 -_3 -_5 )
# + 0.02212838619216169 * ( +_3 +_5 -_5 -_5 )
# + 0.03933542712319877 * ( +_3 +_6 -_2 -_5 )
# + 0.02021134033500935 * ( +_3 +_6 -_6 -_5 )
# + 0.10767965294469878 * ( +_3 +_7 -_7 -_5 )
# + -0.0007725683281290079 * ( +_3 +_7 -_8 -_5 )
# + 0.0010211888127173612 * ( +_3 +_7 -_10 -_5 )
# + 0.00012395575372052434 * ( +_3 +_7 -_12 -_5 )
# + -0.0007725683281290079 * ( +_3 +_8 -_7 -_5 )
# + 0.047979150637460305 * ( +_3 +_8 -_8 -_5 )
# + -0.01584872080807817 * ( +_3 +_8 -_10 -_5 )
# + 0.030619563484429065 * ( +_3 +_8 -_12 -_5 )
# + 0.02146806388413065 * ( +_3 +_9 -_9 -_5 )
# + 0.03933542712319877 * ( +_3 +_9 -_13 -_5 )
# + 0.0010211888127173612 * ( +_3 +_10 -_7 -_5 )
# + -0.01584872080807817 * ( +_3 +_10 -_8 -_5 )
# + 0.06043422850371158 * ( +_3 +_10 -_10 -_5 )
# + 0.034475312935390676 * ( +_3 +_10 -_12 -_5 )
# + 0.05802701431850952 * ( +_3 +_11 -_11 -_5 )
# + 0.00012395575372052434 * ( +_3 +_12 -_7 -_5 )
# + 0.030619563484429065 * ( +_3 +_12 -_8 -_5 )
# + 0.034475312935390676 * ( +_3 +_12 -_10 -_5 )
# + 0.02212838619216169 * ( +_3 +_12 -_12 -_5 )
# + 0.03933542712319877 * ( +_3 +_13 -_9 -_5 )
# + 0.02021134033500935 * ( +_3 +_13 -_13 -_5 )
# + -0.0047990686872964984 * ( +_3 +_0 -_2 -_6 )
# + -0.006542399358200318 * ( +_3 +_0 -_6 -_6 )
# + -0.03842168599794258 * ( +_3 +_1 -_2 -_6 )
# + -0.008324018548720034 * ( +_3 +_1 -_6 -_6 )
# + -0.0047990686872964984 * ( +_3 +_2 -_0 -_6 )
# + -0.03842168599794258 * ( +_3 +_2 -_1 -_6 )
# + 0.0009583108548685334 * ( +_3 +_2 -_3 -_6 )
# + 0.0223855355113857 * ( +_3 +_2 -_5 -_6 )
# + 0.0009583108548685334 * ( +_3 +_3 -_2 -_6 )
# + 0.0344006967228713 * ( +_3 +_3 -_6 -_6 )
# + 0.0223855355113857 * ( +_3 +_5 -_2 -_6 )
# + -0.02925558575660717 * ( +_3 +_5 -_6 -_6 )
# + -0.006542399358200318 * ( +_3 +_6 -_0 -_6 )
# + -0.008324018548720034 * ( +_3 +_6 -_1 -_6 )
# + 0.0344006967228713 * ( +_3 +_6 -_3 -_6 )
# + -0.02925558575660717 * ( +_3 +_6 -_5 -_6 )
# + -0.0047990686872964984 * ( +_3 +_7 -_9 -_6 )
# + -0.006542399358200318 * ( +_3 +_7 -_13 -_6 )
# + -0.03842168599794258 * ( +_3 +_8 -_9 -_6 )
# + -0.008324018548720034 * ( +_3 +_8 -_13 -_6 )
# + -0.0047990686872964984 * ( +_3 +_9 -_7 -_6 )
# + -0.03842168599794258 * ( +_3 +_9 -_8 -_6 )
# + 0.0009583108548685334 * ( +_3 +_9 -_10 -_6 )
# + 0.0223855355113857 * ( +_3 +_9 -_12 -_6 )
# ...
# + 0.019252838693428455 * ( +_12 +_5 -_4 -_11 )
# + 0.007887280475683295 * ( +_12 +_7 -_11 -_11 )
# + 0.029498634842258842 * ( +_12 +_8 -_11 -_11 )
# + -0.000724362471316495 * ( +_12 +_10 -_11 -_11 )
# + 0.007887280475683295 * ( +_12 +_11 -_7 -_11 )
# + 0.029498634842258842 * ( +_12 +_11 -_8 -_11 )
# + -0.000724362471316495 * ( +_12 +_11 -_10 -_11 )
# + 0.019252838693428455 * ( +_12 +_11 -_12 -_11 )
# + 0.019252838693428455 * ( +_12 +_12 -_11 -_11 )
# + 0.4063723467380974 * ( +_12 +_0 -_0 -_12 )
# + -0.0037949781085067523 * ( +_12 +_0 -_1 -_12 )
# + 0.010730825441737767 * ( +_12 +_0 -_3 -_12 )
# + 0.004015121143461755 * ( +_12 +_0 -_5 -_12 )
# + -0.0037949781085067523 * ( +_12 +_1 -_0 -_12 )
# + 0.3081346126528673 * ( +_12 +_1 -_1 -_12 )
# + 0.02923069618602904 * ( +_12 +_1 -_3 -_12 )
# + 0.04928150986734976 * ( +_12 +_1 -_5 -_12 )
# + 0.28648655490815406 * ( +_12 +_2 -_2 -_12 )
# + 0.019140546968560348 * ( +_12 +_2 -_6 -_12 )
# + 0.010730825441737767 * ( +_12 +_3 -_0 -_12 )
# + 0.02923069618602904 * ( +_12 +_3 -_1 -_12 )
# + 0.27572352525455873 * ( +_12 +_3 -_3 -_12 )
# + 0.02212838619216169 * ( +_12 +_3 -_5 -_12 )
# + 0.29531480733218896 * ( +_12 +_4 -_4 -_12 )
# + 0.004015121143461755 * ( +_12 +_5 -_0 -_12 )
# + 0.04928150986734976 * ( +_12 +_5 -_1 -_12 )
# + 0.02212838619216169 * ( +_12 +_5 -_3 -_12 )
# + 0.30034969472407386 * ( +_12 +_5 -_5 -_12 )
# + 0.019140546968560348 * ( +_12 +_6 -_2 -_12 )
# + 0.284138857158958 * ( +_12 +_6 -_6 -_12 )
# + 0.4063723467380974 * ( +_12 +_7 -_7 -_12 )
# + -0.0037949781085067523 * ( +_12 +_7 -_8 -_12 )
# + 0.010730825441737767 * ( +_12 +_7 -_10 -_12 )
# + 0.004015121143461755 * ( +_12 +_7 -_12 -_12 )
# + -0.0037949781085067523 * ( +_12 +_8 -_7 -_12 )
# + 0.3081346126528673 * ( +_12 +_8 -_8 -_12 )
# + 0.02923069618602904 * ( +_12 +_8 -_10 -_12 )
# + 0.04928150986734976 * ( +_12 +_8 -_12 -_12 )
# + 0.28648655490815406 * ( +_12 +_9 -_9 -_12 )
# + 0.019140546968560348 * ( +_12 +_9 -_13 -_12 )
# + 0.010730825441737767 * ( +_12 +_10 -_7 -_12 )
# + 0.02923069618602904 * ( +_12 +_10 -_8 -_12 )
# + 0.27572352525455873 * ( +_12 +_10 -_10 -_12 )
# + 0.02212838619216169 * ( +_12 +_10 -_12 -_12 )
# + 0.29531480733218896 * ( +_12 +_11 -_11 -_12 )
# + 0.004015121143461755 * ( +_12 +_12 -_7 -_12 )
# + 0.04928150986734976 * ( +_12 +_12 -_8 -_12 )
# + 0.02212838619216169 * ( +_12 +_12 -_10 -_12 )
# + 0.30034969472407386 * ( +_12 +_12 -_12 -_12 )
# + 0.019140546968560348 * ( +_12 +_13 -_9 -_12 )
# + 0.284138857158958 * ( +_12 +_13 -_13 -_12 )
# + 0.00466468512794097 * ( +_12 +_0 -_2 -_13 )
# + 0.0061160639130119375 * ( +_12 +_0 -_6 -_13 )
# + 0.04924915786625416 * ( +_12 +_1 -_2 -_13 )
# + -0.004730325378975572 * ( +_12 +_1 -_6 -_13 )
# + 0.00466468512794097 * ( +_12 +_2 -_0 -_13 )
# + 0.04924915786625416 * ( +_12 +_2 -_1 -_13 )
# + 0.024035705430841853 * ( +_12 +_2 -_3 -_13 )
# + -0.03254846231637297 * ( +_12 +_2 -_5 -_13 )
# + 0.024035705430841853 * ( +_12 +_3 -_2 -_13 )
# + -0.02925558575660717 * ( +_12 +_3 -_6 -_13 )
# + -0.03254846231637297 * ( +_12 +_5 -_2 -_13 )
# + 0.058306531163094394 * ( +_12 +_5 -_6 -_13 )
# + 0.0061160639130119375 * ( +_12 +_6 -_0 -_13 )
# + -0.004730325378975572 * ( +_12 +_6 -_1 -_13 )
# + -0.02925558575660717 * ( +_12 +_6 -_3 -_13 )
# + 0.058306531163094394 * ( +_12 +_6 -_5 -_13 )
# + 0.00466468512794097 * ( +_12 +_7 -_9 -_13 )
# + 0.0061160639130119375 * ( +_12 +_7 -_13 -_13 )
# + 0.04924915786625416 * ( +_12 +_8 -_9 -_13 )
# + -0.004730325378975572 * ( +_12 +_8 -_13 -_13 )
# + 0.00466468512794097 * ( +_12 +_9 -_7 -_13 )
# + 0.04924915786625416 * ( +_12 +_9 -_8 -_13 )
# + 0.024035705430841853 * ( +_12 +_9 -_10 -_13 )
# + -0.03254846231637297 * ( +_12 +_9 -_12 -_13 )
# + 0.024035705430841853 * ( +_12 +_10 -_9 -_13 )
# + -0.02925558575660717 * ( +_12 +_10 -_13 -_13 )
# + -0.03254846231637297 * ( +_12 +_12 -_9 -_13 )
# + 0.058306531163094394 * ( +_12 +_12 -_13 -_13 )
# + 0.0061160639130119375 * ( +_12 +_13 -_7 -_13 )
# + -0.004730325378975572 * ( +_12 +_13 -_8 -_13 )
# + -0.02925558575660717 * ( +_12 +_13 -_10 -_13 )
# + 0.058306531163094394 * ( +_12 +_13 -_12 -_13 )
# + 0.007884655233387718 * ( +_13 +_0 -_2 -_7 )
# + 0.011031738253272692 * ( +_13 +_0 -_6 -_7 )
# + 0.011531164060897629 * ( +_13 +_1 -_2 -_7 )
# + 0.009228877299505191 * ( +_13 +_1 -_6 -_7 )
# + 0.007884655233387718 * ( +_13 +_2 -_0 -_7 )
# + 0.011531164060897629 * ( +_13 +_2 -_1 -_7 )
# + -0.0025025354626466985 * ( +_13 +_2 -_3 -_7 )
# + 0.002029824090261239 * ( +_13 +_2 -_5 -_7 )
# + -0.0025025354626466985 * ( +_13 +_3 -_2 -_7 )
# + -0.006542399358200318 * ( +_13 +_3 -_6 -_7 )
# + 0.002029824090261239 * ( +_13 +_5 -_2 -_7 )
# + 0.0061160639130119375 * ( +_13 +_5 -_6 -_7 )
# + 0.011031738253272692 * ( +_13 +_6 -_0 -_7 )
# + 0.009228877299505191 * ( +_13 +_6 -_1 -_7 )
# + -0.006542399358200318 * ( +_13 +_6 -_3 -_7 )
# + 0.0061160639130119375 * ( +_13 +_6 -_5 -_7 )
# + 0.007884655233387718 * ( +_13 +_7 -_9 -_7 )
# + 0.011031738253272692 * ( +_13 +_7 -_13 -_7 )
# + 0.011531164060897629 * ( +_13 +_8 -_9 -_7 )
# + 0.009228877299505191 * ( +_13 +_8 -_13 -_7 )
# + 0.007884655233387718 * ( +_13 +_9 -_7 -_7 )
# + 0.011531164060897629 * ( +_13 +_9 -_8 -_7 )
# + -0.0025025354626466985 * ( +_13 +_9 -_10 -_7 )
# + 0.002029824090261239 * ( +_13 +_9 -_12 -_7 )
# + -0.0025025354626466985 * ( +_13 +_10 -_9 -_7 )
# + -0.006542399358200318 * ( +_13 +_10 -_13 -_7 )
# + 0.002029824090261239 * ( +_13 +_12 -_9 -_7 )
# + 0.0061160639130119375 * ( +_13 +_12 -_13 -_7 )
# + 0.011031738253272692 * ( +_13 +_13 -_7 -_7 )
# + 0.009228877299505191 * ( +_13 +_13 -_8 -_7 )
# + -0.006542399358200318 * ( +_13 +_13 -_10 -_7 )
# + 0.0061160639130119375 * ( +_13 +_13 -_12 -_7 )
# + 0.006972247261198151 * ( +_13 +_0 -_2 -_8 )
# + 0.009228877299505191 * ( +_13 +_0 -_6 -_8 )
# + 0.020558848493961487 * ( +_13 +_1 -_2 -_8 )
# + 0.030995211624204936 * ( +_13 +_1 -_6 -_8 )
# + 0.006972247261198151 * ( +_13 +_2 -_0 -_8 )
# + 0.020558848493961487 * ( +_13 +_2 -_1 -_8 )
# + -0.016963338534790373 * ( +_13 +_2 -_3 -_8 )
# + 0.017592159882129785 * ( +_13 +_2 -_5 -_8 )
# + -0.016963338534790373 * ( +_13 +_3 -_2 -_8 )
# + -0.008324018548720034 * ( +_13 +_3 -_6 -_8 )
# + 0.017592159882129785 * ( +_13 +_5 -_2 -_8 )
# + -0.004730325378975572 * ( +_13 +_5 -_6 -_8 )
# + 0.009228877299505191 * ( +_13 +_6 -_0 -_8 )
# + 0.030995211624204936 * ( +_13 +_6 -_1 -_8 )
# + -0.008324018548720034 * ( +_13 +_6 -_3 -_8 )
# + -0.004730325378975572 * ( +_13 +_6 -_5 -_8 )
# + 0.006972247261198151 * ( +_13 +_7 -_9 -_8 )
# + 0.009228877299505191 * ( +_13 +_7 -_13 -_8 )
# + 0.020558848493961487 * ( +_13 +_8 -_9 -_8 )
# + 0.030995211624204936 * ( +_13 +_8 -_13 -_8 )
# + 0.006972247261198151 * ( +_13 +_9 -_7 -_8 )
# + 0.020558848493961487 * ( +_13 +_9 -_8 -_8 )
# + -0.016963338534790373 * ( +_13 +_9 -_10 -_8 )
# + 0.017592159882129785 * ( +_13 +_9 -_12 -_8 )
# + -0.016963338534790373 * ( +_13 +_10 -_9 -_8 )
# + -0.008324018548720034 * ( +_13 +_10 -_13 -_8 )
# + 0.017592159882129785 * ( +_13 +_12 -_9 -_8 )
# + -0.004730325378975572 * ( +_13 +_12 -_13 -_8 )
# + 0.009228877299505191 * ( +_13 +_13 -_7 -_8 )
# + 0.030995211624204936 * ( +_13 +_13 -_8 -_8 )
# + -0.008324018548720034 * ( +_13 +_13 -_10 -_8 )
# + -0.004730325378975572 * ( +_13 +_13 -_12 -_8 )
# + 0.18183235367517545 * ( +_13 +_0 -_0 -_9 )
# + -0.003628978006755404 * ( +_13 +_0 -_1 -_9 )
# + -0.00047964767956660523 * ( +_13 +_0 -_3 -_9 )
# + -0.003390868999652126 * ( +_13 +_0 -_5 -_9 )
# + -0.003628978006755404 * ( +_13 +_1 -_0 -_9 )
# + 0.07004051019678564 * ( +_13 +_1 -_1 -_9 )
# + -0.03824604091559525 * ( +_13 +_1 -_3 -_9 )
# + 0.03863797474319503 * ( +_13 +_1 -_5 -_9 )
# + 0.04550555366051583 * ( +_13 +_2 -_2 -_9 )
# + 0.07637550732075002 * ( +_13 +_2 -_6 -_9 )
# + -0.00047964767956660523 * ( +_13 +_3 -_0 -_9 )
# + -0.03824604091559525 * ( +_13 +_3 -_1 -_9 )
# + 0.07991915562182955 * ( +_13 +_3 -_3 -_9 )
# + 0.03933542712319877 * ( +_13 +_3 -_5 -_9 )
# + 0.0950224922453338 * ( +_13 +_4 -_4 -_9 )
# + -0.003390868999652126 * ( +_13 +_5 -_0 -_9 )
# + 0.03863797474319503 * ( +_13 +_5 -_1 -_9 )
# + 0.03933542712319877 * ( +_13 +_5 -_3 -_9 )
# + 0.019140546968560348 * ( +_13 +_5 -_5 -_9 )
# + 0.07637550732075002 * ( +_13 +_6 -_2 -_9 )
# + 0.04630824432548887 * ( +_13 +_6 -_6 -_9 )
# + 0.18183235367517545 * ( +_13 +_7 -_7 -_9 )
# + -0.003628978006755404 * ( +_13 +_7 -_8 -_9 )
# + -0.00047964767956660523 * ( +_13 +_7 -_10 -_9 )
# + -0.003390868999652126 * ( +_13 +_7 -_12 -_9 )
# + -0.003628978006755404 * ( +_13 +_8 -_7 -_9 )
# + 0.07004051019678564 * ( +_13 +_8 -_8 -_9 )
# + -0.03824604091559525 * ( +_13 +_8 -_10 -_9 )
# + 0.03863797474319503 * ( +_13 +_8 -_12 -_9 )
# + 0.04550555366051583 * ( +_13 +_9 -_9 -_9 )
# + 0.07637550732075002 * ( +_13 +_9 -_13 -_9 )
# + -0.00047964767956660523 * ( +_13 +_10 -_7 -_9 )
# + -0.03824604091559525 * ( +_13 +_10 -_8 -_9 )
# + 0.07991915562182955 * ( +_13 +_10 -_10 -_9 )
# + 0.03933542712319877 * ( +_13 +_10 -_12 -_9 )
# + 0.0950224922453338 * ( +_13 +_11 -_11 -_9 )
# + -0.003390868999652126 * ( +_13 +_12 -_7 -_9 )
# + 0.03863797474319503 * ( +_13 +_12 -_8 -_9 )
# + 0.03933542712319877 * ( +_13 +_12 -_10 -_9 )
# + 0.019140546968560348 * ( +_13 +_12 -_12 -_9 )
# + 0.07637550732075002 * ( +_13 +_13 -_9 -_9 )
# + 0.04630824432548887 * ( +_13 +_13 -_13 -_9 )
# + -0.0047990686872964984 * ( +_13 +_0 -_2 -_10 )
# + -0.006542399358200318 * ( +_13 +_0 -_6 -_10 )
# + -0.03842168599794258 * ( +_13 +_1 -_2 -_10 )
# + -0.008324018548720034 * ( +_13 +_1 -_6 -_10 )
# + -0.0047990686872964984 * ( +_13 +_2 -_0 -_10 )
# + -0.03842168599794258 * ( +_13 +_2 -_1 -_10 )
# + 0.0009583108548685334 * ( +_13 +_2 -_3 -_10 )
# + 0.0223855355113857 * ( +_13 +_2 -_5 -_10 )
# + 0.0009583108548685334 * ( +_13 +_3 -_2 -_10 )
# + 0.0344006967228713 * ( +_13 +_3 -_6 -_10 )
# + 0.0223855355113857 * ( +_13 +_5 -_2 -_10 )
# + -0.02925558575660717 * ( +_13 +_5 -_6 -_10 )
# + -0.006542399358200318 * ( +_13 +_6 -_0 -_10 )
# + -0.008324018548720034 * ( +_13 +_6 -_1 -_10 )
# + 0.0344006967228713 * ( +_13 +_6 -_3 -_10 )
# + -0.02925558575660717 * ( +_13 +_6 -_5 -_10 )
# + -0.0047990686872964984 * ( +_13 +_7 -_9 -_10 )
# + -0.006542399358200318 * ( +_13 +_7 -_13 -_10 )
# + -0.03842168599794258 * ( +_13 +_8 -_9 -_10 )
# + -0.008324018548720034 * ( +_13 +_8 -_13 -_10 )
# + -0.0047990686872964984 * ( +_13 +_9 -_7 -_10 )
# + -0.03842168599794258 * ( +_13 +_9 -_8 -_10 )
# + 0.0009583108548685334 * ( +_13 +_9 -_10 -_10 )
# + 0.0223855355113857 * ( +_13 +_9 -_12 -_10 )
# + 0.0009583108548685334 * ( +_13 +_10 -_9 -_10 )
# + 0.0344006967228713 * ( +_13 +_10 -_13 -_10 )
# + 0.0223855355113857 * ( +_13 +_12 -_9 -_10 )
# + -0.02925558575660717 * ( +_13 +_12 -_13 -_10 )
# + -0.006542399358200318 * ( +_13 +_13 -_7 -_10 )
# + -0.008324018548720034 * ( +_13 +_13 -_8 -_10 )
# + 0.0344006967228713 * ( +_13 +_13 -_10 -_10 )
# + -0.02925558575660717 * ( +_13 +_13 -_12 -_10 )
# + 0.011855702248728135 * ( +_13 +_2 -_4 -_11 )
# + 0.011855702248728135 * ( +_13 +_4 -_2 -_11 )
# + 0.012174811792423208 * ( +_13 +_4 -_6 -_11 )
# + 0.012174811792423208 * ( +_13 +_6 -_4 -_11 )
# + 0.011855702248728135 * ( +_13 +_9 -_11 -_11 )
# + 0.011855702248728135 * ( +_13 +_11 -_9 -_11 )
# + 0.012174811792423208 * ( +_13 +_11 -_13 -_11 )
# + 0.012174811792423208 * ( +_13 +_13 -_11 -_11 )
# + 0.00466468512794097 * ( +_13 +_0 -_2 -_12 )
# + 0.0061160639130119375 * ( +_13 +_0 -_6 -_12 )
# + 0.04924915786625416 * ( +_13 +_1 -_2 -_12 )
# + -0.004730325378975572 * ( +_13 +_1 -_6 -_12 )
# + 0.00466468512794097 * ( +_13 +_2 -_0 -_12 )
# + 0.04924915786625416 * ( +_13 +_2 -_1 -_12 )
# + 0.024035705430841853 * ( +_13 +_2 -_3 -_12 )
# + -0.03254846231637297 * ( +_13 +_2 -_5 -_12 )
# + 0.024035705430841853 * ( +_13 +_3 -_2 -_12 )
# + -0.02925558575660717 * ( +_13 +_3 -_6 -_12 )
# + -0.03254846231637297 * ( +_13 +_5 -_2 -_12 )
# + 0.058306531163094394 * ( +_13 +_5 -_6 -_12 )
# + 0.0061160639130119375 * ( +_13 +_6 -_0 -_12 )
# + -0.004730325378975572 * ( +_13 +_6 -_1 -_12 )
# + -0.02925558575660717 * ( +_13 +_6 -_3 -_12 )
# + 0.058306531163094394 * ( +_13 +_6 -_5 -_12 )
# + 0.00466468512794097 * ( +_13 +_7 -_9 -_12 )
# + 0.0061160639130119375 * ( +_13 +_7 -_13 -_12 )
# + 0.04924915786625416 * ( +_13 +_8 -_9 -_12 )
# + -0.004730325378975572 * ( +_13 +_8 -_13 -_12 )
# + 0.00466468512794097 * ( +_13 +_9 -_7 -_12 )
# + 0.04924915786625416 * ( +_13 +_9 -_8 -_12 )
# + 0.024035705430841853 * ( +_13 +_9 -_10 -_12 )
# + -0.03254846231637297 * ( +_13 +_9 -_12 -_12 )
# + 0.024035705430841853 * ( +_13 +_10 -_9 -_12 )
# + -0.02925558575660717 * ( +_13 +_10 -_13 -_12 )
# + -0.03254846231637297 * ( +_13 +_12 -_9 -_12 )
# + 0.058306531163094394 * ( +_13 +_12 -_13 -_12 )
# + 0.0061160639130119375 * ( +_13 +_13 -_7 -_12 )
# + -0.004730325378975572 * ( +_13 +_13 -_8 -_12 )
# + -0.02925558575660717 * ( +_13 +_13 -_10 -_12 )
# + 0.058306531163094394 * ( +_13 +_13 -_12 -_12 )
# + 0.4347103345071293 * ( +_13 +_0 -_0 -_13 )
# + -0.0045295302574999245 * ( +_13 +_0 -_1 -_13 )
# + 0.001958494169269961 * ( +_13 +_0 -_3 -_13 )
# + -0.002500440798282844 * ( +_13 +_0 -_5 -_13 )
# + -0.0045295302574999245 * ( +_13 +_1 -_0 -_13 )
# + 0.31246622012021186 * ( +_13 +_1 -_1 -_13 )
# + -0.0069246232003216035 * ( +_13 +_1 -_3 -_13 )
# + 0.035046540146689995 * ( +_13 +_1 -_5 -_13 )
# + 0.3055683941275754 * ( +_13 +_2 -_2 -_13 )
# + 0.04630824432548887 * ( +_13 +_2 -_6 -_13 )
# + 0.001958494169269961 * ( +_13 +_3 -_0 -_13 )
# + -0.0069246232003216035 * ( +_13 +_3 -_1 -_13 )
# + 0.3040835411195416 * ( +_13 +_3 -_3 -_13 )
# + 0.02021134033500935 * ( +_13 +_3 -_5 -_13 )
# + 0.31233544691162274 * ( +_13 +_4 -_4 -_13 )
# + -0.002500440798282844 * ( +_13 +_5 -_0 -_13 )
# + 0.035046540146689995 * ( +_13 +_5 -_1 -_13 )
# + 0.02021134033500935 * ( +_13 +_5 -_3 -_13 )
# + 0.284138857158958 * ( +_13 +_5 -_5 -_13 )
# + 0.04630824432548887 * ( +_13 +_6 -_2 -_13 )
# + 0.30981153723167376 * ( +_13 +_6 -_6 -_13 )
# + 0.4347103345071293 * ( +_13 +_7 -_7 -_13 )
# + -0.0045295302574999245 * ( +_13 +_7 -_8 -_13 )
# + 0.001958494169269961 * ( +_13 +_7 -_10 -_13 )
# + -0.002500440798282844 * ( +_13 +_7 -_12 -_13 )
# + -0.0045295302574999245 * ( +_13 +_8 -_7 -_13 )
# + 0.31246622012021186 * ( +_13 +_8 -_8 -_13 )
# + -0.0069246232003216035 * ( +_13 +_8 -_10 -_13 )
# + 0.035046540146689995 * ( +_13 +_8 -_12 -_13 )
# + 0.3055683941275754 * ( +_13 +_9 -_9 -_13 )
# + 0.04630824432548887 * ( +_13 +_9 -_13 -_13 )
# + 0.001958494169269961 * ( +_13 +_10 -_7 -_13 )
# + -0.0069246232003216035 * ( +_13 +_10 -_8 -_13 )
# + 0.3040835411195416 * ( +_13 +_10 -_10 -_13 )
# + 0.02021134033500935 * ( +_13 +_10 -_12 -_13 )
# + 0.31233544691162274 * ( +_13 +_11 -_11 -_13 )
# + -0.002500440798282844 * ( +_13 +_12 -_7 -_13 )
# + 0.035046540146689995 * ( +_13 +_12 -_8 -_13 )
# + 0.02021134033500935 * ( +_13 +_12 -_10 -_13 )
# + 0.284138857158958 * ( +_13 +_12 -_12 -_13 )
# + 0.04630824432548887 * ( +_13 +_13 -_9 -_13 )
# + 0.30981153723167376 * ( +_13 +_13 -_13 -_13 )
# + -33.0214769847188 * ( +_0 -_0 )
# + 0.5671633167720119 * ( +_0 -_1 )
# + -0.23867444191504203 * ( +_0 -_3 )
# + 0.31772255651187736 * ( +_0 -_5 )
# + 0.5671633167720127 * ( +_1 -_0 )
# + -7.717879433282242 * ( +_1 -_1 )
# + 0.44551763579857406 * ( +_1 -_3 )
# + -1.408782637947514 * ( +_1 -_5 )
# + -6.380229531857711 * ( +_2 -_2 )
# + -1.7157545456455097 * ( +_2 -_6 )
# + -0.23867444191504206 * ( +_3 -_0 )
# + 0.44551763579857445 * ( +_3 -_1 )
# + -7.008551868710885 * ( +_3 -_3 )
# + -1.0726530785718829 * ( +_3 -_5 )
# + -7.4744573295342995 * ( +_4 -_4 )
# + 0.3177225565118776 * ( +_5 -_0 )
# + -1.408782637947513 * ( +_5 -_1 )
# + -1.0726530785718842 * ( +_5 -_3 )
# + -5.375953015983558 * ( +_5 -_5 )
# + -1.71575454564551 * ( +_6 -_2 )
# + -5.6179002186511235 * ( +_6 -_6 )
# + -33.0214769847188 * ( +_7 -_7 )
# + 0.5671633167720119 * ( +_7 -_8 )
# + -0.23867444191504203 * ( +_7 -_10 )
# + 0.31772255651187736 * ( +_7 -_12 )
# + 0.5671633167720127 * ( +_8 -_7 )
# + -7.717879433282242 * ( +_8 -_8 )
# + 0.44551763579857406 * ( +_8 -_10 )
# + -1.408782637947514 * ( +_8 -_12 )
# + -6.380229531857711 * ( +_9 -_9 )
# + -1.7157545456455097 * ( +_9 -_13 )
# + -0.23867444191504206 * ( +_10 -_7 )
# + 0.44551763579857445 * ( +_10 -_8 )
# + -7.008551868710885 * ( +_10 -_10 )
# + -1.0726530785718829 * ( +_10 -_12 )
# + -7.4744573295342995 * ( +_11 -_11 )
# + 0.3177225565118776 * ( +_12 -_7 )
# + -1.408782637947513 * ( +_12 -_8 )
# + -1.0726530785718842 * ( +_12 -_10 )
# + -5.375953015983558 * ( +_12 -_12 )
# + -1.71575454564551 * ( +_13 -_9 )
# + -5.6179002186511235 * ( +_13 -_13 )
# Energies: (<qiskit_nature.second_q.problems.electronic_structure_result.ElectronicStructureResult object at 0x173f82c60>, -75.72907801309533, 9.180509891119375)

# %% [markdown]
# ## H2O GS energy as function of distance and angle

# %%
# Constants and initialization
known_R = 0.9584
known_theta = 104.5 * pi / 180  # Convert to radians
N = 11 # choose an odd number so that the known minimum is included in linspace
Rs = linspace(0.6, 1.4, N) * known_R  # Generate scaled bond lengths
thetas = linspace(0.6, 1.4, N) * known_theta  # Generate scaled bond angles
energies = np.zeros((len(Rs), len(thetas)))  # Initialize energy grid

transformer_H2O = ActiveSpaceTransformer(num_electrons=4, num_spatial_orbitals=4)
# transformer_H2O = None

# Calculate energies
for i, R in enumerate(Rs):
    for j, theta in enumerate(thetas):
        atom_str = (
            f"O .0 .0 .0; "
            f"H {R * sin(theta / 2):.3f} {R * cos(theta / 2):.3f} .0; "
            f"H {-R * sin(theta / 2):.3f} {R * cos(theta / 2):.3f} .0"
        )
        H2O_qub, H2O_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer_H2O)
        energies[i, j] = get_exact_energies(H2O_es)[1]
        print('GS energy=',energies[i, j],'R=',R,'theta=',theta)

# Create meshgrid and contour plot
X, Y = np.meshgrid(Rs, thetas * (180/pi))  # Create 2D grid for Rs and thetas
plt.figure(figsize=(len(Rs), len(thetas)))
contour = plt.contourf(X, Y, energies.T, levels=50, cmap='viridis')  # Transpose energies for correct orientation
plt.colorbar(contour, label='Energy [Hartree]')
plt.xlabel('R [Angstrom]')
plt.ylabel('Theta [degrees]')

# Add a point of known vals (should be middle vals in linspace)
plt.scatter(known_R, known_theta * (180/pi), color='red', marker='o')
plt.text(known_R - 0.1, known_theta * (180/pi) -3, f"Known min at (R,Theta)=(0.9584,104.5). E={energies[N//2][N//2]:.4f}", color='red', fontsize=10)

# Add a point of simulation min vals
min_index = np.unravel_index(np.argmin(energies, axis=None), energies.shape)
x_min, y_min, z_min = Rs[min_index[0]], thetas[min_index[1]], energies[min_index]
plt.scatter(x_min, y_min * (180/pi), color='cyan', marker='o')
plt.text(x_min - 0.1, y_min * (180/pi) -3, f"Simulation min E={z_min:.4f}", color='cyan', fontsize=10)


plt.title('Contour Plot of H2O Energy')
plt.show()
# Out:
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.44887119067008 R= 0.57504 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.53075124951238 R= 0.57504 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.58437472265221 R= 0.57504 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.62804141011527 R= 0.57504 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.65373347747227 R= 0.57504 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.67145533066234 R= 0.57504 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.6777216961599 R= 0.57504 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.68200169779591 R= 0.57504 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.68327487192289 R= 0.57504 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.68667069577278 R= 0.57504 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.68411032799807 R= 0.57504 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -74.97408877910588 R= 0.651712 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.03989292890472 R= 0.651712 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.08502910982816 R= 0.651712 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.12168150742019 R= 0.651712 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.13977854125012 R= 0.651712 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.15137032233092 R= 0.651712 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.15692237392734 R= 0.651712 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.15988888497989 R= 0.651712 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.15923321777362 R= 0.651712 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.15242544762837 R= 0.651712 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.15082726866711 R= 0.651712 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.28301478603093 R= 0.728384 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.3388321160396 R= 0.728384 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.37716311381155 R= 0.728384 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.40530408251627 R= 0.728384 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.42201835090833 R= 0.728384 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.42971770484733 R= 0.728384 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.43193288002254 R= 0.728384 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.42891235387846 R= 0.728384 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.42271668146967 R= 0.728384 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.41552606592026 R= 0.728384 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.4073933204958 R= 0.728384 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.46431062921424 R= 0.805056 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.51046366825958 R= 0.805056 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.54246188979846 R= 0.805056 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.56446679385485 R= 0.805056 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.57721942632139 R= 0.805056 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.5824959449352 R= 0.805056 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.5807222976303 R= 0.805056 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.57413754983523 R= 0.805056 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.56513115809702 R= 0.805056 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.55393629145931 R= 0.805056 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.54198889337782 R= 0.805056 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.56984564723818 R= 0.881728 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.60200735834383 R= 0.881728 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.62906751266226 R= 0.881728 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.64649154717605 R= 0.881728 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.65581804105643 R= 0.881728 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.65782654595402 R= 0.881728 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.65421034177466 R= 0.881728 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.64517135236775 R= 0.881728 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6331433150355 R= 0.881728 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.61818158287758 R= 0.881728 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.60331534667887 R= 0.881728 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.61782742876335 R= 0.9583999999999999 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.64380964181453 R= 0.9583999999999999 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.66612720976599 R= 0.9583999999999999 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.68009735677032 R= 0.9583999999999999 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.68653483063936 R= 0.9583999999999999 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6863533525917 R= 0.9583999999999999 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.68028563834065 R= 0.9583999999999999 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.66928321907098 R= 0.9583999999999999 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.65454073449892 R= 0.9583999999999999 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.63717032757091 R= 0.9583999999999999 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.61870042173356 R= 0.9583999999999999 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.63247636744319 R= 1.035072 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.66108259778115 R= 1.035072 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.67168356202207 R= 1.035072 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.68272495168318 R= 1.035072 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.68699491867748 R= 1.035072 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.68517295730072 R= 1.035072 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6777292213729 R= 1.035072 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.66523637679173 R= 1.035072 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.64893274160724 R= 1.035072 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6291155048397 R= 1.035072 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.60762013039913 R= 1.035072 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.62547170097035 R= 1.111744 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.64933317060382 R= 1.111744 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6571558890599 R= 1.111744 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.66577257334241 R= 1.111744 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.66845841524598 R= 1.111744 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.66542668237437 R= 1.111744 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6572950105934 R= 1.111744 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.64397647826212 R= 1.111744 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6267253588255 R= 1.111744 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.60569762502354 R= 1.111744 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.58229583946094 R= 1.111744 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6044684589507 R= 1.188416 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.62464948534182 R= 1.188416 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.62993447603111 R= 1.188416 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6366816583371 R= 1.188416 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.63817296198667 R= 1.188416 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6342758629112 R= 1.188416 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.6261407073953 R= 1.188416 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.61319677772845 R= 1.188416 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.595749678994 R= 1.188416 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.57458846581709 R= 1.188416 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.55024116874677 R= 1.188416 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.57486264703844 R= 1.265088 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.59124759283094 R= 1.265088 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.60269304452339 R= 1.265088 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.59981592010342 R= 1.265088 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.60083910765964 R= 1.265088 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.59687207004104 R= 1.265088 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.58863175887308 R= 1.265088 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.57637339068526 R= 1.265088 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.55959317927429 R= 1.265088 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.53950511537164 R= 1.265088 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.51578279564694 R= 1.265088 theta= 2.553416695667704
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.53906992032651 R= 1.34176 theta= 1.0943214410004445
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.55313402385187 R= 1.34176 theta= 1.2402309664671705
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.56250622213221 R= 1.34176 theta= 1.3861404919338964
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.55914856959916 R= 1.34176 theta= 1.5320500174006224
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.55924958139055 R= 1.34176 theta= 1.6779595428673484
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.55572953629742 R= 1.34176 theta= 1.8238690683340741
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.5480656109358 R= 1.34176 theta= 1.9697785938008001
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.53689452606012 R= 1.34176 theta= 2.115688119267526
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.52183063220443 R= 1.34176 theta= 2.261597644734252
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.50372940078158 R= 1.34176 theta= 2.407507170200978
# Number of particles: (2, 2)
# Number of spatial orbitals: 4
# Number of qubits: 6
# Number of Paulis: 95
# GS energy= -75.48198537557155 R= 1.34176 theta= 2.553416695667704

# %%
# Constants and initialization
known_R = 0.9584
known_theta = 104.5 * pi / 180  # Convert to radians
N = 11 # choose an odd number so that the known minimum is included in linspace
Rs = linspace(0.6, 1.4, N) * known_R  # Generate scaled bond lengths
thetas = linspace(0.6, 1.4, N) * known_theta  # Generate scaled bond angles
energies = np.zeros((len(Rs), len(thetas)))  # Initialize energy grid

# transformer_H2O = ActiveSpaceTransformer(num_electrons=4, num_spatial_orbitals=4)
transformer_H2O = None

# Calculate energies
for i, R in enumerate(Rs):
    for j, theta in enumerate(thetas):
        atom_str = (
            f"O .0 .0 .0; "
            f"H {R * sin(theta / 2):.3f} {R * cos(theta / 2):.3f} .0; "
            f"H {-R * sin(theta / 2):.3f} {R * cos(theta / 2):.3f} .0"
        )
        H2O_qub, H2O_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer_H2O)
        energies[i, j] = get_exact_energies(H2O_es)[1]
        print('GS energy=',energies[i, j],'R=',R,'theta=',theta)

# Create meshgrid and contour plot
X, Y = np.meshgrid(Rs, thetas * (180/pi))  # Create 2D grid for Rs and thetas
plt.figure(figsize=(len(Rs), len(thetas)))
contour = plt.contourf(X, Y, energies.T, levels=50, cmap='viridis')  # Transpose energies for correct orientation
plt.colorbar(contour, label='Energy [Hartree]')
plt.xlabel('R [Angstrom]')
plt.ylabel('Theta [degrees]')


# Add a point of known vals (should be middle vals in linspace)
plt.scatter(known_R, known_theta * (180/pi), color='red', marker='o')
plt.text(known_R - 0.1, known_theta * (180/pi) -3, f"Known min at (R,Theta)=(0.9584,104.5). E={energies[N//2][N//2]:.4f}", color='red', fontsize=10)

# Add a point of simulation min vals
min_index = np.unravel_index(np.argmin(energies, axis=None), energies.shape)
x_min, y_min, z_min = Rs[min_index[0]], thetas[min_index[1]], energies[min_index]
plt.scatter(x_min, y_min * (180/pi), color='cyan', marker='o')
plt.text(x_min - 0.1, y_min * (180/pi) -3, f"Simulation min E={z_min:.4f}", color='cyan', fontsize=10)


plt.title('Contour Plot of H2O Energy')
plt.show()
# Out:
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.46672770427523 R= 0.57504 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.54785380003423 R= 0.57504 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.60069033555916 R= 0.57504 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.64372048012531 R= 0.57504 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.66891351772048 R= 0.57504 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.68629924912099 R= 0.57504 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.69232990557089 R= 0.57504 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.69646907447974 R= 0.57504 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.69763299288033 R= 0.57504 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.70092273555463 R= 0.57504 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.69819425118631 R= 0.57504 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -74.9969599367536 R= 0.651712 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.06185521335377 R= 0.651712 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.10604391520002 R= 0.651712 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.14189531980735 R= 0.651712 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.15924278583032 R= 0.651712 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.17030465622193 R= 0.651712 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.1754655178417 R= 0.651712 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.17817223120288 R= 0.651712 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.17729009883104 R= 0.651712 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.17019520814439 R= 0.651712 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.16832967513571 R= 0.651712 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.31122003025345 R= 0.728384 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.36616606590508 R= 0.728384 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.4033945072504 R= 0.728384 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.43055087120858 R= 0.728384 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.44640107450529 R= 0.728384 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.45338926993391 R= 0.728384 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.45507888161492 R= 0.728384 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.45162458445624 R= 0.728384 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.44504411293816 R= 0.728384 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.43745840912713 R= 0.728384 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.42884999860927 R= 0.728384 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.49828097178577 R= 0.805056 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.54363085245345 R= 0.805056 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.57450028936415 R= 0.805056 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.59539221498721 R= 0.805056 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.60716807434774 R= 0.805056 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.61165802933813 R= 0.805056 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.60922358023785 R= 0.805056 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.60209002195388 R= 0.805056 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.59261579778521 R= 0.805056 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.58087585663165 R= 0.805056 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.5682295948758 R= 0.805056 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.60355762078198 R= 0.881728 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.64157317907515 R= 0.881728 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6675557068846 R= 0.881728 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.68381386623427 R= 0.881728 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.69211923405616 R= 0.881728 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.69327984811667 R= 0.881728 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6890459377067 R= 0.881728 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6794250279093 R= 0.881728 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6669358512111 R= 0.881728 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6512970508156 R= 0.881728 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.63560070314975 R= 0.881728 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.65825288432775 R= 0.9583999999999999 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.69027980978849 R= 0.9583999999999999 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.7117455838759 R= 0.9583999999999999 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.72466429313066 R= 0.9583999999999999 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.7300296348162 R= 0.9583999999999999 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.72907801309447 R= 0.9583999999999999 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.72240959673321 R= 0.9583999999999999 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.71090721086107 R= 0.9583999999999999 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.69577358953453 R= 0.9583999999999999 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.67792949131072 R= 0.9583999999999999 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.65846067593273 R= 0.9583999999999999 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6804739811605 R= 1.035072 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.70744034479766 R= 1.035072 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.72516018275738 R= 1.035072 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.73533497219016 R= 1.035072 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.73864355022225 R= 1.035072 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.73604140105063 R= 1.035072 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.72807862905175 R= 1.035072 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.71544243115947 R= 1.035072 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.69897348166228 R= 1.035072 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.67896500190527 R= 1.035072 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.65689375556683 R= 1.035072 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.68173005519529 R= 1.111744 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.7043186183792 R= 1.111744 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.71929689525686 R= 1.111744 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.72723831897369 R= 1.111744 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.72910447544113 R= 1.111744 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.725490020411 R= 1.111744 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.71704718218403 R= 1.111744 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.7038873053466 R= 1.111744 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.68696531785865 R= 1.111744 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.66638008348089 R= 1.111744 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.64308237696073 R= 1.111744 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.67008213071837 R= 1.188416 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.68926061983825 R= 1.188416 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.70165748303822 R= 1.188416 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.70796241181385 R= 1.188416 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.70880492733681 R= 1.188416 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.70455286368812 R= 1.188416 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6962511832226 R= 1.188416 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.68367324020397 R= 1.188416 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.66712752530287 R= 1.188416 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.64721227123722 R= 1.188416 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.62431912589543 R= 1.188416 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.65087018065064 R= 1.265088 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.66670889264753 R= 1.265088 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.67726287106616 R= 1.265088 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.68209311920657 R= 1.265088 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.68253855384341 R= 1.265088 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.67833154179198 R= 1.265088 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.67023810535487 R= 1.265088 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.65861944565931 R= 1.265088 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.64327054517787 R= 1.265088 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.62517700737207 R= 1.265088 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.60431966085032 R= 1.265088 theta= 2.553416695667704
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.62706011537665 R= 1.34176 theta= 1.0943214410004445
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6407617414409 R= 1.34176 theta= 1.2402309664671705
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.64955667742986 R= 1.34176 theta= 1.3861404919338964
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.65350495015606 R= 1.34176 theta= 1.5320500174006224
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.6533160651894 R= 1.34176 theta= 1.6779595428673484
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.64955625170944 R= 1.34176 theta= 1.8238690683340741
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.64221317282606 R= 1.34176 theta= 1.9697785938008001
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.63188653091498 R= 1.34176 theta= 2.115688119267526
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.61855452178834 R= 1.34176 theta= 2.261597644734252
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.60288921840962 R= 1.34176 theta= 2.407507170200978
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# GS energy= -75.58496918494933 R= 1.34176 theta= 2.553416695667704

# %% [markdown]
# ## RHF VS UHF

# %%
### Molecule geometries

# H2
atom_str_H2 = f"H .0 .0 .0; H .0 .0 0.74"

# HeH+
atom_str_HeH = f"He .0 .0 .0; H .0 .0 0.77"

# LiH
atom_str_LiH = f"Li .0 .0 .0; H .0 .0 1.6"

# Water
R=0.9584
theta=104.5 * pi / 180
atom_str_H2O = (
            f"O .0 .0 .0; "
            f"H {R * sin(theta / 2):.3f} {R * cos(theta / 2):.3f} .0; "
            f"H {-R * sin(theta / 2):.3f} {R * cos(theta / 2):.3f} .0"
        )
def get_fermionic_Ham(atom_str, charge, basis, mapping_name, transformer=None, method_type="rhf", spin=0):
    H2_qub, H2_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer, method_type, spin)
    return H2_es.hamiltonian.second_q_op()

def get_GS_energy(atom_str, charge, basis, mapping_name, transformer=None, method_type="rhf", spin=0):
    H2_qub, H2_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer, method_type, spin)
    GS_energy = get_exact_energies(H2_es)[1]
    return GS_energy

### They are similar (defulat settings, no need for active space)
Fermioni_Ham_H2_RHF = get_fermionic_Ham(atom_str=atom_str_H2, charge=0, basis='sto3g', mapping_name='parity', method_type='rhf')
Fermion_Ham_H2_UHF = get_fermionic_Ham(atom_str=atom_str_H2, charge=0, basis='sto3g', mapping_name='parity', method_type='uhf')
Fermion_Ham_HeH_RHF = get_fermionic_Ham(atom_str=atom_str_HeH, charge=1, basis='sto3g', mapping_name='parity', method_type='rhf')
Fermion_Ham_HeH_UHF = get_fermionic_Ham(atom_str=atom_str_HeH, charge=1, basis='sto3g', mapping_name='parity', method_type='uhf')

### Vary the active space. 
Fermion_Ham_LiH_RHF = get_fermionic_Ham(atom_str=atom_str_LiH, charge=0, basis='sto3g', mapping_name='parity', transformer=transformer4, method_type='rhf')
Fermion_Ham_LiH_UHF = get_fermionic_Ham(atom_str=atom_str_LiH, charge=0, basis='sto3g', mapping_name='parity', transformer=transformer4, method_type='uhf')

print('GS enrgies by method RHF,UHF,ROHF. With sto3g and sto6g basis sets')
### GS energy for LiH - to compare with the FCI energy
GS_energy_LiH_RHF3 = get_GS_energy(atom_str=atom_str_LiH, charge=0, basis='sto3g', mapping_name='parity', transformer=None, method_type='rhf')
GS_energy_LiH_UHF3 = get_GS_energy(atom_str=atom_str_LiH, charge=0, basis='sto3g', mapping_name='parity', transformer=None, method_type='uhf')
GS_energyLiH_ROHF3 = get_GS_energy(atom_str=atom_str_LiH, charge=0, basis='sto3g', mapping_name='parity', transformer=None, method_type='rohf')
GS_energy_LiH_RHF6 = get_GS_energy(atom_str=atom_str_LiH, charge=0, basis='sto6g', mapping_name='parity', transformer=None, method_type='rhf')
GS_energy_LiH_UHF6 = get_GS_energy(atom_str=atom_str_LiH, charge=0, basis='sto6g', mapping_name='parity', transformer=None, method_type='uhf')
GS_energyLiH_ROHF6 = get_GS_energy(atom_str=atom_str_LiH, charge=0, basis='sto6g', mapping_name='parity', transformer=None, method_type='rohf')
print('LiH:')
print('sto3g:')
print('RHF:',GS_energy_LiH_RHF3,'UHF:',GS_energy_LiH_UHF3,'RHOF:', GS_energyLiH_ROHF3)
print('sto6g:')
print('RHF:',GS_energy_LiH_RHF6,'UHF:',GS_energy_LiH_UHF6,'RHOF:', GS_energyLiH_ROHF6)
print('\n')

### GS energy for H2O - to compare with the FCI energy
GS_energy_H2O_RHF3 = get_GS_energy(atom_str=atom_str_H2O, charge=0, basis='sto3g', mapping_name='parity', transformer=None, method_type='rhf')
GS_energy_H2O_UHF3 = get_GS_energy(atom_str=atom_str_H2O, charge=0, basis='sto3g', mapping_name='parity', transformer=None, method_type='uhf')
GS_energy_H2O_ROHF3 = get_GS_energy(atom_str=atom_str_H2O, charge=0, basis='sto6g', mapping_name='parity', transformer=None, method_type='rohf')
GS_energy_H2O_RHF6 = get_GS_energy(atom_str=atom_str_H2O, charge=0, basis='sto6g', mapping_name='parity', transformer=None, method_type='rhf')
GS_energy_H2O_UHF6 = get_GS_energy(atom_str=atom_str_H2O, charge=0, basis='sto6g', mapping_name='parity', transformer=None, method_type='uhf')
GS_energy_H2O_ROHF6 = get_GS_energy(atom_str=atom_str_H2O, charge=0, basis='sto6g', mapping_name='parity', transformer=None, method_type='rohf')
print('\n')

print('H2O:')
print('sto3g:')
print('RHF:',GS_energy_H2O_RHF3,'UHF:',GS_energy_H2O_UHF3,'RHOF:', GS_energy_H2O_ROHF3)
print('sto6g:')
print('RHF:',GS_energy_H2O_RHF6,'UHF:',GS_energy_H2O_UHF6,'RHOF:', GS_energy_H2O_ROHF6)
# Out:
# Number of particles: (1, 1)
# Number of spatial orbitals: 2
# Number of qubits: 2
# Number of Paulis: 5
# Number of particles: (1, 1)
# Number of spatial orbitals: 2
# Number of qubits: 2
# Number of Paulis: 5
# Number of particles: (1, 1)
# Number of spatial orbitals: 2
# Number of qubits: 2
# Number of Paulis: 9
# Number of particles: (1, 1)
# Number of spatial orbitals: 2
# Number of qubits: 2
# Number of Paulis: 9
# The following error was encountered during the attempted conversion of the 4-fold to 8-fold symmetric integrals: Expected a symmetric tensor.
# The provided alpha-beta overlap matrix is NOT unitary! This can happen when the alpha- and beta-spin orbitals do not span the same space. To provide an example of what this means, consider an active space chosen from unrestricted-spin orbitals. Computing <S^2> within this active space may not result in the same <S^2> value as obtained on the single-reference starting point. More importantly, this implies that the inactive subspace will account for the difference between these two <S^2> values, possibly resulting in significant spin contamination in both subspaces. You should verify whether this is intentional/acceptable or whether your choice of active space can be improved. As a reference, here is the summed-absolute deviation of `S^T @ S` from the identity: 0.9024981218730149
# Number of particles: (1, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# Number of particles: (1, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# GS enrgies by method RHF,UHF,ROHF. With sto3g and sto6g basis sets
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# The following error was encountered during the attempted conversion of the 4-fold to 8-fold symmetric integrals: Expected a symmetric tensor.
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 767
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# The following error was encountered during the attempted conversion of the 4-fold to 8-fold symmetric integrals: Expected a symmetric tensor.
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 767
# Number of particles: (2, 2)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 631
# LiH:
# sto3g:
# RHF: -7.882324378883525 UHF: -7.882324378883534 RHOF: -7.882324378883465
# sto6g:
# RHF: -7.972249851370569 UHF: -7.972249851370491 RHOF: -7.972249851370541
#
#
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# The following error was encountered during the attempted conversion of the 4-fold to 8-fold symmetric integrals: Expected a symmetric tensor.
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# The following error was encountered during the attempted conversion of the 4-fold to 8-fold symmetric integrals: Expected a symmetric tensor.
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
# Number of particles: (5, 5)
# Number of spatial orbitals: 7
# Number of qubits: 12
# Number of Paulis: 1086
#
#
# H2O:
# sto3g:
# RHF: -75.01282317655736 UHF: -75.0128231765572 RHOF: -75.72907801309535
# sto6g:
# RHF: -75.72907801309533 UHF: -75.72907801309506 RHOF: -75.72907801309495

# %%
##### RHF H2 Fermionic Hamiltonian #####
print('RHF H2 Fermionic Hamiltonian:')
print(Fermion_Ham_H2_RHF_mat)
# Out:
# RHF H2 Fermionic Hamiltonian:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 ##### RHF H2 Fermionic Hamiltonian #####
#       2 print('RHF H2 Fermionic Hamiltonian:')
# ----> 3 print(Fermion_Ham_H2_RHF_mat)
#
# NameError: name 'Fermion_Ham_H2_RHF_mat' is not defined

# %%
##### UHF H2 Fermionic Hamiltonian #####
print('UHF H2 Fermionic Hamiltonian:')
print(Fermion_Ham_H2_UHF_mat)

# %%
##### RHF HeH Fermionic Hamiltonian #####
print('RHF HeH Fermionic Hamiltonian')
print(Fermion_Ham_HeH_RHF_mat)

# %%
##### UHF HeH Fermionic Hamiltonian #####
print('UHF HeH Fermionic Hamiltonian')
print(Fermion_Ham_HeH_UHF_mat)

# %%
##### RHF LiH Fermionic Hamiltonian #####
print('RHF LiH Fermionic Hamiltonian')
print(Fermion_Ham_LiH_RHF_mat)

# %%
##### UHF LiH Fermionic Hamiltonian with Active Space#####
print('UHF LiH Fermionic Hamiltonian')
print(Fermion_Ham_LiH_UHF_mat)

# %% [markdown]
# # Reactions
# ### H2 + H -> H3

# %%
# Should I add this? gpt says so.
#spin=1  # Doublet state (since neutral H3 has an unpaired electron)


# Define grid
L=20
R1_values = np.linspace(0.5, 2.0,L)  # Range of R1 in Å
R2_values = np.linspace(0.5, 2.0,L)  # Range of R2 in Å

pes_data = []

for R1 in R1_values:
    for R2 in R2_values:

        # Define atom string
        atom_string_H3 = f"H .0 .0 .0; H {R1:.3f} .0 .0; H {(R1+R2):.3f} .0 .0"
        # Create molecule
        GS_energy = get_GS_energy(atom_str=atom_string_H3, charge=0, basis='sto3g', mapping_name='parity', transformer=None, method_type="rhf", spin=1)
        pes_data.append((R1, R2, GS_energy))

        
        print(f"R1={R1:.2f}, R2={R2:.2f} → Energy = {GS_energy:.6f} Ha")

# Convert data to arrays
R1_list, R2_list, E_list = zip(*pes_data)
R1_grid = np.reshape(R1_list, (L,L))
R2_grid = np.reshape(R2_list, (L,L))
E_grid = np.reshape(E_list, (L,L))

plt.figure(figsize=(8, 6))
plt.contourf(R1_grid, R2_grid, E_grid, levels=100, cmap="viridis")
plt.colorbar(label="Energy (Hartree)")
plt.xlabel("R1 (Å)")
plt.ylabel("R2 (Å)")
plt.title("Potential Energy Surface of H3 Reaction")
plt.show()
# Out:
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=0.50, R2=0.50 → Energy = -1.170532 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=0.58 → Energy = -1.266439 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=0.66 → Energy = -1.331566 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=0.74 → Energy = -1.377406 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=0.82 → Energy = -1.410688 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=0.89 → Energy = -1.435482 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=0.97 → Energy = -1.454330 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.05 → Energy = -1.468881 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.13 → Energy = -1.480239 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.21 → Energy = -1.489171 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.29 → Energy = -1.496144 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.37 → Energy = -1.501737 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.45 → Energy = -1.506157 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.53 → Energy = -1.509643 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.61 → Energy = -1.512385 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.68 → Energy = -1.514534 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.76 → Energy = -1.516213 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.84 → Energy = -1.517519 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=1.92 → Energy = -1.518531 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.50, R2=2.00 → Energy = -1.519312 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=0.50 → Energy = -1.266439 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=0.58, R2=0.58 → Energy = -1.353567 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=0.66 → Energy = -1.411275 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=0.74 → Energy = -1.450912 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=0.82 → Energy = -1.479125 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=0.89 → Energy = -1.499884 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=0.97 → Energy = -1.515602 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.05 → Energy = -1.527774 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.13 → Energy = -1.537361 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.21 → Energy = -1.544907 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.29 → Energy = -1.551037 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.37 → Energy = -1.555955 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.45 → Energy = -1.559895 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.53 → Energy = -1.563043 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.61 → Energy = -1.565548 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.68 → Energy = -1.567531 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.76 → Energy = -1.569094 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.84 → Energy = -1.570319 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=1.92 → Energy = -1.571274 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.58, R2=2.00 → Energy = -1.572015 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=0.50 → Energy = -1.331566 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=0.58 → Energy = -1.411275 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=0.66, R2=0.66 → Energy = -1.462330 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=0.74 → Energy = -1.496114 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=0.82 → Energy = -1.519337 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=0.89 → Energy = -1.535993 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=0.97 → Energy = -1.548445 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.05 → Energy = -1.558098 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.13 → Energy = -1.565700 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.21 → Energy = -1.571953 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.29 → Energy = -1.577069 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.37 → Energy = -1.581263 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.45 → Energy = -1.584692 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.53 → Energy = -1.587480 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.61 → Energy = -1.589733 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.68 → Energy = -1.591540 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.76 → Energy = -1.592980 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.84 → Energy = -1.594118 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=1.92 → Energy = -1.595013 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.66, R2=2.00 → Energy = -1.595711 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=0.50 → Energy = -1.377406 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=0.58 → Energy = -1.450912 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=0.66 → Energy = -1.496114 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=0.74, R2=0.74 → Energy = -1.524485 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=0.82 → Energy = -1.542873 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=0.89 → Energy = -1.555383 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=0.97 → Energy = -1.564423 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.05 → Energy = -1.571297 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.13 → Energy = -1.576938 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.21 → Energy = -1.581655 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.29 → Energy = -1.585659 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.37 → Energy = -1.589063 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.45 → Energy = -1.591937 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.53 → Energy = -1.594338 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.61 → Energy = -1.596322 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.68 → Energy = -1.597943 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.76 → Energy = -1.599252 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.84 → Energy = -1.600300 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=1.92 → Energy = -1.601131 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.74, R2=2.00 → Energy = -1.601784 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=0.50 → Energy = -1.410688 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=0.58 → Energy = -1.479125 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=0.66 → Energy = -1.519337 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=0.74 → Energy = -1.542873 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=0.82, R2=0.82 → Energy = -1.556720 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=0.89 → Energy = -1.565132 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=0.97 → Energy = -1.570587 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.05 → Energy = -1.574657 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.13 → Energy = -1.578022 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.21 → Energy = -1.581027 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.29 → Energy = -1.583787 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.37 → Energy = -1.586308 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.45 → Energy = -1.588567 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.53 → Energy = -1.590545 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.61 → Energy = -1.592237 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.68 → Energy = -1.593658 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.76 → Energy = -1.594830 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.84 → Energy = -1.595783 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=1.92 → Energy = -1.596548 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.82, R2=2.00 → Energy = -1.597155 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=0.50 → Energy = -1.435482 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=0.58 → Energy = -1.499884 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=0.66 → Energy = -1.535993 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=0.74 → Energy = -1.555383 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=0.82 → Energy = -1.565132 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=0.89 → Energy = -1.569601 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=0.97 → Energy = -1.571579 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.05 → Energy = -1.572574 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.13 → Energy = -1.573433 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.21 → Energy = -1.574505 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.29 → Energy = -1.575841 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.37 → Energy = -1.577351 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.45 → Energy = -1.578911 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.53 → Energy = -1.580411 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.61 → Energy = -1.581781 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.68 → Energy = -1.582984 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.76 → Energy = -1.584009 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.84 → Energy = -1.584862 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=1.92 → Energy = -1.585559 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.89, R2=2.00 → Energy = -1.586119 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=0.50 → Energy = -1.454330 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=0.58 → Energy = -1.515602 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=0.66 → Energy = -1.548445 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=0.74 → Energy = -1.564423 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=0.82 → Energy = -1.570607 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=0.89 → Energy = -1.571603 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=0.97 → Energy = -1.570132 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.05 → Energy = -1.567959 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.13 → Energy = -1.566090 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.21 → Energy = -1.564968 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.29 → Energy = -1.564647 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.37 → Energy = -1.564969 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.45 → Energy = -1.565707 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.53 → Energy = -1.566652 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.61 → Energy = -1.567653 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.68 → Energy = -1.568611 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.76 → Energy = -1.569474 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.84 → Energy = -1.570219 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=1.92 → Energy = -1.570844 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=0.97, R2=2.00 → Energy = -1.571356 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=0.50 → Energy = -1.468881 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=0.58 → Energy = -1.527774 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=0.66 → Energy = -1.558098 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=0.74 → Energy = -1.571281 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=0.82 → Energy = -1.574702 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=0.89 → Energy = -1.572633 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=0.97 → Energy = -1.567998 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.05 → Energy = -1.562708 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.13 → Energy = -1.557961 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.21 → Energy = -1.554383 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.29 → Energy = -1.552125 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.37 → Energy = -1.551022 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.45 → Energy = -1.550766 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.53 → Energy = -1.551043 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.61 → Energy = -1.551604 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.68 → Energy = -1.552276 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.76 → Energy = -1.552954 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.84 → Energy = -1.553580 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=1.92 → Energy = -1.554127 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.05, R2=2.00 → Energy = -1.554588 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=0.50 → Energy = -1.480239 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=0.58 → Energy = -1.537361 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=0.66 → Energy = -1.565554 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=0.74 → Energy = -1.576936 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=0.82 → Energy = -1.578091 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=0.89 → Energy = -1.573526 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=0.97 → Energy = -1.566172 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.05 → Energy = -1.558010 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.13 → Energy = -1.550396 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.21 → Energy = -1.544171 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.29 → Energy = -1.539686 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.37 → Energy = -1.536868 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.45 → Energy = -1.535385 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.53 → Energy = -1.534832 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.61 → Energy = -1.534851 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.68 → Energy = -1.535176 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.76 → Energy = -1.535634 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.84 → Energy = -1.536121 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=1.92 → Energy = -1.536581 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.13, R2=2.00 → Energy = -1.536987 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=0.50 → Energy = -1.489171 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=0.58 → Energy = -1.544498 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=0.66 → Energy = -1.571809 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=0.74 → Energy = -1.581663 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=0.82 → Energy = -1.581116 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=0.89 → Energy = -1.574627 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=0.97 → Energy = -1.565090 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.05 → Energy = -1.554481 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.13 → Energy = -1.544226 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.21 → Energy = -1.535341 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.29 → Energy = -1.528415 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.37 → Energy = -1.523578 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.45 → Energy = -1.520583 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.53 → Energy = -1.518981 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.61 → Energy = -1.518309 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.68 → Energy = -1.518197 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.76 → Energy = -1.518382 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.84 → Energy = -1.518701 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=1.92 → Energy = -1.519058 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.21, R2=2.00 → Energy = -1.519402 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=0.50 → Energy = -1.496144 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=0.58 → Energy = -1.551037 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=0.66 → Energy = -1.577069 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=0.74 → Energy = -1.585659 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=0.82 → Energy = -1.583787 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=0.89 → Energy = -1.575841 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=0.97 → Energy = -1.564647 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.05 → Energy = -1.552125 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.13 → Energy = -1.539686 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.21 → Energy = -1.528415 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.29 → Energy = -1.519081 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.37 → Energy = -1.512063 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.45 → Energy = -1.507306 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.53 → Energy = -1.504420 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.61 → Energy = -1.502886 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.68 → Energy = -1.502222 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.76 → Energy = -1.502066 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.84 → Energy = -1.502178 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=1.92 → Energy = -1.502411 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.29, R2=2.00 → Energy = -1.502677 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=0.50 → Energy = -1.501737 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=0.58 → Energy = -1.555955 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=0.66 → Energy = -1.581263 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=0.74 → Energy = -1.589063 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=0.82 → Energy = -1.586308 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=0.89 → Energy = -1.577351 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=0.97 → Energy = -1.564969 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.05 → Energy = -1.551022 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.13 → Energy = -1.536868 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.21 → Energy = -1.523578 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.29 → Energy = -1.512005 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.37 → Energy = -1.502723 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.45 → Energy = -1.495939 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.53 → Energy = -1.491454 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.61 → Energy = -1.488787 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.68 → Energy = -1.487384 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.76 → Energy = -1.486770 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.84 → Energy = -1.486607 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=1.92 → Energy = -1.486676 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.37, R2=2.00 → Energy = -1.486850 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=0.50 → Energy = -1.506157 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=0.58 → Energy = -1.559895 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=0.66 → Energy = -1.584692 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=0.74 → Energy = -1.591937 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=0.82 → Energy = -1.588567 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=0.89 → Energy = -1.578911 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=0.97 → Energy = -1.565707 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.05 → Energy = -1.550766 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.13 → Energy = -1.535385 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.21 → Energy = -1.520583 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.29 → Energy = -1.507196 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.37 → Energy = -1.495881 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.45 → Energy = -1.487047 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.53 → Energy = -1.480751 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.61 → Energy = -1.476688 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.68 → Energy = -1.474323 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.76 → Energy = -1.473098 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.84 → Energy = -1.472569 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=1.92 → Energy = -1.472420 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.45, R2=2.00 → Energy = -1.472469 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=0.50 → Energy = -1.509643 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=0.58 → Energy = -1.563043 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=0.66 → Energy = -1.587480 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=0.74 → Energy = -1.594338 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=0.82 → Energy = -1.590545 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=0.89 → Energy = -1.580411 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=0.97 → Energy = -1.566652 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.05 → Energy = -1.551043 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.13 → Energy = -1.534832 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.21 → Energy = -1.518981 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.29 → Energy = -1.504271 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.37 → Energy = -1.491348 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.45 → Energy = -1.480697 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.53 → Energy = -1.472575 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.61 → Energy = -1.466921 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.68 → Energy = -1.463356 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.76 → Energy = -1.461344 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.84 → Energy = -1.460302 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=1.92 → Energy = -1.459857 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.53, R2=2.00 → Energy = -1.459736 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=0.50 → Energy = -1.512385 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=0.58 → Energy = -1.565548 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=0.66 → Energy = -1.589733 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=0.74 → Energy = -1.596322 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=0.82 → Energy = -1.592237 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=0.89 → Energy = -1.581781 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=0.97 → Energy = -1.567653 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.05 → Energy = -1.551604 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.13 → Energy = -1.534851 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.21 → Energy = -1.518309 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.29 → Energy = -1.502710 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.37 → Energy = -1.488645 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.45 → Energy = -1.476589 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.53 → Energy = -1.466871 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.61 → Energy = -1.459620 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.68 → Energy = -1.454732 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.76 → Energy = -1.451666 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.84 → Energy = -1.449955 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=1.92 → Energy = -1.449103 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.61, R2=2.00 → Energy = -1.448747 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=0.50 → Energy = -1.514534 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=0.58 → Energy = -1.567531 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=0.66 → Energy = -1.591540 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=0.74 → Energy = -1.597943 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=0.82 → Energy = -1.593658 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=0.89 → Energy = -1.582984 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=0.97 → Energy = -1.568611 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.05 → Energy = -1.552276 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.13 → Energy = -1.535176 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.21 → Energy = -1.518197 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.29 → Energy = -1.502029 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.37 → Energy = -1.487219 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.45 → Energy = -1.474192 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.53 → Energy = -1.463266 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.61 → Energy = -1.454732 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=1.68, R2=1.68 → Energy = -1.448391 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.76 → Energy = -1.444157 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.84 → Energy = -1.441597 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=1.92 → Energy = -1.440198 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.68, R2=2.00 → Energy = -1.439518 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=0.50 → Energy = -1.516213 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=0.58 → Energy = -1.569094 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=0.66 → Energy = -1.592980 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=0.74 → Energy = -1.599252 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=0.82 → Energy = -1.594830 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=0.89 → Energy = -1.584009 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=0.97 → Energy = -1.569474 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.05 → Energy = -1.552954 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.13 → Energy = -1.535634 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.21 → Energy = -1.518382 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.29 → Energy = -1.501864 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.37 → Energy = -1.486591 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.45 → Energy = -1.472947 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.53 → Energy = -1.461344 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.61 → Energy = -1.451666 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.68 → Energy = -1.444157 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=1.76, R2=1.76 → Energy = -1.438759 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.84 → Energy = -1.435222 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=1.92 → Energy = -1.433126 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.76, R2=2.00 → Energy = -1.432005 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=0.50 → Energy = -1.517519 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=0.58 → Energy = -1.570319 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=0.66 → Energy = -1.594118 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=0.74 → Energy = -1.600300 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=0.82 → Energy = -1.595783 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=0.89 → Energy = -1.584862 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=0.97 → Energy = -1.570219 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.05 → Energy = -1.553580 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.13 → Energy = -1.536121 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.21 → Energy = -1.518701 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.29 → Energy = -1.501971 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.37 → Energy = -1.486420 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.45 → Energy = -1.472569 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.53 → Energy = -1.460302 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.61 → Energy = -1.449955 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.68 → Energy = -1.441597 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.76 → Energy = -1.435222 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=1.84, R2=1.84 → Energy = -1.430717 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=1.92 → Energy = -1.427816 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.84, R2=2.00 → Energy = -1.426128 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=0.50 → Energy = -1.518531 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=0.58 → Energy = -1.571274 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=0.66 → Energy = -1.595013 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=0.74 → Energy = -1.601131 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=0.82 → Energy = -1.596548 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=0.89 → Energy = -1.585559 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=0.97 → Energy = -1.570844 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.05 → Energy = -1.554127 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.13 → Energy = -1.536581 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.21 → Energy = -1.519058 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.29 → Energy = -1.502201 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.37 → Energy = -1.486676 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.45 → Energy = -1.472420 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.53 → Energy = -1.459857 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.61 → Energy = -1.449103 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.68 → Energy = -1.440198 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.76 → Energy = -1.433126 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=1.84 → Energy = -1.427816 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=1.92, R2=1.92 → Energy = -1.424119 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=1.92, R2=2.00 → Energy = -1.421776 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=0.50 → Energy = -1.519312 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=0.58 → Energy = -1.572015 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=0.66 → Energy = -1.595711 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=0.74 → Energy = -1.601784 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=0.82 → Energy = -1.597155 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=0.89 → Energy = -1.586119 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=0.97 → Energy = -1.571356 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.05 → Energy = -1.554588 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.13 → Energy = -1.536987 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.21 → Energy = -1.519402 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.29 → Energy = -1.502677 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.37 → Energy = -1.486850 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.45 → Energy = -1.472469 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.53 → Energy = -1.459736 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.61 → Energy = -1.448747 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.68 → Energy = -1.439518 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.76 → Energy = -1.432005 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.84 → Energy = -1.426128 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 100
# R1=2.00, R2=1.92 → Energy = -1.421776 Ha
# Number of particles: (2, 1)
# Number of spatial orbitals: 3
# Number of qubits: 4
# Number of Paulis: 52
# R1=2.00, R2=2.00 → Energy = -1.418787 Ha

# %% [markdown]
# ### H2 + CO2 -> HCOOH

# %%
    
# Should I add this? gpt says so.
#spin=1  # Doublet state (since neutral H3 has an unpaired electron)


# fixed parameters
r1 = 1
r2 = 2

# Define grid
L=1
R_values = np.linspace(0.5, 2.0,L)  # Range of R in Å
theta_values = np.linspace(0.1,pi,L) # Range of Theta in radians (0 to pi radians, 
                                    ### is this a good choice?!?!) ### !!! ###

pes_data = []

for R in R_values:
    for theta in theta_values:

        # Define atom string
        atom_string_H3 = f'''H {-R:.3f} {0.5*r1:.3f} .0; 
                             H {-R:.3f} {-0.5*r2:.3f} .0; 
                             C .0 .0 .0
                             O {r2*cos(theta/2):.3f} {r2*sin(theta/2):.3f} .0
                             O {r2*cos(theta/2):.3f} {-r2*sin(theta/2):.3f} .0'''
        # Create molecule

        # Possible active space transformers:
        transformer1 = ActiveSpaceTransformer(num_electrons=6,num_spatial_orbitals=6)
        GS_energy = get_GS_energy(atom_str=atom_string_H3, charge=0, basis='sto3g', mapping_name='parity', transformer=transformer1, method_type="rhf", spin=0)
        # pes_data.append((R1, R2, GS_energy))

        
        # print(f"R1={R1:.2f}, R2={R2:.2f} → Energy = {GS_energy:.6f} Ha")

# Convert data to arrays
# R1_list, R2_list, E_list = zip(*pes_data)
# R1_grid = np.reshape(R1_list, (L,L))
# R2_grid = np.reshape(R2_list, (L,L))
# E_grid = np.reshape(E_list, (L,L))

# plt.figure(figsize=(8, 6))
# plt.contourf(R1_grid, R2_grid, E_grid, levels=100, cmap="viridis")
# plt.colorbar(label="Energy (Hartree)")
# plt.xlabel("R1 (Å)")
# plt.ylabel("R2 (Å)")
# plt.title("Potential Energy Surface of H3 Reaction")
# plt.show()
# Out:
# Number of particles: (3, 3)
# Number of spatial orbitals: 6
# Number of qubits: 10
# Number of Paulis: 1079

# %% [markdown]
# ## CO2 molecule

# %%
from qiskit_nature.second_q.problems.electronic_structure_result import ElectronicStructureResult
#####
'''
When using an ActiveSpaceTransformer, the calculated energy from the transformed hamiltonian (CO2_qub, in this case), is shifted with an extracted_transformer_energy of the inactive orbitals.
To account for this, The formula you should look for is this:
GroundState_energy = qubit_hamiltonian.min_eigenvalue + ElectronicStructureProblem.nuclear_repulsion_energy + ElectronicStructureResult.extracted_transformer_energy

Ex.
ElectronicStructureResult, CO2_energy, _ = get_exact_energies(CO2_es)
eigenvalues, eigenvectors = linalg.eig(CO2_qub.to_matrix())
print("Numpy solver", min(eigenvalues).real + CO2_es.nuclear_repulsion_energy + CO2_ElectronicStructureResult.extracted_transformer_energy)
'''

def invert_activate_space_transformation_energy(untransformed_energy: float, electronicStructure: ElectronicStructureProblem, eigenstateResult: ElectronicStructureResult) -> float:
    return untransformed_energy + electronicStructure.nuclear_repulsion_energy + eigenstateResult.extracted_transformer_energy
#####

# %%
from numpy import linalg

##PARAMETERS
###########
known_R = 1.16 #Angstrom

atom_str = (
    f"C .0 .0 .0; "
    f"O  .0 .0 {-known_R}; "
    f"O .0 .0 {known_R}"
)

charge = 0
basis = 'sto3g'
mapping_name = "parity"

transformer_CO2 = ActiveSpaceTransformer(num_electrons=4, num_spatial_orbitals=4)
###########

#### PROBLEM DEFINITION
CO2_qub, CO2_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer_CO2)
print("CO2 Sparse Pauli Hamiltonian",CO2_qub)


#CLASSIC SOLVER - HF Approximation (Pure PySCF)
print("CO2 RHF Approximation", HF_approx_energy(atom_str, basis, method_type="rhf", charge=0, spin=0))

#CLASSIC SOLVER - Exact solution
###########
CO2_ElectronicStructureResult, CO2_energy, _ = get_exact_energies(CO2_es)
print('Energies:',CO2_energy)
###Numpy Manual Eigensolver for practice
eigenvalues, eigenvectors = linalg.eig(CO2_qub.to_matrix())
print("Numpy solver", invert_activate_space_transformation_energy(min(eigenvalues).real, CO2_es, CO2_ElectronicStructureResult))

# ### WHOLE PROBLEM PRINT
# print("CO2 Electronic Structure Problem",CO2_ElectronicStructureResult)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 basis = 'sto3g'
#      15 mapping_name = "parity"
# ---> 17 transformer_CO2 = ActiveSpaceTransformer(num_electrons=4, num_spatial_orbitals=4)
#      18 ###########
#      19
#      20 #### PROBLEM DEFINITION
#      21 CO2_qub, CO2_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer_CO2)
#
# NameError: name 'ActiveSpaceTransformer' is not defined

# %% [markdown]
# **Normal VQE Solver**

# %%
from vqe import *

energy_values = []
theta_path = []

args = {
    'plot_func': lambda: plot_energies(
        invert_activate_space_transformation_energy(energy_values, CO2_es, CO2_ElectronicStructureResult), 
        CO2_energy
    ),
    'callback_func': lambda a, b, c, d: store_energy(energy_values, theta_path, a, b, c, d)
}

vqe_eigenvalue = run_VQE(CO2_qub, maxiter=1000, seed=10, **args)
print("Ground state energy - inverted", invert_activate_space_transformation_energy(vqe_eigenvalue, CO2_es, CO2_ElectronicStructureResult))
# Out:
# NUMBER OF QUBITS 2 2
# Ground state energy: -1.340572782473365
# Optimal parameters: [ 3.4815651  -0.12482935  2.95495236 -2.15221078 -0.0080011  -1.46002685
#   1.2099694   1.63178278 -0.36862601  3.35526026  1.98401467 -1.52661415
#   0.18730987  1.53486002  1.77576448  2.87307994]
# Number of iterations: None
# Ground state energy - inverted -185.06494781233874

# %%
for i in range(4):
    visualize_path_2d(theta_path, i, i+1)
for i in range(4):
    visualize_path_1d(theta_path, i)

# %% [markdown]
# **CO2 + H2 Calculation Attempt**

# %%
# Define molecules and their spin multiplicity
molecules = {
    "H2": ("H 0 0 0; H 0 0 0.74", 0),  # spin = 0 for closed-shell molecules
    "LiH": ("Li 0 0 0; H 0 0 1.6", 0),
    "H2O": ("O 0 0 0; H 0 0.76 0.58; H 0 -0.76 0.58", 0),
}

# Basis sets
basis_sets = ["sto-3g", "sto-6g"]

# HF methods
hf_methods = {
    "RHF": scf.RHF,  # Generic HF (let PySCF decide the type)
    "UHF": scf.UHF,  # Restricted HF
    "ROHF": scf.ROHF,  # Restricted Open-Shell HF
}

# Store results
results = []

# Iterate over (molecule, basis)
for (mol_name, (atom_str, spin)), basis in product(molecules.items(), basis_sets):
    # Define molecule in PySCF
    mol = gto.M(atom=atom_str, basis=basis, spin=spin, charge=0)

    # Compute FCI energy only once per molecule
    driver = PySCFDriver(atom=atom_str, basis=basis, spin=spin)
    problem = driver.run()
    qubit_mapper = JordanWignerMapper()
    hamiltonian = qubit_mapper.map(problem.hamiltonian.second_q_op())

    solver = NumPyMinimumEigensolver()
    fci_energy = solver.compute_minimum_eigenvalue(hamiltonian).eigenvalue.real

    # Store FCI energy
    results.append((mol_name, basis, "FCI", fci_energy))

    # Compute HF, RHF, and ROHF
    for hf_name, hf_class in hf_methods.items():
        mf = hf_class(mol)
        hf_energy = mf.kernel()
        results.append((mol_name, basis, hf_name, hf_energy))

# Pretty print results
print("\nComparison of HF, RHF, ROHF, and FCI Energies:\n")
print(f"{'Molecule':<10} {'Basis':<7} {'Method':<6} {'Energy':>12}")
print("=" * 40)
for mol, basis, method, energy in results:
    print(f"{mol:<10} {basis:<7} {method:<6} {energy:12.8f}")
# Out:
# converged SCF energy = -1.11675930739643
# converged SCF energy = -1.11675930739643  <S^2> = 0  2S+1 = 1
# converged SCF energy = -1.11675930739643
# converged SCF energy = -1.12537219464375
# converged SCF energy = -1.12537219464375  <S^2> = 0  2S+1 = 1
# converged SCF energy = -1.12537219464375
# converged SCF energy = -7.86186476980865
# converged SCF energy = -7.86186476978944  <S^2> = 3.7932857e-10  2S+1 = 1
# converged SCF energy = -7.86186476980865
# converged SCF energy = -7.95180496344701
# converged SCF energy = -7.9518049634282  <S^2> = 3.5752334e-10  2S+1 = 1
# converged SCF energy = -7.951804963447
# converged SCF energy = -74.9624891153372
# converged SCF energy = -74.9624891153381  <S^2> = 1.5196733e-12  2S+1 = 1
# converged SCF energy = -74.9624891153372
# converged SCF energy = -75.6782528024108
# converged SCF energy = -75.6782528024112  <S^2> = 1.9557689e-12  2S+1 = 1
# converged SCF energy = -75.6782528024108
#
# Comparison of HF, RHF, ROHF, and FCI Energies:
#
# Molecule   Basis   Method       Energy
# ========================================
# H2         sto-3g  FCI     -1.85238817
# H2         sto-3g  RHF     -1.11675931
# H2         sto-3g  UHF     -1.11675931
# H2         sto-3g  ROHF    -1.11675931
# H2         sto-6g  FCI     -1.86104415
# H2         sto-6g  RHF     -1.12537219
# H2         sto-6g  UHF     -1.12537219
# H2         sto-6g  ROHF    -1.12537219
# LiH        sto-3g  FCI     -8.87453165
# LiH        sto-3g  RHF     -7.86186477
# LiH        sto-3g  UHF     -7.86186477
# LiH        sto-3g  ROHF    -7.86186477
# LiH        sto-6g  FCI     -8.96445712
# LiH        sto-6g  RHF     -7.95180496
# LiH        sto-6g  UHF     -7.95180496
# LiH        sto-6g  ROHF    -7.95180496
# H2O        sto-3g  FCI    -84.21604696
# H2O        sto-3g  RHF    -74.96248912
# H2O        sto-3g  UHF    -74.96248912
# H2O        sto-3g  ROHF   -74.96248912
# H2O        sto-6g  FCI    -84.93234415
# H2O        sto-6g  RHF    -75.67825280
# H2O        sto-6g  UHF    -75.67825280
# H2O        sto-6g  ROHF   -75.67825280

# %% [markdown]
# **Potential Energy Surface**

# %%
charge = 0
basis = 'sto3g'
mapping_name = "parity"

transformer_reaction = ActiveSpaceTransformer(num_electrons=8,num_spatial_orbitals=8)

##
# fixed parameters
H2_R = 0.74 #Angstrom, H2 bond distance
# d = 0.2
# Define grid
L=8
R_values = np.linspace(0.1, 1.16,L)  # Range of R in Å
d_values = np.linspace(-0.5, 0.5,L) # Range of d in Å, distance from CO2 center to H2 center
#phi_values = np.linspace(0, pi, L)

pes_data = []
###

for known_R in R_values:
    for d in d_values:
        atom_str = (
            f"C .0 .0 .0; "
            f"O  .0 .0 {-known_R}; "
            f"O .0 .0 {known_R};"
            f"H .0 {-H2_R/2} {d};"
            f"H .0 {H2_R/2} {d};"
        )
        ###########

        #### PROBLEM DEFINITION
        reaction_qub, reaction_es = get_qubit_op(atom_str, charge, basis, mapping_name, transformer_reaction)
        _, reaction_energy, _ = get_exact_energies(reaction_es)

        pes_data.append((known_R, d, reaction_energy))

# Convert data to arrays
R1_list, R2_list, E_list = zip(*pes_data)
R1_grid = np.reshape(R1_list, (L,L))
R2_grid = np.reshape(R2_list, (L,L))
E_grid = np.reshape(E_list, (L,L))

plt.figure(figsize=(8, 6))
plt.contourf(R1_grid, R2_grid, E_grid, levels=100, cmap="viridis")
plt.colorbar(label="Energy (Hartree)")
plt.xlabel("known_R (Å)")
plt.ylabel("d (Å)")
plt.title("Potential Energy Surface of CO2+H2 Reaction")
plt.show()
# Out:
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1609
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1609
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1977
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1977
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1977
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1977
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1617
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
# Number of particles: (4, 4)
# Number of spatial orbitals: 8
# Number of qubits: 14
# Number of Paulis: 1545
